# %% [markdown]
# <a href="https://colab.research.google.com/github/Sachira-Heshan/omic-data-and-machine-learning-in-the-identification-of-coronary-artery-disease/blob/main/microarray_data/models_with_microarray_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Research/Datasets/Cleaned/cleaned-dataset-GSE113079.xlsx')
df
# Out:
#             Unnamed: 0         0         1         2         3         4  \
# 0      GE_BrightCorner  2.157974  1.779174  1.476457  1.635460  1.459245
# 1           DarkCorner -4.972070 -5.079564 -5.055798 -5.048396 -4.759264
# 2            p42318_v4 -5.136246 -5.309609 -4.683745 -5.058544 -5.044792
# 3                 p117 -0.908056 -0.279806 -0.814316 -0.403859 -0.239435
# 4               p28737 -5.142836 -5.326123 -4.436602 -5.173800 -5.042362
# ...                ...       ...       ...       ...       ...       ...
# 65519           p11121 -0.410480 -0.499581  0.422740  0.741620 -0.625730
# 65520           p26746 -3.946267 -4.027231 -4.745641 -4.544183 -4.912573
# 65521    A_33_P3677559 -3.019150 -3.490440 -3.532535 -4.334243 -4.216743
# 65522             p361 -1.535002 -1.432819 -1.561514 -1.536728 -1.963562
# 65523     target_value  1.000000  1.000000  1.000000  1.000000  1.000000
#
#               5         6         7         8  ...       131       132  \
# 0      1.014671  1.548667  1.299535  1.340023  ...  2.105669  3.494671
# 1     -5.384547 -4.916507 -4.586820 -4.649654  ... -2.250812 -4.181840
# 2     -5.042380 -5.147751 -4.501071 -4.903667  ... -2.410703 -4.110729
# 3     -0.586996 -0.996306 -0.345914 -0.344358  ... -1.481907 -0.438192
# 4     -5.497274 -5.146853 -4.856003 -4.855644  ... -2.457831 -4.348550
# ...         ...       ...       ...       ...  ...       ...       ...
# 65519 -0.441957 -0.252325 -0.555881 -1.208597  ... -0.757013  0.169991
# 65520 -5.310057 -4.868157 -4.756682 -5.345671  ... -2.579270 -4.372013
# 65521 -5.219829 -5.396364 -3.718595 -2.599477  ... -2.389817 -4.387563
# 65522 -2.229453 -2.975171 -2.859623 -2.772754  ... -2.327698 -3.180684
# 65523  1.000000  1.000000  1.000000  1.000000  ...  0.000000  0.000000
#
#             133       134       135       136       137       138       139  \
# 0      2.225658  2.244781  2.954112  4.258145  3.446817  3.219271  3.048190
# 1     -5.607463 -5.420901 -6.074095 -5.355829 -5.419512 -5.156093 -5.566904
# 2     -5.811153 -5.480375 -6.194078 -4.979015 -5.532501 -5.517557 -5.754226
# 3     -0.463400 -0.838711 -0.213053 -0.019725 -0.439010 -0.169885 -0.269132
# 4     -5.849335 -5.599132 -6.290147 -4.613355 -5.186365 -5.343323 -5.344678
# ...         ...       ...       ...       ...       ...       ...       ...
# 65519 -0.178983  0.499544 -0.530568 -1.288435 -0.544972  0.350077 -0.841183
# 65520 -4.498916 -4.658971 -5.640641 -5.186352 -5.634085 -5.651629 -5.692634
# 65521 -3.224986 -3.943109 -4.271065 -4.154407 -4.483709 -4.718823 -4.067185
# 65522 -2.276162 -2.942826 -3.597050 -3.767594 -3.135914 -3.117811 -3.442971
# 65523  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             140
# 0      3.601977
# 1     -5.874120
# 2     -6.050066
# 3     -0.156173
# 4     -5.375709
# ...         ...
# 65519 -0.443985
# 65520 -6.183776
# 65521 -4.858379
# 65522 -4.068343
# 65523  0.000000
#
# [65524 rows x 142 columns]

# %%
df = df.T
df
# Out:
#                       0           1          2         3         4      \
# Unnamed: 0  GE_BrightCorner  DarkCorner  p42318_v4      p117    p28737
# 0                  2.157974    -4.97207  -5.136246 -0.908056 -5.142836
# 1                  1.779174   -5.079564  -5.309609 -0.279806 -5.326123
# 2                  1.476457   -5.055798  -4.683745 -0.814316 -4.436602
# 3                   1.63546   -5.048396  -5.058544 -0.403859   -5.1738
# ...                     ...         ...        ...       ...       ...
# 136                4.258145   -5.355829  -4.979015 -0.019725 -4.613355
# 137                3.446817   -5.419512  -5.532501  -0.43901 -5.186365
# 138                3.219271   -5.156093  -5.517557 -0.169885 -5.343323
# 139                 3.04819   -5.566904  -5.754226 -0.269132 -5.344678
# 140                3.601977    -5.87412  -6.050066 -0.156173 -5.375709
#
#                5              6         7         8         9      ...  \
# Unnamed: 0    p17314  A_33_P3310047    p22477     p8225     p7095  ...
# 0           -5.24106       0.996369 -3.309695 -1.096744 -2.356272  ...
# 1          -5.431599       1.049151  -2.68212  -0.88413 -3.141455  ...
# 2          -5.483527       1.107679 -3.565926 -1.364489 -3.778602  ...
# 3          -5.315852       0.922813 -3.687033 -0.971812 -2.599749  ...
# ...              ...            ...       ...       ...       ...  ...
# 136        -4.134005       -1.02978 -4.104466  -1.71746 -1.981112  ...
# 137        -4.357549      -0.695331 -5.582504 -2.215403 -1.984762  ...
# 138        -3.391208       -0.55013 -5.504555 -2.193739 -2.051957  ...
# 139        -2.432148      -0.529649 -5.844207 -2.272894 -2.500574  ...
# 140        -3.145069      -0.341402   -5.2971 -1.877006 -2.699321  ...
#
#                65514     65515          65516          65517         65518  \
# Unnamed: 0    p25976    p23884  A_33_P3800496  A_21_P0006729  A_24_P284523
# 0           1.746663 -2.448382      -1.259322      -3.232127      3.164295
# 1           0.961229 -2.325115      -0.878489      -2.476317      3.059818
# 2            1.24937 -2.352775      -1.309131      -2.841979      2.908225
# 3           1.431779 -3.219944      -1.369312      -2.633309      2.667611
# ...              ...       ...            ...            ...           ...
# 136         1.562222 -5.508901      -1.604411      -5.501566      1.666188
# 137          1.16232 -5.405059      -2.289792      -5.268457      2.085141
# 138         1.138208 -5.613715      -1.707906      -2.949284      2.089414
# 139         1.303925 -5.470889      -1.717739      -5.548789      1.890642
# 140         1.101084 -4.271622      -1.615469      -4.164873      2.211423
#
#                65519     65520          65521     65522         65523
# Unnamed: 0    p11121    p26746  A_33_P3677559      p361  target_value
# 0           -0.41048 -3.946267       -3.01915 -1.535002           1.0
# 1          -0.499581 -4.027231       -3.49044 -1.432819           1.0
# 2            0.42274 -4.745641      -3.532535 -1.561514           1.0
# 3            0.74162 -4.544183      -4.334243 -1.536728           1.0
# ...              ...       ...            ...       ...           ...
# 136        -1.288435 -5.186352      -4.154407 -3.767594           0.0
# 137        -0.544972 -5.634085      -4.483709 -3.135914           0.0
# 138         0.350077 -5.651629      -4.718823 -3.117811           0.0
# 139        -0.841183 -5.692634      -4.067185 -3.442971           0.0
# 140        -0.443985 -6.183776      -4.858379 -4.068343           0.0
#
# [142 rows x 65524 columns]

# %%
column_names = df.iloc[0, :]
df.columns = column_names.tolist()
df
# Out:
#             GE_BrightCorner  DarkCorner  p42318_v4      p117    p28737  \
# Unnamed: 0  GE_BrightCorner  DarkCorner  p42318_v4      p117    p28737
# 0                  2.157974    -4.97207  -5.136246 -0.908056 -5.142836
# 1                  1.779174   -5.079564  -5.309609 -0.279806 -5.326123
# 2                  1.476457   -5.055798  -4.683745 -0.814316 -4.436602
# 3                   1.63546   -5.048396  -5.058544 -0.403859   -5.1738
# ...                     ...         ...        ...       ...       ...
# 136                4.258145   -5.355829  -4.979015 -0.019725 -4.613355
# 137                3.446817   -5.419512  -5.532501  -0.43901 -5.186365
# 138                3.219271   -5.156093  -5.517557 -0.169885 -5.343323
# 139                 3.04819   -5.566904  -5.754226 -0.269132 -5.344678
# 140                3.601977    -5.87412  -6.050066 -0.156173 -5.375709
#
#               p17314  A_33_P3310047    p22477     p8225     p7095  ...  \
# Unnamed: 0    p17314  A_33_P3310047    p22477     p8225     p7095  ...
# 0           -5.24106       0.996369 -3.309695 -1.096744 -2.356272  ...
# 1          -5.431599       1.049151  -2.68212  -0.88413 -3.141455  ...
# 2          -5.483527       1.107679 -3.565926 -1.364489 -3.778602  ...
# 3          -5.315852       0.922813 -3.687033 -0.971812 -2.599749  ...
# ...              ...            ...       ...       ...       ...  ...
# 136        -4.134005       -1.02978 -4.104466  -1.71746 -1.981112  ...
# 137        -4.357549      -0.695331 -5.582504 -2.215403 -1.984762  ...
# 138        -3.391208       -0.55013 -5.504555 -2.193739 -2.051957  ...
# 139        -2.432148      -0.529649 -5.844207 -2.272894 -2.500574  ...
# 140        -3.145069      -0.341402   -5.2971 -1.877006 -2.699321  ...
#
#               p25976    p23884  A_33_P3800496  A_21_P0006729  A_24_P284523  \
# Unnamed: 0    p25976    p23884  A_33_P3800496  A_21_P0006729  A_24_P284523
# 0           1.746663 -2.448382      -1.259322      -3.232127      3.164295
# 1           0.961229 -2.325115      -0.878489      -2.476317      3.059818
# 2            1.24937 -2.352775      -1.309131      -2.841979      2.908225
# 3           1.431779 -3.219944      -1.369312      -2.633309      2.667611
# ...              ...       ...            ...            ...           ...
# 136         1.562222 -5.508901      -1.604411      -5.501566      1.666188
# 137          1.16232 -5.405059      -2.289792      -5.268457      2.085141
# 138         1.138208 -5.613715      -1.707906      -2.949284      2.089414
# 139         1.303925 -5.470889      -1.717739      -5.548789      1.890642
# 140         1.101084 -4.271622      -1.615469      -4.164873      2.211423
#
#               p11121    p26746  A_33_P3677559      p361  target_value
# Unnamed: 0    p11121    p26746  A_33_P3677559      p361  target_value
# 0           -0.41048 -3.946267       -3.01915 -1.535002           1.0
# 1          -0.499581 -4.027231       -3.49044 -1.432819           1.0
# 2            0.42274 -4.745641      -3.532535 -1.561514           1.0
# 3            0.74162 -4.544183      -4.334243 -1.536728           1.0
# ...              ...       ...            ...       ...           ...
# 136        -1.288435 -5.186352      -4.154407 -3.767594           0.0
# 137        -0.544972 -5.634085      -4.483709 -3.135914           0.0
# 138         0.350077 -5.651629      -4.718823 -3.117811           0.0
# 139        -0.841183 -5.692634      -4.067185 -3.442971           0.0
# 140        -0.443985 -6.183776      -4.858379 -4.068343           0.0
#
# [142 rows x 65524 columns]

# %%
df.drop(index=["Unnamed: 0"], inplace=True)
df
# Out:
#     GE_BrightCorner DarkCorner p42318_v4      p117    p28737    p17314  \
# 0          2.157974   -4.97207 -5.136246 -0.908056 -5.142836  -5.24106
# 1          1.779174  -5.079564 -5.309609 -0.279806 -5.326123 -5.431599
# 2          1.476457  -5.055798 -4.683745 -0.814316 -4.436602 -5.483527
# 3           1.63546  -5.048396 -5.058544 -0.403859   -5.1738 -5.315852
# 4          1.459245  -4.759264 -5.044792 -0.239435 -5.042362 -4.622399
# ..              ...        ...       ...       ...       ...       ...
# 136        4.258145  -5.355829 -4.979015 -0.019725 -4.613355 -4.134005
# 137        3.446817  -5.419512 -5.532501  -0.43901 -5.186365 -4.357549
# 138        3.219271  -5.156093 -5.517557 -0.169885 -5.343323 -3.391208
# 139         3.04819  -5.566904 -5.754226 -0.269132 -5.344678 -2.432148
# 140        3.601977   -5.87412 -6.050066 -0.156173 -5.375709 -3.145069
#
#     A_33_P3310047    p22477     p8225     p7095  ...    p25976    p23884  \
# 0        0.996369 -3.309695 -1.096744 -2.356272  ...  1.746663 -2.448382
# 1        1.049151  -2.68212  -0.88413 -3.141455  ...  0.961229 -2.325115
# 2        1.107679 -3.565926 -1.364489 -3.778602  ...   1.24937 -2.352775
# 3        0.922813 -3.687033 -0.971812 -2.599749  ...  1.431779 -3.219944
# 4        0.786796 -3.605453 -0.992999 -3.243779  ...  1.117545 -3.630248
# ..            ...       ...       ...       ...  ...       ...       ...
# 136      -1.02978 -4.104466  -1.71746 -1.981112  ...  1.562222 -5.508901
# 137     -0.695331 -5.582504 -2.215403 -1.984762  ...   1.16232 -5.405059
# 138      -0.55013 -5.504555 -2.193739 -2.051957  ...  1.138208 -5.613715
# 139     -0.529649 -5.844207 -2.272894 -2.500574  ...  1.303925 -5.470889
# 140     -0.341402   -5.2971 -1.877006 -2.699321  ...  1.101084 -4.271622
#
#     A_33_P3800496 A_21_P0006729 A_24_P284523    p11121    p26746  \
# 0       -1.259322     -3.232127     3.164295  -0.41048 -3.946267
# 1       -0.878489     -2.476317     3.059818 -0.499581 -4.027231
# 2       -1.309131     -2.841979     2.908225   0.42274 -4.745641
# 3       -1.369312     -2.633309     2.667611   0.74162 -4.544183
# 4       -1.304075     -3.936828      2.64173  -0.62573 -4.912573
# ..            ...           ...          ...       ...       ...
# 136     -1.604411     -5.501566     1.666188 -1.288435 -5.186352
# 137     -2.289792     -5.268457     2.085141 -0.544972 -5.634085
# 138     -1.707906     -2.949284     2.089414  0.350077 -5.651629
# 139     -1.717739     -5.548789     1.890642 -0.841183 -5.692634
# 140     -1.615469     -4.164873     2.211423 -0.443985 -6.183776
#
#     A_33_P3677559      p361 target_value
# 0        -3.01915 -1.535002          1.0
# 1        -3.49044 -1.432819          1.0
# 2       -3.532535 -1.561514          1.0
# 3       -4.334243 -1.536728          1.0
# 4       -4.216743 -1.963562          1.0
# ..            ...       ...          ...
# 136     -4.154407 -3.767594          0.0
# 137     -4.483709 -3.135914          0.0
# 138     -4.718823 -3.117811          0.0
# 139     -4.067185 -3.442971          0.0
# 140     -4.858379 -4.068343          0.0
#
# [141 rows x 65524 columns]

# %%
# convert target value as integer
df["target_value"] = df["target_value"].astype(int)
df
# Out:
#     GE_BrightCorner DarkCorner p42318_v4      p117    p28737    p17314  \
# 0          2.157974   -4.97207 -5.136246 -0.908056 -5.142836  -5.24106
# 1          1.779174  -5.079564 -5.309609 -0.279806 -5.326123 -5.431599
# 2          1.476457  -5.055798 -4.683745 -0.814316 -4.436602 -5.483527
# 3           1.63546  -5.048396 -5.058544 -0.403859   -5.1738 -5.315852
# 4          1.459245  -4.759264 -5.044792 -0.239435 -5.042362 -4.622399
# ..              ...        ...       ...       ...       ...       ...
# 136        4.258145  -5.355829 -4.979015 -0.019725 -4.613355 -4.134005
# 137        3.446817  -5.419512 -5.532501  -0.43901 -5.186365 -4.357549
# 138        3.219271  -5.156093 -5.517557 -0.169885 -5.343323 -3.391208
# 139         3.04819  -5.566904 -5.754226 -0.269132 -5.344678 -2.432148
# 140        3.601977   -5.87412 -6.050066 -0.156173 -5.375709 -3.145069
#
#     A_33_P3310047    p22477     p8225     p7095  ...    p25976    p23884  \
# 0        0.996369 -3.309695 -1.096744 -2.356272  ...  1.746663 -2.448382
# 1        1.049151  -2.68212  -0.88413 -3.141455  ...  0.961229 -2.325115
# 2        1.107679 -3.565926 -1.364489 -3.778602  ...   1.24937 -2.352775
# 3        0.922813 -3.687033 -0.971812 -2.599749  ...  1.431779 -3.219944
# 4        0.786796 -3.605453 -0.992999 -3.243779  ...  1.117545 -3.630248
# ..            ...       ...       ...       ...  ...       ...       ...
# 136      -1.02978 -4.104466  -1.71746 -1.981112  ...  1.562222 -5.508901
# 137     -0.695331 -5.582504 -2.215403 -1.984762  ...   1.16232 -5.405059
# 138      -0.55013 -5.504555 -2.193739 -2.051957  ...  1.138208 -5.613715
# 139     -0.529649 -5.844207 -2.272894 -2.500574  ...  1.303925 -5.470889
# 140     -0.341402   -5.2971 -1.877006 -2.699321  ...  1.101084 -4.271622
#
#     A_33_P3800496 A_21_P0006729 A_24_P284523    p11121    p26746  \
# 0       -1.259322     -3.232127     3.164295  -0.41048 -3.946267
# 1       -0.878489     -2.476317     3.059818 -0.499581 -4.027231
# 2       -1.309131     -2.841979     2.908225   0.42274 -4.745641
# 3       -1.369312     -2.633309     2.667611   0.74162 -4.544183
# 4       -1.304075     -3.936828      2.64173  -0.62573 -4.912573
# ..            ...           ...          ...       ...       ...
# 136     -1.604411     -5.501566     1.666188 -1.288435 -5.186352
# 137     -2.289792     -5.268457     2.085141 -0.544972 -5.634085
# 138     -1.707906     -2.949284     2.089414  0.350077 -5.651629
# 139     -1.717739     -5.548789     1.890642 -0.841183 -5.692634
# 140     -1.615469     -4.164873     2.211423 -0.443985 -6.183776
#
#     A_33_P3677559      p361 target_value
# 0        -3.01915 -1.535002            1
# 1        -3.49044 -1.432819            1
# 2       -3.532535 -1.561514            1
# 3       -4.334243 -1.536728            1
# 4       -4.216743 -1.963562            1
# ..            ...       ...          ...
# 136     -4.154407 -3.767594            0
# 137     -4.483709 -3.135914            0
# 138     -4.718823 -3.117811            0
# 139     -4.067185 -3.442971            0
# 140     -4.858379 -4.068343            0
#
# [141 rows x 65524 columns]

# %%
dataset = df.copy()
dataset.value_counts('target_value')
# Out:
# target_value
# 1    93
# 0    48
# dtype: int64

# %%
dataset.shape
# Out:
# (141, 65524)

# %%
X = dataset.drop(columns=["target_value"])
y = dataset["target_value"]

# %%
X.shape
# Out:
# (141, 65523)

# %%
y.shape
# Out:
# (141,)

# %%
# mutual information values
from sklearn.feature_selection import mutual_info_classif
import numpy as np

# Calculate Mutual Information between each feature and the target variable
mi_scores = mutual_info_classif(X, y, discrete_features=[False]*X.shape[1])

# Create a dictionary that maps feature names to their MI scores
feature_mi_scores = {feature_name: mi_score for feature_name, mi_score in zip(X.columns, mi_scores)}

# Sort the features in ascending order of their MI scores
sorted_features_ascending = sorted(feature_mi_scores.items(), key=lambda x: x[1])

# %%
# now let's plot this data
import matplotlib.pyplot as plt

# Extract the feature names and their MI scores from sorted_features_ascending
feature_names, mi_scores = zip(*sorted_features_ascending)

# Create a bar plot to visualize MI scores
plt.figure(figsize=(12, 8))
plt.barh(range(len(feature_names)), mi_scores, align='center', alpha=0.7)
plt.yticks(range(len(feature_names)), feature_names)
plt.xlabel('Mutual Information Score')
plt.ylabel('Feature Name')
plt.title('Mutual Information Scores of All Features')
plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
# Filter features with non-zero mutual information scores
selected_features = [feature_name for feature_name, mi_score in sorted_features_ascending if mi_score > 0]
# let's create new X with only these features
X_selected = X[selected_features]
X_selected.shape
# Out:
# (141, 54244)

# %%
# let's select best 1000 features
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
# Feature selection using mutual information
mi_classif = SelectKBest(score_func=mutual_info_classif, k=1000)

# Apply the mutual information selector on the dataset
X_MI_selected = mi_classif.fit_transform(X, y)

# Get the selected features
selected_features = mi_classif.get_support()

# Feature names of selected features
selected_feature_names = X.columns[selected_features]

X_top = X[selected_feature_names]

print("Shape of X_top: ", X_top.shape)
# Out:
# Shape of X_top:  (141, 1000)

# %%
# SVM
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

no_of_features = [1, 2, 3]
cross_val_k = [5, 8, 10]
results = {}

for feature_count in no_of_features:
    print(f"RESULTS FOR {feature_count} FEATURES")
    print("--------------------------------------------------")

    results[feature_count] = {}

    # Feature selection using mutual information
    mi_classif = SelectKBest(score_func=mutual_info_classif, k=feature_count)

    # Apply the mutual information selector on the dataset
    X_MI_selected = mi_classif.fit_transform(X_top, y)

    # Get the selected features
    selected_features = mi_classif.get_support()

    # Feature names of selected features
    selected_feature_names = X_top.columns[selected_features]

    X_new = X_top[selected_feature_names]

    print("Shape of X_new: ", X_new.shape)

    # Divide the dataset to train 0.8 and test 0.2
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Create SVM classifier and fit the data
    svm_classif = SVC()
    svm_classif.fit(X_train, y_train)

    # Test the model on the test set
    y_pred = svm_classif.predict(X_test)

    # Check the accuracy of the model
    accuracy_svm_model = accuracy_score(y_test, y_pred)
    print(f"Accuracy of the {feature_count} features SVM model is: {round(accuracy_svm_model * 100, 3)}%")

    results[feature_count]["accuracy"] = round(accuracy_svm_model * 100, 3)

    # Confusion matrix of the model
    confusion_matrix_svm_model = confusion_matrix(y_test, y_pred)

    TP_svm_model = confusion_matrix_svm_model[1, 1]  # True Positives
    FN_svm_model = confusion_matrix_svm_model[1, 0]  # False Negatives

    # Calculate Sensitivity (True Positive Rate or Recall)
    sensitivity_svm_model = TP_svm_model / (TP_svm_model + FN_svm_model)
    print(f"Sensitivity for {feature_count} features SVM model (True Positive Rate): {round(sensitivity_svm_model * 100, 3)}%")

    results[feature_count]["sensitivity"] = round(sensitivity_svm_model * 100, 3)

    # Print the confusion matrix
    print(f"Confusion matrix of the {feature_count} features SVM model is: ")
    print(confusion_matrix_svm_model)

    # Classification report for the model
    report_svm_model = classification_report(y_test, y_pred)
    print(f"Classification report of {feature_count} features SVM model is: ")
    print(report_svm_model)

    # Now let's do the cross-validation
    for k in cross_val_k:
        print(f"{k}-fold Cross Validation")

        results[feature_count][f"{k}-fold-CV"] = {}

        # Create a cross-validation object (K-Fold cross-validator)
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Perform k-fold cross-validation and get the cross-validation scores using SVM
        scores = cross_val_score(svm_classif, X_new, y, cv=kf, scoring='accuracy')

        # Print the cross-validation scores
        print("Cross-Validation Scores:", scores)

        # Calculate and print the mean and standard deviation of the scores
        print(f"Mean Accuracy: {round(scores.mean() * 100, 3)}%")
        print(f"Standard Deviation: {round(scores.std() * 100, 3)}%")

        results[feature_count][f"{k}-fold-CV"]["mean-accuracy"] = round(scores.mean() * 100, 3)
        results[feature_count][f"{k}-fold-CV"]["standard-deviation"] = round(scores.std() * 100, 3)
        results[feature_count]["acc-std"] = f"{results[feature_count][f'{k}-fold-CV']['mean-accuracy']}% ± {results[feature_count][f'{k}-fold-CV']['standard-deviation']}%"

        print("")
    print("")
# Out:
# RESULTS FOR 1 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 1)
# Accuracy of the 1 features SVM model is: 89.655%
# Sensitivity for 1 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 1 features SVM model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 1 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 0.89285714 0.89285714 0.85714286]
# Mean Accuracy: 90.074%
# Standard Deviation: 3.487%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 0.88888889 0.94444444 0.88235294
#  0.88235294 0.88235294]
# Mean Accuracy: 90.727%
# Standard Deviation: 2.891%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 0.85714286 0.92857143
#  1.         0.78571429 0.92857143 0.85714286]
# Mean Accuracy: 90.762%
# Standard Deviation: 6.446%
#
#
# RESULTS FOR 2 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 2)
# Accuracy of the 2 features SVM model is: 89.655%
# Sensitivity for 2 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 2 features SVM model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 2 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 0.92857143 0.92857143 0.92857143]
# Mean Accuracy: 92.931%
# Standard Deviation: 2.144%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 0.94444444 0.94444444 0.94117647
#  0.94117647 0.88235294]
# Mean Accuracy: 92.892%
# Standard Deviation: 2.509%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         0.92857143 0.92857143
#  1.         0.85714286 1.         0.85714286]
# Mean Accuracy: 93.619%
# Standard Deviation: 5.929%
#
#
# RESULTS FOR 3 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 3)
# Accuracy of the 3 features SVM model is: 89.655%
# Sensitivity for 3 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 3 features SVM model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 3 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 0.92857143 0.89285714 0.92857143]
# Mean Accuracy: 92.217%
# Standard Deviation: 2.597%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 0.94444444 0.94444444 0.94444444 0.88235294
#  0.94117647 0.88235294]
# Mean Accuracy: 92.851%
# Standard Deviation: 2.667%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.92857143 1.         0.92857143 0.92857143 0.92857143
#  1.         0.85714286 1.         0.85714286]
# Mean Accuracy: 93.619%
# Standard Deviation: 4.995%

# %%
selected_feature_names
# Out:
# Index(['A_32_P75902', 'RNA95441|RNS_523_158', 'A_33_P3290588'], dtype='object')

# %%
# Extract the data for plotting
x_values = results.keys()
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results.values()]
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results.values()]

# Create a single plot for mean accuracy and standard deviation
plt.figure(figsize=(12, 8))

plt.errorbar(x_values, mean_5_fold, yerr=std_5_fold, marker='o', label='5-fold', linestyle='-', capsize=5)

plt.xlabel('Number of features')
plt.ylabel('Mean Accuracy')
plt.title('Variation of Mean Accuracy with different number of features for 5-fold Cross Validation')
plt.legend()
plt.grid(True)

plt.show()

# %%
# SVM
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

no_of_features = [5, 15, 25, 35, 45, 55, 65]
cross_val_k = [5, 8, 10]
results_svm = {}

for feature_count in no_of_features:
    print(f"RESULTS FOR {feature_count} FEATURES")
    print("--------------------------------------------------")

    results_svm[feature_count] = {}

    # Feature selection using mutual information
    mi_classif = SelectKBest(score_func=mutual_info_classif, k=feature_count)

    # Apply the mutual information selector on the dataset
    X_MI_selected = mi_classif.fit_transform(X_top, y)

    # Get the selected features
    selected_features = mi_classif.get_support()

    # Feature names of selected features
    selected_feature_names = X_top.columns[selected_features]

    X_new = X_top[selected_feature_names]

    print("Shape of X_new: ", X_new.shape)

    # Divide the dataset to train 0.8 and test 0.2
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Create SVM classifier and fit the data
    svm_classif = SVC()
    svm_classif.fit(X_train, y_train)

    # Test the model on the test set
    y_pred = svm_classif.predict(X_test)

    # Check the accuracy of the model
    accuracy_svm_model = accuracy_score(y_test, y_pred)
    print(f"Accuracy of the {feature_count} features SVM model is: {round(accuracy_svm_model * 100, 3)}%")

    results_svm[feature_count]["accuracy"] = round(accuracy_svm_model * 100, 3)

    # Confusion matrix of the model
    confusion_matrix_svm_model = confusion_matrix(y_test, y_pred)

    TP_svm_model = confusion_matrix_svm_model[1, 1]  # True Positives
    FN_svm_model = confusion_matrix_svm_model[1, 0]  # False Negatives

    # Calculate Sensitivity (True Positive Rate or Recall)
    sensitivity_svm_model = TP_svm_model / (TP_svm_model + FN_svm_model)
    print(f"Sensitivity for {feature_count} features SVM model (True Positive Rate): {round(sensitivity_svm_model * 100, 3)}%")

    results_svm[feature_count]["sensitivity"] = round(sensitivity_svm_model * 100, 3)

    # Print the confusion matrix
    print(f"Confusion matrix of the {feature_count} features SVM model is: ")
    print(confusion_matrix_svm_model)

    # Classification report for the model
    report_svm_model = classification_report(y_test, y_pred)
    print(f"Classification report of {feature_count} features SVM model is: ")
    print(report_svm_model)

    # Now let's do the cross-validation
    for k in cross_val_k:
        print(f"{k}-fold Cross Validation")

        results_svm[feature_count][f"{k}-fold-CV"] = {}

        # Create a cross-validation object (K-Fold cross-validator)
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Perform k-fold cross-validation and get the cross-validation scores using SVM
        scores = cross_val_score(svm_classif, X_new, y, cv=kf, scoring='accuracy')

        # Print the cross-validation scores
        print("Cross-Validation Scores:", scores)

        # Calculate and print the mean and standard deviation of the scores
        print(f"Mean Accuracy: {round(scores.mean() * 100, 3)}%")
        print(f"Standard Deviation: {round(scores.std() * 100, 3)}%")

        results_svm[feature_count][f"{k}-fold-CV"]["mean-accuracy"] = round(scores.mean() * 100, 3)
        results_svm[feature_count][f"{k}-fold-CV"]["standard-deviation"] = round(scores.std() * 100, 3)
        results_svm[feature_count]["acc-std"] = f"{results_svm[feature_count][f'{k}-fold-CV']['mean-accuracy']}% ± {results_svm[feature_count][f'{k}-fold-CV']['standard-deviation']}%"

        print("")
    print("")
# Out:
# RESULTS FOR 5 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 5)
# Accuracy of the 5 features SVM model is: 89.655%
# Sensitivity for 5 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 5 features SVM model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 5 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 0.92857143 0.89285714 0.92857143]
# Mean Accuracy: 92.217%
# Standard Deviation: 2.597%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 0.94444444 0.94444444 0.94444444 0.88235294
#  0.94117647 0.88235294]
# Mean Accuracy: 92.851%
# Standard Deviation: 2.667%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.92857143 1.         0.92857143 0.92857143 0.92857143
#  1.         0.78571429 1.         0.85714286]
# Mean Accuracy: 92.905%
# Standard Deviation: 6.39%
#
#
# RESULTS FOR 15 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 15)
# Accuracy of the 15 features SVM model is: 89.655%
# Sensitivity for 15 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 15 features SVM model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 15 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 0.92857143 0.96428571 0.92857143]
# Mean Accuracy: 93.645%
# Standard Deviation: 2.556%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 1.         0.94444444 1.
#  0.94117647 0.88235294]
# Mean Accuracy: 94.322%
# Standard Deviation: 4.049%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         0.92857143
#  1.         0.92857143 1.         0.85714286]
# Mean Accuracy: 94.333%
# Standard Deviation: 5.334%
#
#
# RESULTS FOR 25 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 25)
# Accuracy of the 25 features SVM model is: 89.655%
# Sensitivity for 25 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 25 features SVM model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 25 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 0.96428571 0.92857143 0.92857143]
# Mean Accuracy: 93.645%
# Standard Deviation: 2.556%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 1.         0.94444444 0.94117647
#  0.94117647 0.88235294]
# Mean Accuracy: 93.587%
# Standard Deviation: 3.439%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         0.92857143
#  1.         0.85714286 1.         0.85714286]
# Mean Accuracy: 93.619%
# Standard Deviation: 5.929%
#
#
# RESULTS FOR 35 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 35)
# Accuracy of the 35 features SVM model is: 89.655%
# Sensitivity for 35 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 35 features SVM model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 35 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 0.96428571 0.89285714 0.92857143]
# Mean Accuracy: 92.931%
# Standard Deviation: 3.114%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 1.         0.94444444 0.88235294
#  0.94117647 0.88235294]
# Mean Accuracy: 92.851%
# Standard Deviation: 3.851%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         0.92857143
#  1.         0.78571429 1.         0.85714286]
# Mean Accuracy: 92.905%
# Standard Deviation: 7.144%
#
#
# RESULTS FOR 45 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 45)
# Accuracy of the 45 features SVM model is: 89.655%
# Sensitivity for 45 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 45 features SVM model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 45 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 0.96428571 0.89285714 0.92857143]
# Mean Accuracy: 92.931%
# Standard Deviation: 3.114%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 1.         0.94444444 0.88235294
#  0.94117647 0.88235294]
# Mean Accuracy: 92.851%
# Standard Deviation: 3.851%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         0.92857143
#  1.         0.78571429 1.         0.85714286]
# Mean Accuracy: 92.905%
# Standard Deviation: 7.144%
#
#
# RESULTS FOR 55 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 55)
# Accuracy of the 55 features SVM model is: 89.655%
# Sensitivity for 55 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 55 features SVM model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 55 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 0.92857143 0.89285714 0.92857143]
# Mean Accuracy: 92.217%
# Standard Deviation: 2.597%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 1.         0.94444444 0.88235294
#  0.94117647 0.88235294]
# Mean Accuracy: 92.851%
# Standard Deviation: 3.851%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         0.92857143
#  1.         0.78571429 1.         0.85714286]
# Mean Accuracy: 92.905%
# Standard Deviation: 7.144%
#
#
# RESULTS FOR 65 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 65)
# Accuracy of the 65 features SVM model is: 89.655%
# Sensitivity for 65 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 65 features SVM model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 65 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 0.92857143 0.89285714 0.92857143]
# Mean Accuracy: 92.217%
# Standard Deviation: 2.597%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 1.         0.94444444 0.88235294
#  0.94117647 0.88235294]
# Mean Accuracy: 92.851%
# Standard Deviation: 3.851%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         0.92857143
#  1.         0.78571429 1.         0.85714286]
# Mean Accuracy: 92.905%
# Standard Deviation: 7.144%

# %%
# Extract the data for plotting
x_values = results_svm.keys()
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results_svm.values()]
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results_svm.values()]

# Create a single plot for mean accuracy and standard deviation
plt.figure(figsize=(12, 8))

plt.errorbar(x_values, mean_5_fold, yerr=std_5_fold, marker='o', label='5-fold', linestyle='-', capsize=5)

plt.xlabel('Number of features')
plt.ylabel('Mean Accuracy')
plt.title('Variation of Mean Accuracy with different number of features for 5-fold Cross Validation')
plt.legend()
plt.grid(True)

plt.show()

# %%
results_svm
# Out:
# {5: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 92.217, 'standard-deviation': 2.597},
#   'acc-std': '92.905% ± 6.39%',
#   '8-fold-CV': {'mean-accuracy': 92.851, 'standard-deviation': 2.667},
#   '10-fold-CV': {'mean-accuracy': 92.905, 'standard-deviation': 6.39}},
#  15: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 93.645, 'standard-deviation': 2.556},
#   'acc-std': '94.333% ± 5.334%',
#   '8-fold-CV': {'mean-accuracy': 94.322, 'standard-deviation': 4.049},
#   '10-fold-CV': {'mean-accuracy': 94.333, 'standard-deviation': 5.334}},
#  25: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 93.645, 'standard-deviation': 2.556},
#   'acc-std': '93.619% ± 5.929%',
#   '8-fold-CV': {'mean-accuracy': 93.587, 'standard-deviation': 3.439},
#   '10-fold-CV': {'mean-accuracy': 93.619, 'standard-deviation': 5.929}},
#  35: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 92.931, 'standard-deviation': 3.114},
#   'acc-std': '92.905% ± 7.144%',
#   '8-fold-CV': {'mean-accuracy': 92.851, 'standard-deviation': 3.851},
#   '10-fold-CV': {'mean-accuracy': 92.905, 'standard-deviation': 7.144}},
#  45: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 92.931, 'standard-deviation': 3.114},
#   'acc-std': '92.905% ± 7.144%',
#   '8-fold-CV': {'mean-accuracy': 92.851, 'standard-deviation': 3.851},
#   '10-fold-CV': {'mean-accuracy': 92.905, 'standard-deviation': 7.144}},
#  55: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 92.217, 'standard-deviation': 2.597},
#   'acc-std': '92.905% ± 7.144%',
#   '8-fold-CV': {'mean-accuracy': 92.851, 'standard-deviation': 3.851},
#   '10-fold-CV': {'mean-accuracy': 92.905, 'standard-deviation': 7.144}},
#  65: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 92.217, 'standard-deviation': 2.597},
#   'acc-std': '92.905% ± 7.144%',
#   '8-fold-CV': {'mean-accuracy': 92.851, 'standard-deviation': 3.851},
#   '10-fold-CV': {'mean-accuracy': 92.905, 'standard-deviation': 7.144}}}

# %%
import matplotlib.pyplot as plt

x_values = results_svm.keys()
# Mean accuracy values for different number of features
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results_svm.values()]

# Standard deviation values for different number of features
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results_svm.values()]

# Create a bar chart for mean accuracy
plt.figure(figsize=(10, 6))
plt.bar(x_values, mean_5_fold, yerr=std_5_fold, capsize=5)
plt.xlabel("Number of Features")
plt.ylabel("Mean Accuracy")
plt.title("Mean Accuracy for Different Number of Features for SVM")
plt.show()

# %%
# Random Forest
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

no_of_features = [5, 15, 25, 35, 45, 55, 65]
cross_val_k = [5, 8, 10]
results_rf = {}

for feature_count in no_of_features:
    print(f"RESULTS FOR {feature_count} FEATURES")
    print("--------------------------------------------------")

    results_rf[feature_count] = {}

    # Feature selection using mutual information
    mi_classif = SelectKBest(score_func=mutual_info_classif, k=feature_count)

    # Apply the mutual information selector on the dataset
    X_MI_selected = mi_classif.fit_transform(X_top, y)

    # Get the selected features
    selected_features = mi_classif.get_support()

    # Feature names of selected features
    selected_feature_names = X_top.columns[selected_features]

    X_new = X_top[selected_feature_names]

    print("Shape of X_new: ", X_new.shape)

    # Divide the dataset to train 0.8 and test 0.2
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Create Random Forest classifier and fit the data
    rf_classif = RandomForestClassifier(n_estimators=100, random_state=42)
    rf_classif.fit(X_train, y_train)

    # Test the model on the test set
    y_pred = rf_classif.predict(X_test)

    # Check the accuracy of the model
    accuracy_rf_model = accuracy_score(y_test, y_pred)
    print(f"Accuracy of the {feature_count} features Random Forest model is: {round(accuracy_rf_model * 100, 3)}%")

    results_rf[feature_count]["accuracy"] = round(accuracy_rf_model * 100, 3)

    # Confusion matrix of the model
    confusion_matrix_rf_model = confusion_matrix(y_test, y_pred)

    TP_rf_model = confusion_matrix_rf_model[1, 1]  # True Positives
    FN_rf_model = confusion_matrix_rf_model[1, 0]  # False Negatives

    # Calculate Sensitivity (True Positive Rate or Recall)
    sensitivity_rf_model = TP_rf_model / (TP_rf_model + FN_rf_model)
    print(f"Sensitivity for {feature_count} features Random Forest model (True Positive Rate): {round(sensitivity_rf_model * 100, 3)}%")

    results_rf[feature_count]["sensitivity"] = round(sensitivity_rf_model * 100, 3)

    # Print the confusion matrix
    print(f"Confusion matrix of the {feature_count} features Random Forest model is: ")
    print(confusion_matrix_rf_model)

    # Classification report for the model
    report_rf_model = classification_report(y_test, y_pred)
    print(f"Classification report of {feature_count} features Random Forest model is: ")
    print(report_rf_model)

    # Now let's do the cross-validation
    for k in cross_val_k:
        print(f"{k}-fold Cross Validation")

        results_rf[feature_count][f"{k}-fold-CV"] = {}

        # Create a cross-validation object (K-Fold cross-validator)
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Perform k-fold cross-validation and get the cross-validation scores using Random Forest
        scores = cross_val_score(rf_classif, X_new, y, cv=kf, scoring='accuracy')

        # Print the cross-validation scores
        print("Cross-Validation Scores:", scores)

        # Calculate and print the mean and standard deviation of the scores
        print(f"Mean Accuracy: {round(scores.mean() * 100, 3)}%")
        print(f"Standard Deviation: {round(scores.std() * 100, 3)}%")

        results_rf[feature_count][f"{k}-fold-CV"]["mean-accuracy"] = round(scores.mean() * 100, 3)
        results_rf[feature_count][f"{k}-fold-CV"]["standard-deviation"] = round(scores.std() * 100, 3)
        results_rf[feature_count]["acc-std"] = f"{results_rf[feature_count][f'{k}-fold-CV']['mean-accuracy']}% ± {results_rf[feature_count][f'{k}-fold-CV']['standard-deviation']}%"

        print("")
    print("")
# Out:
# RESULTS FOR 5 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 5)
# Accuracy of the 5 features Random Forest model is: 89.655%
# Sensitivity for 5 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 5 features Random Forest model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 5 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.92857143 1.         0.96428571 0.96428571]
# Mean Accuracy: 95.074%
# Standard Deviation: 3.527%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 0.94444444 1.         1.         0.94117647
#  0.94117647 1.        ]
# Mean Accuracy: 96.446%
# Standard Deviation: 2.756%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.92857143 0.92857143 1.         1.         1.
#  1.         0.92857143 0.92857143 1.        ]
# Mean Accuracy: 96.476%
# Standard Deviation: 3.526%
#
#
# RESULTS FOR 15 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 15)
# Accuracy of the 15 features Random Forest model is: 89.655%
# Sensitivity for 15 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 15 features Random Forest model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 15 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         0.96428571 0.96428571 0.96428571]
# Mean Accuracy: 95.788%
# Standard Deviation: 3.364%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         1.         0.94444444 1.
#  0.94117647 0.88235294]
# Mean Accuracy: 95.016%
# Standard Deviation: 4.465%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         0.92857143
#  1.         0.92857143 1.         0.92857143]
# Mean Accuracy: 95.048%
# Standard Deviation: 4.554%
#
#
# RESULTS FOR 25 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 25)
# Accuracy of the 25 features Random Forest model is: 89.655%
# Sensitivity for 25 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 25 features Random Forest model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 25 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         0.96428571 0.96428571 1.        ]
# Mean Accuracy: 96.502%
# Standard Deviation: 3.778%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         1.         0.94444444 1.
#  1.         0.88235294]
# Mean Accuracy: 95.752%
# Standard Deviation: 4.733%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         1.         0.92857143
#  1.         0.85714286 1.         0.92857143]
# Mean Accuracy: 95.048%
# Standard Deviation: 5.562%
#
#
# RESULTS FOR 35 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 35)
# Accuracy of the 35 features Random Forest model is: 89.655%
# Sensitivity for 35 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 35 features Random Forest model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 35 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         0.96428571 0.92857143 0.96428571]
# Mean Accuracy: 95.074%
# Standard Deviation: 3.527%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         1.         0.94444444 0.94117647
#  0.94117647 0.88235294]
# Mean Accuracy: 94.281%
# Standard Deviation: 4.049%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         1.         0.92857143
#  1.         0.85714286 1.         0.85714286]
# Mean Accuracy: 94.333%
# Standard Deviation: 6.218%
#
#
# RESULTS FOR 45 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 45)
# Accuracy of the 45 features Random Forest model is: 89.655%
# Sensitivity for 45 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 45 features Random Forest model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 45 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         0.96428571 0.92857143 0.92857143]
# Mean Accuracy: 94.36%
# Standard Deviation: 3.542%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         1.         1.         0.88235294
#  0.94117647 0.88235294]
# Mean Accuracy: 94.24%
# Standard Deviation: 5.004%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         1.         0.92857143
#  1.         0.85714286 1.         0.85714286]
# Mean Accuracy: 94.333%
# Standard Deviation: 6.218%
#
#
# RESULTS FOR 55 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 55)
# Accuracy of the 55 features Random Forest model is: 89.655%
# Sensitivity for 55 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 55 features Random Forest model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 55 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         0.96428571 0.89285714 0.96428571]
# Mean Accuracy: 94.36%
# Standard Deviation: 4.201%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 1.         0.94444444 0.88235294
#  0.94117647 0.88235294]
# Mean Accuracy: 92.851%
# Standard Deviation: 3.851%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         1.         1.
#  1.         0.78571429 1.         0.85714286]
# Mean Accuracy: 94.333%
# Standard Deviation: 7.686%
#
#
# RESULTS FOR 65 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 65)
# Accuracy of the 65 features Random Forest model is: 89.655%
# Sensitivity for 65 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 65 features Random Forest model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 65 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         0.96428571 0.92857143 0.92857143]
# Mean Accuracy: 94.36%
# Standard Deviation: 3.542%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         1.         0.94444444 0.88235294
#  1.         0.88235294]
# Mean Accuracy: 94.281%
# Standard Deviation: 5.004%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         0.92857143
#  1.         0.85714286 1.         0.85714286]
# Mean Accuracy: 93.619%
# Standard Deviation: 5.929%

# %%
# Extract the data for plotting
x_values = results_rf.keys()
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results_rf.values()]
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results_rf.values()]

# Create a single plot for mean accuracy and standard deviation
plt.figure(figsize=(12, 8))

plt.errorbar(x_values, mean_5_fold, yerr=std_5_fold, marker='o', label='5-fold', linestyle='-', capsize=5)

plt.xlabel('Number of features')
plt.ylabel('Mean Accuracy')
plt.title('Variation of Mean Accuracy with different number of features for 5-fold Cross Validation')
plt.legend()
plt.grid(True)

plt.show()

# %%
results_rf
# Out:
# {5: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.074, 'standard-deviation': 3.527},
#   'acc-std': '96.476% ± 3.526%',
#   '8-fold-CV': {'mean-accuracy': 96.446, 'standard-deviation': 2.756},
#   '10-fold-CV': {'mean-accuracy': 96.476, 'standard-deviation': 3.526}},
#  15: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.788, 'standard-deviation': 3.364},
#   'acc-std': '95.048% ± 4.554%',
#   '8-fold-CV': {'mean-accuracy': 95.016, 'standard-deviation': 4.465},
#   '10-fold-CV': {'mean-accuracy': 95.048, 'standard-deviation': 4.554}},
#  25: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 96.502, 'standard-deviation': 3.778},
#   'acc-std': '95.048% ± 5.562%',
#   '8-fold-CV': {'mean-accuracy': 95.752, 'standard-deviation': 4.733},
#   '10-fold-CV': {'mean-accuracy': 95.048, 'standard-deviation': 5.562}},
#  35: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.074, 'standard-deviation': 3.527},
#   'acc-std': '94.333% ± 6.218%',
#   '8-fold-CV': {'mean-accuracy': 94.281, 'standard-deviation': 4.049},
#   '10-fold-CV': {'mean-accuracy': 94.333, 'standard-deviation': 6.218}},
#  45: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.36, 'standard-deviation': 3.542},
#   'acc-std': '94.333% ± 6.218%',
#   '8-fold-CV': {'mean-accuracy': 94.24, 'standard-deviation': 5.004},
#   '10-fold-CV': {'mean-accuracy': 94.333, 'standard-deviation': 6.218}},
#  55: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.36, 'standard-deviation': 4.201},
#   'acc-std': '94.333% ± 7.686%',
#   '8-fold-CV': {'mean-accuracy': 92.851, 'standard-deviation': 3.851},
#   '10-fold-CV': {'mean-accuracy': 94.333, 'standard-deviation': 7.686}},
#  65: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.36, 'standard-deviation': 3.542},
#   'acc-std': '93.619% ± 5.929%',
#   '8-fold-CV': {'mean-accuracy': 94.281, 'standard-deviation': 5.004},
#   '10-fold-CV': {'mean-accuracy': 93.619, 'standard-deviation': 5.929}}}

# %%
# XGBoost
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

no_of_features = [5, 15, 25, 35, 45, 55, 65]
cross_val_k = [5, 8, 10]
results_xgb = {}

for feature_count in no_of_features:
    print(f"RESULTS FOR {feature_count} FEATURES")
    print("--------------------------------------------------")

    results_xgb[feature_count] = {}

    # Feature selection using mutual information
    mi_classif = SelectKBest(score_func=mutual_info_classif, k=feature_count)

    # Apply the mutual information selector on the dataset
    X_MI_selected = mi_classif.fit_transform(X_top, y)

    # Get the selected features
    selected_features = mi_classif.get_support()

    # Feature names of selected features
    selected_feature_names = X_top.columns[selected_features]

    X_new = X_top[selected_feature_names]

    print("Shape of X_new: ", X_new.shape)

    # Convert every column to float
    X_new = X_new.astype(float)

    # Divide the dataset to train 0.8 and test 0.2
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Create XGBoost classifier and fit the data
    xgb_classif = XGBClassifier()
    xgb_classif.fit(X_train, y_train)

    # Test the model on the test set
    y_pred = xgb_classif.predict(X_test)

    # Check the accuracy of the model
    accuracy_xgb_model = accuracy_score(y_test, y_pred)
    print(f"Accuracy of the {feature_count} features XGBoost model is: {round(accuracy_xgb_model * 100, 3)}%")

    results_xgb[feature_count]["accuracy"] = round(accuracy_xgb_model * 100, 3)

    # Confusion matrix of the model
    confusion_matrix_xgb_model = confusion_matrix(y_test, y_pred)

    TP_xgb_model = confusion_matrix_xgb_model[1, 1]  # True Positives
    FN_xgb_model = confusion_matrix_xgb_model[1, 0]  # False Negatives

    # Calculate Sensitivity (True Positive Rate or Recall)
    sensitivity_xgb_model = TP_xgb_model / (TP_xgb_model + FN_xgb_model)
    print(f"Sensitivity for {feature_count} features XGBoost model (True Positive Rate): {round(sensitivity_xgb_model * 100, 3)}%")

    results_xgb[feature_count]["sensitivity"] = round(sensitivity_xgb_model * 100, 3)

    # Print the confusion matrix
    print(f"Confusion matrix of the {feature_count} features XGBoost model is: ")
    print(confusion_matrix_xgb_model)

    # Classification report for the model
    report_xgb_model = classification_report(y_test, y_pred)
    print(f"Classification report of {feature_count} features XGBoost model is: ")
    print(report_xgb_model)

    # Now let's do the cross-validation
    for k in cross_val_k:
        print(f"{k}-fold Cross Validation")

        results_xgb[feature_count][f"{k}-fold-CV"] = {}

        # Create a cross-validation object (K-Fold cross-validator)
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Perform k-fold cross-validation and get the cross-validation scores using XGBoost
        scores = cross_val_score(xgb_classif, X_new, y, cv=kf, scoring='accuracy')

        # Print the cross-validation scores
        print("Cross-Validation Scores:", scores)

        # Calculate and print the mean and standard deviation of the scores
        print(f"Mean Accuracy: {round(scores.mean() * 100, 3)}%")
        print(f"Standard Deviation: {round(scores.std() * 100, 3)}%")

        results_xgb[feature_count][f"{k}-fold-CV"]["mean-accuracy"] = round(scores.mean() * 100, 3)
        results_xgb[feature_count][f"{k}-fold-CV"]["standard-deviation"] = round(scores.std() * 100, 3)
        results_xgb[feature_count]["acc-std"] = f"{results_xgb[feature_count][f'{k}-fold-CV']['mean-accuracy']}% ± {results_xgb[feature_count][f'{k}-fold-CV']['standard-deviation']}%"

        print("")
    print("")
# Out:
# RESULTS FOR 5 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 5)
# Accuracy of the 5 features XGBoost model is: 89.655%
# Sensitivity for 5 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 5 features XGBoost model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 5 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.89285714 0.96428571 1.         0.96428571]
# Mean Accuracy: 94.36%
# Standard Deviation: 4.201%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.94444444 0.83333333 0.94444444 1.         1.
#  0.94117647 1.        ]
# Mean Accuracy: 95.792%
# Standard Deviation: 5.391%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.92857143 0.92857143 0.92857143 0.92857143 1.
#  1.         1.         0.92857143 1.        ]
# Mean Accuracy: 96.429%
# Standard Deviation: 3.571%
#
#
# RESULTS FOR 15 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 15)
# Accuracy of the 15 features XGBoost model is: 89.655%
# Sensitivity for 15 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 15 features XGBoost model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 15 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 0.96428571 0.92857143 0.96428571]
# Mean Accuracy: 94.36%
# Standard Deviation: 2.729%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 0.94444444 1.         0.94117647
#  0.94117647 0.94117647]
# Mean Accuracy: 94.322%
# Standard Deviation: 2.782%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 0.92857143 1.
#  1.         0.85714286 1.         0.92857143]
# Mean Accuracy: 94.333%
# Standard Deviation: 5.334%
#
#
# RESULTS FOR 25 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 25)
# Accuracy of the 25 features XGBoost model is: 89.655%
# Sensitivity for 25 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 25 features XGBoost model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 25 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         1.         0.92857143 0.96428571]
# Mean Accuracy: 95.788%
# Standard Deviation: 4.052%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         1.         1.         0.94117647
#  1.         0.94117647]
# Mean Accuracy: 96.446%
# Standard Deviation: 3.913%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         1.         1.
#  1.         0.85714286 1.         0.92857143]
# Mean Accuracy: 95.762%
# Standard Deviation: 5.692%
#
#
# RESULTS FOR 35 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 35)
# Accuracy of the 35 features XGBoost model is: 89.655%
# Sensitivity for 35 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 35 features XGBoost model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 35 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         0.96428571 0.92857143 0.96428571]
# Mean Accuracy: 95.074%
# Standard Deviation: 3.527%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         1.         1.         0.94117647
#  1.         0.94117647]
# Mean Accuracy: 96.446%
# Standard Deviation: 3.913%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         1.         1.
#  1.         0.85714286 1.         0.85714286]
# Mean Accuracy: 95.048%
# Standard Deviation: 6.414%
#
#
# RESULTS FOR 45 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 45)
# Accuracy of the 45 features XGBoost model is: 89.655%
# Sensitivity for 45 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 45 features XGBoost model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 45 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         1.         0.96428571 0.96428571]
# Mean Accuracy: 96.502%
# Standard Deviation: 3.778%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         0.94444444 1.         0.94117647
#  1.         0.94117647]
# Mean Accuracy: 95.752%
# Standard Deviation: 3.708%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         0.92857143 1.
#  1.         0.92857143 1.         0.92857143]
# Mean Accuracy: 95.762%
# Standard Deviation: 4.711%
#
#
# RESULTS FOR 55 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 55)
# Accuracy of the 55 features XGBoost model is: 89.655%
# Sensitivity for 55 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 55 features XGBoost model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 55 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         0.96428571 0.96428571 0.96428571]
# Mean Accuracy: 95.788%
# Standard Deviation: 3.364%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         0.94444444 1.         0.94117647
#  1.         0.94117647]
# Mean Accuracy: 95.752%
# Standard Deviation: 3.708%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         0.92857143 1.
#  1.         0.92857143 1.         0.92857143]
# Mean Accuracy: 95.762%
# Standard Deviation: 4.711%
#
#
# RESULTS FOR 65 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 65)
# Accuracy of the 65 features XGBoost model is: 89.655%
# Sensitivity for 65 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 65 features XGBoost model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 65 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         0.92857143 0.96428571 0.96428571]
# Mean Accuracy: 95.074%
# Standard Deviation: 3.527%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         0.94444444 1.         0.94117647
#  1.         0.94117647]
# Mean Accuracy: 95.752%
# Standard Deviation: 3.708%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         0.92857143 1.
#  1.         0.85714286 1.         0.92857143]
# Mean Accuracy: 95.048%
# Standard Deviation: 5.562%

# %%
# Extract the data for plotting
x_values = results_xgb.keys()
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results_xgb.values()]
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results_xgb.values()]

# Create a single plot for mean accuracy and standard deviation
plt.figure(figsize=(12, 8))

plt.errorbar(x_values, mean_5_fold, yerr=std_5_fold, marker='o', label='5-fold', linestyle='-', capsize=5)

plt.xlabel('Number of features')
plt.ylabel('Mean Accuracy')
plt.title('Variation of Mean Accuracy with different number of features for 5-fold Cross Validation')
plt.legend()
plt.grid(True)

plt.show()

# %%
results_xgb
# Out:
# {5: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.36, 'standard-deviation': 4.201},
#   'acc-std': '96.429% ± 3.571%',
#   '8-fold-CV': {'mean-accuracy': 95.792, 'standard-deviation': 5.391},
#   '10-fold-CV': {'mean-accuracy': 96.429, 'standard-deviation': 3.571}},
#  15: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.36, 'standard-deviation': 2.729},
#   'acc-std': '94.333% ± 5.334%',
#   '8-fold-CV': {'mean-accuracy': 94.322, 'standard-deviation': 2.782},
#   '10-fold-CV': {'mean-accuracy': 94.333, 'standard-deviation': 5.334}},
#  25: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.788, 'standard-deviation': 4.052},
#   'acc-std': '95.762% ± 5.692%',
#   '8-fold-CV': {'mean-accuracy': 96.446, 'standard-deviation': 3.913},
#   '10-fold-CV': {'mean-accuracy': 95.762, 'standard-deviation': 5.692}},
#  35: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.074, 'standard-deviation': 3.527},
#   'acc-std': '95.048% ± 6.414%',
#   '8-fold-CV': {'mean-accuracy': 96.446, 'standard-deviation': 3.913},
#   '10-fold-CV': {'mean-accuracy': 95.048, 'standard-deviation': 6.414}},
#  45: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 96.502, 'standard-deviation': 3.778},
#   'acc-std': '95.762% ± 4.711%',
#   '8-fold-CV': {'mean-accuracy': 95.752, 'standard-deviation': 3.708},
#   '10-fold-CV': {'mean-accuracy': 95.762, 'standard-deviation': 4.711}},
#  55: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.788, 'standard-deviation': 3.364},
#   'acc-std': '95.762% ± 4.711%',
#   '8-fold-CV': {'mean-accuracy': 95.752, 'standard-deviation': 3.708},
#   '10-fold-CV': {'mean-accuracy': 95.762, 'standard-deviation': 4.711}},
#  65: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.074, 'standard-deviation': 3.527},
#   'acc-std': '95.048% ± 5.562%',
#   '8-fold-CV': {'mean-accuracy': 95.752, 'standard-deviation': 3.708},
#   '10-fold-CV': {'mean-accuracy': 95.048, 'standard-deviation': 5.562}}}

# %%
# Logistic Regression
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

no_of_features = [5, 15, 25, 35, 45, 55, 65]
cross_val_k = [5, 8, 10]
results_lr = {}

for feature_count in no_of_features:
    print(f"RESULTS FOR {feature_count} FEATURES")
    print("--------------------------------------------------")

    results_lr[feature_count] = {}

    # Feature selection using mutual information
    mi_classif = SelectKBest(score_func=mutual_info_classif, k=feature_count)

    # Apply the mutual information selector on the dataset
    X_MI_selected = mi_classif.fit_transform(X_top, y)

    # Get the selected features
    selected_features = mi_classif.get_support()

    # Feature names of selected features
    selected_feature_names = X_top.columns[selected_features]

    X_new = X_top[selected_feature_names]

    print("Shape of X_new: ", X_new.shape)

    # Divide the dataset to train 0.8 and test 0.2
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Create Logistic Regression classifier and fit the data
    lr_classif = LogisticRegression()
    lr_classif.fit(X_train, y_train)

    # Test the model on the test set
    y_pred = lr_classif.predict(X_test)

    # Check the accuracy of the model
    accuracy_lr_model = accuracy_score(y_test, y_pred)
    print(f"Accuracy of the {feature_count} features Logistic Regression model is: {round(accuracy_lr_model * 100, 3)}%")

    results_lr[feature_count]["accuracy"] = round(accuracy_lr_model * 100, 3)

    # Confusion matrix of the model
    confusion_matrix_lr_model = confusion_matrix(y_test, y_pred)

    TP_lr_model = confusion_matrix_lr_model[1, 1]  # True Positives
    FN_lr_model = confusion_matrix_lr_model[1, 0]  # False Negatives

    # Calculate Sensitivity (True Positive Rate or Recall)
    sensitivity_lr_model = TP_lr_model / (TP_lr_model + FN_lr_model)
    print(f"Sensitivity for {feature_count} features Logistic Regression model (True Positive Rate): {round(sensitivity_lr_model * 100, 3)}%")

    results_lr[feature_count]["sensitivity"] = round(sensitivity_lr_model * 100, 3)

    # Print the confusion matrix
    print(f"Confusion matrix of the {feature_count} features Logistic Regression model is: ")
    print(confusion_matrix_lr_model)

    # Classification report for the model
    report_lr_model = classification_report(y_test, y_pred)
    print(f"Classification report of {feature_count} features Logistic Regression model is: ")
    print(report_lr_model)

    # Now let's do the cross-validation
    for k in cross_val_k:
        print(f"{k}-fold Cross Validation")

        results_lr[feature_count][f"{k}-fold-CV"] = {}

        # Create a cross-validation object (K-Fold cross-validator)
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Perform k-fold cross-validation and get the cross-validation scores using Logistic Regression
        scores = cross_val_score(lr_classif, X_new, y, cv=kf, scoring='accuracy')

        # Print the cross-validation scores
        print("Cross-Validation Scores:", scores)

        # Calculate and print the mean and standard deviation of the scores
        print(f"Mean Accuracy: {round(scores.mean() * 100, 3)}%")
        print(f"Standard Deviation: {round(scores.std() * 100, 3)}%")

        results_lr[feature_count][f"{k}-fold-CV"]["mean-accuracy"] = round(scores.mean() * 100, 3)
        results_lr[feature_count][f"{k}-fold-CV"]["standard-deviation"] = round(scores.std() * 100, 3)
        results_lr[feature_count]["acc-std"] = f"{results_lr[feature_count][f'{k}-fold-CV']['mean-accuracy']}% ± {results_lr[feature_count][f'{k}-fold-CV']['standard-deviation']}%"

        print("")
    print("")
# Out:
# RESULTS FOR 5 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 5)
# Accuracy of the 5 features Logistic Regression model is: 89.655%
# Sensitivity for 5 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 5 features Logistic Regression model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 5 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 0.92857143 0.92857143 0.92857143]
# Mean Accuracy: 92.931%
# Standard Deviation: 2.144%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 0.94444444 0.94444444 0.94117647
#  0.94117647 0.88235294]
# Mean Accuracy: 92.892%
# Standard Deviation: 2.509%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 0.92857143 0.92857143
#  1.         0.85714286 1.         0.85714286]
# Mean Accuracy: 92.905%
# Standard Deviation: 5.535%
#
#
# RESULTS FOR 15 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 15)
# Accuracy of the 15 features Logistic Regression model is: 89.655%
# Sensitivity for 15 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 15 features Logistic Regression model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 15 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         0.96428571 0.96428571 0.96428571]
# Mean Accuracy: 95.788%
# Standard Deviation: 3.364%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 1.         0.94444444 1.
#  0.94117647 0.94117647]
# Mean Accuracy: 95.057%
# Standard Deviation: 3.35%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         0.92857143
#  1.         0.92857143 1.         0.92857143]
# Mean Accuracy: 95.048%
# Standard Deviation: 4.554%
#
#
# RESULTS FOR 25 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 25)
# Accuracy of the 25 features Logistic Regression model is: 89.655%
# Sensitivity for 25 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 25 features Logistic Regression model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 25 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         1.         0.92857143 0.96428571]
# Mean Accuracy: 95.788%
# Standard Deviation: 4.052%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 1.         1.         1.         1.
#  0.94117647 0.94117647]
# Mean Accuracy: 97.141%
# Standard Deviation: 3.988%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.85714286 1.         1.         1.         1.
#  1.         0.85714286 1.         0.92857143]
# Mean Accuracy: 96.429%
# Standard Deviation: 5.759%
#
#
# RESULTS FOR 35 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 35)
# Accuracy of the 35 features Logistic Regression model is: 89.655%
# Sensitivity for 35 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 35 features Logistic Regression model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 35 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         1.         0.92857143 0.96428571]
# Mean Accuracy: 95.788%
# Standard Deviation: 4.052%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         1.         1.         0.94117647
#  0.94117647 0.94117647]
# Mean Accuracy: 95.711%
# Standard Deviation: 3.724%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         1.         1.
#  1.         0.85714286 1.         0.92857143]
# Mean Accuracy: 95.762%
# Standard Deviation: 5.692%
#
#
# RESULTS FOR 45 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 45)
# Accuracy of the 45 features Logistic Regression model is: 89.655%
# Sensitivity for 45 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 45 features Logistic Regression model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 45 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 1.         0.92857143 0.96428571]
# Mean Accuracy: 95.074%
# Standard Deviation: 3.527%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 1.         1.         0.88235294
#  0.94117647 0.94117647]
# Mean Accuracy: 94.281%
# Standard Deviation: 4.049%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         1.
#  1.         0.85714286 1.         0.92857143]
# Mean Accuracy: 95.048%
# Standard Deviation: 5.562%
#
#
# RESULTS FOR 55 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 55)
# Accuracy of the 55 features Logistic Regression model is: 89.655%
# Sensitivity for 55 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 55 features Logistic Regression model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 55 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 1.         0.92857143 0.96428571]
# Mean Accuracy: 95.074%
# Standard Deviation: 3.527%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 1.         1.         0.88235294
#  0.94117647 0.94117647]
# Mean Accuracy: 94.281%
# Standard Deviation: 4.049%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         1.
#  1.         0.85714286 1.         0.92857143]
# Mean Accuracy: 95.048%
# Standard Deviation: 5.562%
#
#
# RESULTS FOR 65 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 65)
# Accuracy of the 65 features Logistic Regression model is: 89.655%
# Sensitivity for 65 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 65 features Logistic Regression model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 65 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.96428571 1.         0.92857143 0.96428571]
# Mean Accuracy: 95.074%
# Standard Deviation: 3.527%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 1.         1.         0.94117647
#  0.94117647 0.94117647]
# Mean Accuracy: 95.016%
# Standard Deviation: 3.36%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         1.
#  1.         0.85714286 1.         0.92857143]
# Mean Accuracy: 95.048%
# Standard Deviation: 5.562%

# %%
# Extract the data for plotting
x_values = results_lr.keys()
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results_lr.values()]
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results_lr.values()]

# Create a single plot for mean accuracy and standard deviation
plt.figure(figsize=(12, 8))

plt.errorbar(x_values, mean_5_fold, yerr=std_5_fold, marker='o', label='5-fold', linestyle='-', capsize=5)

plt.xlabel('Number of features')
plt.ylabel('Mean Accuracy')
plt.title('Variation of Mean Accuracy with different number of features for 5-fold Cross Validation')
plt.legend()
plt.grid(True)

plt.show()

# %%
results_lr
# Out:
# {5: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 92.931, 'standard-deviation': 2.144},
#   'acc-std': '92.905% ± 5.535%',
#   '8-fold-CV': {'mean-accuracy': 92.892, 'standard-deviation': 2.509},
#   '10-fold-CV': {'mean-accuracy': 92.905, 'standard-deviation': 5.535}},
#  15: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.788, 'standard-deviation': 3.364},
#   'acc-std': '95.048% ± 4.554%',
#   '8-fold-CV': {'mean-accuracy': 95.057, 'standard-deviation': 3.35},
#   '10-fold-CV': {'mean-accuracy': 95.048, 'standard-deviation': 4.554}},
#  25: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.788, 'standard-deviation': 4.052},
#   'acc-std': '96.429% ± 5.759%',
#   '8-fold-CV': {'mean-accuracy': 97.141, 'standard-deviation': 3.988},
#   '10-fold-CV': {'mean-accuracy': 96.429, 'standard-deviation': 5.759}},
#  35: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.788, 'standard-deviation': 4.052},
#   'acc-std': '95.762% ± 5.692%',
#   '8-fold-CV': {'mean-accuracy': 95.711, 'standard-deviation': 3.724},
#   '10-fold-CV': {'mean-accuracy': 95.762, 'standard-deviation': 5.692}},
#  45: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.074, 'standard-deviation': 3.527},
#   'acc-std': '95.048% ± 5.562%',
#   '8-fold-CV': {'mean-accuracy': 94.281, 'standard-deviation': 4.049},
#   '10-fold-CV': {'mean-accuracy': 95.048, 'standard-deviation': 5.562}},
#  55: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.074, 'standard-deviation': 3.527},
#   'acc-std': '95.048% ± 5.562%',
#   '8-fold-CV': {'mean-accuracy': 94.281, 'standard-deviation': 4.049},
#   '10-fold-CV': {'mean-accuracy': 95.048, 'standard-deviation': 5.562}},
#  65: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.074, 'standard-deviation': 3.527},
#   'acc-std': '95.048% ± 5.562%',
#   '8-fold-CV': {'mean-accuracy': 95.016, 'standard-deviation': 3.36},
#   '10-fold-CV': {'mean-accuracy': 95.048, 'standard-deviation': 5.562}}}

# %%
# Decision Tree
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

no_of_features = [5, 15, 25, 35, 45, 55, 65]
cross_val_k = [5, 8, 10]
results_dt = {}

for feature_count in no_of_features:
    print(f"RESULTS FOR {feature_count} FEATURES")
    print("--------------------------------------------------")

    results_dt[feature_count] = {}

    # Feature selection using mutual information
    mi_classif = SelectKBest(score_func=mutual_info_classif, k=feature_count)

    # Apply the mutual information selector on the dataset
    X_MI_selected = mi_classif.fit_transform(X_top, y)

    # Get the selected features
    selected_features = mi_classif.get_support()

    # Feature names of selected features
    selected_feature_names = X_top.columns[selected_features]

    X_new = X_top[selected_feature_names]

    print("Shape of X_new: ", X_new.shape)

    # Divide the dataset to train 0.8 and test 0.2
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Create Decision Tree classifier and fit the data
    dt_classif = DecisionTreeClassifier()
    dt_classif.fit(X_train, y_train)

    # Test the model on the test set
    y_pred = dt_classif.predict(X_test)

    # Check the accuracy of the model
    accuracy_dt_model = accuracy_score(y_test, y_pred)
    print(f"Accuracy of the {feature_count} features Decision Tree model is: {round(accuracy_dt_model * 100, 3)}%")

    results_dt[feature_count]["accuracy"] = round(accuracy_dt_model * 100, 3)

    # Confusion matrix of the model
    confusion_matrix_dt_model = confusion_matrix(y_test, y_pred)

    TP_dt_model = confusion_matrix_dt_model[1, 1]  # True Positives
    FN_dt_model = confusion_matrix_dt_model[1, 0]  # False Negatives

    # Calculate Sensitivity (True Positive Rate or Recall)
    sensitivity_dt_model = TP_dt_model / (TP_dt_model + FN_dt_model)
    print(f"Sensitivity for {feature_count} features Decision Tree model (True Positive Rate): {round(sensitivity_dt_model * 100, 3)}%")

    results_dt[feature_count]["sensitivity"] = round(sensitivity_dt_model * 100, 3)

    # Print the confusion matrix
    print(f"Confusion matrix of the {feature_count} features Decision Tree model is: ")
    print(confusion_matrix_dt_model)

    # Classification report for the model
    report_dt_model = classification_report(y_test, y_pred)
    print(f"Classification report of {feature_count} features Decision Tree model is: ")
    print(report_dt_model)

    # Now let's do the cross-validation
    for k in cross_val_k:
        print(f"{k}-fold Cross Validation")

        results_dt[feature_count][f"{k}-fold-CV"] = {}

        # Create a cross-validation object (K-Fold cross-validator)
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Perform k-fold cross-validation and get the cross-validation scores using Decision Tree
        scores = cross_val_score(dt_classif, X_new, y, cv=kf, scoring='accuracy')

        # Print the cross-validation scores
        print("Cross-Validation Scores:", scores)

        # Calculate and print the mean and standard deviation of the scores
        print(f"Mean Accuracy: {round(scores.mean() * 100, 3)}%")
        print(f"Standard Deviation: {round(scores.std() * 100, 3)}%")

        results_dt[feature_count][f"{k}-fold-CV"]["mean-accuracy"] = round(scores.mean() * 100, 3)
        results_dt[feature_count][f"{k}-fold-CV"]["standard-deviation"] = round(scores.std() * 100, 3)
        results_dt[feature_count]["acc-std"] = f"{results_dt[feature_count]['5-fold-CV']['mean-accuracy']}% ± {results_dt[feature_count]['5-fold-CV']['standard-deviation']}%"

        print("")
    print("")
# Out:
# RESULTS FOR 5 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 5)
# Accuracy of the 5 features Decision Tree model is: 89.655%
# Sensitivity for 5 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 5 features Decision Tree model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 5 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.89285714 0.96428571 1.         0.96428571]
# Mean Accuracy: 94.36%
# Standard Deviation: 4.201%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.94444444 0.83333333 0.94444444 1.         1.
#  0.94117647 1.        ]
# Mean Accuracy: 95.792%
# Standard Deviation: 5.391%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.92857143 0.92857143 0.92857143 0.92857143 1.
#  0.92857143 1.         0.92857143 1.        ]
# Mean Accuracy: 95.714%
# Standard Deviation: 3.499%
#
#
# RESULTS FOR 15 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 15)
# Accuracy of the 15 features Decision Tree model is: 89.655%
# Sensitivity for 15 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 15 features Decision Tree model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 15 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.92857143 0.92857143 0.92857143 0.92857143]
# Mean Accuracy: 92.217%
# Standard Deviation: 1.281%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.88888889 1.         1.         0.88235294
#  1.         0.94117647]
# Mean Accuracy: 94.322%
# Standard Deviation: 4.91%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 0.92857143 1.         1.         0.92857143
#  1.         0.85714286 1.         1.        ]
# Mean Accuracy: 95.048%
# Standard Deviation: 5.562%
#
#
# RESULTS FOR 25 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 25)
# Accuracy of the 25 features Decision Tree model is: 89.655%
# Sensitivity for 25 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 25 features Decision Tree model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 25 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.92857143 0.96428571 0.96428571 0.96428571]
# Mean Accuracy: 94.36%
# Standard Deviation: 2.729%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 0.88888889 1.         0.88888889 0.94117647
#  0.94117647 1.        ]
# Mean Accuracy: 94.363%
# Standard Deviation: 3.931%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         0.92857143 1.         0.85714286
#  1.         0.85714286 0.92857143 0.92857143]
# Mean Accuracy: 92.905%
# Standard Deviation: 5.535%
#
#
# RESULTS FOR 35 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 35)
# Accuracy of the 35 features Decision Tree model is: 89.655%
# Sensitivity for 35 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 35 features Decision Tree model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 35 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.92857143 0.96428571 0.89285714 0.96428571]
# Mean Accuracy: 92.931%
# Standard Deviation: 3.114%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 0.88888889 1.         0.94444444 0.94117647
#  0.94117647 1.        ]
# Mean Accuracy: 95.057%
# Standard Deviation: 3.35%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.92857143 1.         0.92857143 1.         0.92857143
#  1.         0.92857143 0.92857143 1.        ]
# Mean Accuracy: 95.762%
# Standard Deviation: 3.463%
#
#
# RESULTS FOR 45 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 45)
# Accuracy of the 45 features Decision Tree model is: 89.655%
# Sensitivity for 45 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 45 features Decision Tree model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 45 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.92857143 0.96428571 0.85714286 0.92857143]
# Mean Accuracy: 91.502%
# Standard Deviation: 3.601%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 0.88888889 0.94444444 0.94444444 0.94117647
#  0.94117647 0.88235294]
# Mean Accuracy: 92.892%
# Standard Deviation: 2.509%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.92857143 1.         0.92857143 0.92857143 0.92857143
#  1.         0.85714286 0.92857143 0.92857143]
# Mean Accuracy: 93.619%
# Standard Deviation: 3.84%
#
#
# RESULTS FOR 55 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 55)
# Accuracy of the 55 features Decision Tree model is: 89.655%
# Sensitivity for 55 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 55 features Decision Tree model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 55 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 0.92857143 0.92857143 0.85714286 0.89285714]
# Mean Accuracy: 90.074%
# Standard Deviation: 2.657%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 0.88888889 0.94444444 0.94444444 0.94117647
#  0.94117647 0.94117647]
# Mean Accuracy: 93.627%
# Standard Deviation: 1.797%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         1.         0.92857143
#  1.         0.92857143 0.92857143 0.92857143]
# Mean Accuracy: 95.048%
# Standard Deviation: 4.554%
#
#
# RESULTS FOR 65 FEATURES
# --------------------------------------------------
# Shape of X_new:  (141, 65)
# Accuracy of the 65 features Decision Tree model is: 89.655%
# Sensitivity for 65 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 65 features Decision Tree model is:
# [[11  3]
#  [ 0 15]]
# Classification report of 65 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.82758621 0.92857143 0.96428571 0.96428571 0.92857143]
# Mean Accuracy: 92.266%
# Standard Deviation: 5.015%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 0.88888889 0.94444444 0.94444444 0.94117647
#  0.94117647 1.        ]
# Mean Accuracy: 94.363%
# Standard Deviation: 2.781%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.92857143 1.         1.         0.92857143 0.92857143
#  1.         0.78571429 0.92857143 0.92857143]
# Mean Accuracy: 93.619%
# Standard Deviation: 5.929%

# %%
# Extract the data for plotting
x_values = results_dt.keys()
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results_dt.values()]
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results_dt.values()]

# Create a single plot for mean accuracy and standard deviation
plt.figure(figsize=(12, 8))

plt.errorbar(x_values, mean_5_fold, yerr=std_5_fold, marker='o', label='5-fold', linestyle='-', capsize=5)

plt.xlabel('Number of features')
plt.ylabel('Mean Accuracy')
plt.title('Variation of Mean Accuracy with different number of features for 5-fold Cross Validation')
plt.legend()
plt.grid(True)

plt.show()

# %%
results_dt
# Out:
# {5: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.36, 'standard-deviation': 4.201},
#   'acc-std': '94.36% ± 4.201%',
#   '8-fold-CV': {'mean-accuracy': 95.792, 'standard-deviation': 5.391},
#   '10-fold-CV': {'mean-accuracy': 95.714, 'standard-deviation': 3.499}},
#  15: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 92.217, 'standard-deviation': 1.281},
#   'acc-std': '92.217% ± 1.281%',
#   '8-fold-CV': {'mean-accuracy': 94.322, 'standard-deviation': 4.91},
#   '10-fold-CV': {'mean-accuracy': 95.048, 'standard-deviation': 5.562}},
#  25: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.36, 'standard-deviation': 2.729},
#   'acc-std': '94.36% ± 2.729%',
#   '8-fold-CV': {'mean-accuracy': 94.363, 'standard-deviation': 3.931},
#   '10-fold-CV': {'mean-accuracy': 92.905, 'standard-deviation': 5.535}},
#  35: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 92.931, 'standard-deviation': 3.114},
#   'acc-std': '92.931% ± 3.114%',
#   '8-fold-CV': {'mean-accuracy': 95.057, 'standard-deviation': 3.35},
#   '10-fold-CV': {'mean-accuracy': 95.762, 'standard-deviation': 3.463}},
#  45: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 91.502, 'standard-deviation': 3.601},
#   'acc-std': '91.502% ± 3.601%',
#   '8-fold-CV': {'mean-accuracy': 92.892, 'standard-deviation': 2.509},
#   '10-fold-CV': {'mean-accuracy': 93.619, 'standard-deviation': 3.84}},
#  55: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 90.074, 'standard-deviation': 2.657},
#   'acc-std': '90.074% ± 2.657%',
#   '8-fold-CV': {'mean-accuracy': 93.627, 'standard-deviation': 1.797},
#   '10-fold-CV': {'mean-accuracy': 95.048, 'standard-deviation': 4.554}},
#  65: {'accuracy': 89.655,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 92.266, 'standard-deviation': 5.015},
#   'acc-std': '92.266% ± 5.015%',
#   '8-fold-CV': {'mean-accuracy': 94.363, 'standard-deviation': 2.781},
#   '10-fold-CV': {'mean-accuracy': 93.619, 'standard-deviation': 5.929}}}

# %%
# plotting all the results for microarray data

# %%
import matplotlib.pyplot as plt

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Define colors for each algorithm
colors = ['b', 'g', 'r', 'c', 'm']  # You can add more colors if needed

# Data for different algorithms
algorithms = ['SVM', 'Random Forest', 'XGBoost', 'Logistic Regression', 'Decision Tree']
data = [results_svm, results_rf, results_xgb, results_lr, results_dt]

# Plot data for each algorithm
for i, algorithm_data in enumerate(data):
    mean_accuracies = [item['5-fold-CV']['mean-accuracy'] for item in algorithm_data.values()]
    std_devs = [item['5-fold-CV']['standard-deviation'] for item in algorithm_data.values()]

    feature_counts = list(algorithm_data.keys())

    ax.errorbar(
        feature_counts,
        mean_accuracies,
        yerr=std_devs,
        label=algorithms[i],
        marker='o',
        color=colors[i],
    )

# Customize the plot
plt.title("Mean Accuracy vs. Number of Features for Different Algorithms (5-fold CV) for Microarray Data")
plt.xlabel("Number of Features")
plt.ylabel("Mean Accuracy (%)")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and axis with a larger size
fig, ax = plt.subplots(figsize=(12, 8))

# Define colors for each algorithm
colors = ['b', 'g', 'r', 'c', 'm']  # You can add more colors if needed

# Data for different algorithms
algorithms = ['SVM', 'Random Forest', 'XGBoost', 'Logistic Regression', 'Decision Tree']
data = [results_svm, results_rf, results_xgb, results_lr, results_dt]

# Plot data for each algorithm
for i, algorithm_data in enumerate(data):
    mean_accuracies = [item['5-fold-CV']['mean-accuracy'] for item in algorithm_data.values()]

    feature_counts = list(algorithm_data.keys())

    ax.plot(
        feature_counts,
        mean_accuracies,
        label=algorithms[i],
        marker='o',
        color=colors[i],
    )

# Customize the plot
plt.title("Mean Accuracy vs. Number of Features for Different Algorithms (5-fold CV) for Microarray Data")
plt.xlabel("Number of Features")
plt.ylabel("Mean Accuracy (%)")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and axis with a larger size
fig, ax = plt.subplots(figsize=(12, 8))

# Define colors for each algorithm
colors = ['b', 'g', 'r', 'c']

# Data for different algorithms
algorithms = ['SVM', 'Random Forest', 'XGBoost', 'Decision Tree']
data = [results_svm, results_rf, results_xgb, results_dt]

# Plot data for each algorithm
for i, algorithm_data in enumerate(data):
    mean_accuracies = [item['5-fold-CV']['mean-accuracy'] for item in algorithm_data.values()]

    feature_counts = list(algorithm_data.keys())

    ax.plot(
        feature_counts,
        mean_accuracies,
        label=algorithms[i],
        marker='o',
        color=colors[i],
    )

# Customize the plot
plt.title("Mean Accuracy vs. Number of Features for Different Algorithms (5-fold CV) for Microarray Data")
plt.xlabel("Number of Features")
plt.ylabel("Mean Accuracy (%)")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# plot without legend

# %%
import matplotlib.pyplot as plt

# Create a figure and axis with a larger size
fig, ax = plt.subplots(figsize=(12, 8))

# Define colors for each algorithm
colors = ['b', 'g', 'r', 'c']

# Data for different algorithms
algorithms = ['SVM', 'Random Forest', 'XGBoost', 'Decision Tree']
data = [results_svm, results_rf, results_xgb, results_dt]

# Plot data for each algorithm
for i, algorithm_data in enumerate(data):
    mean_accuracies = [item['5-fold-CV']['mean-accuracy'] for item in algorithm_data.values()]

    feature_counts = list(algorithm_data.keys())

    ax.plot(
        feature_counts,
        mean_accuracies,
        label=algorithms[i],
        marker='o',
        color=colors[i],
    )

# Customize the plot
plt.title("Mean Accuracy vs. Number of Features for Different Algorithms (5-fold CV) for Microarray Data")
plt.xlabel("Number of Features")
plt.ylabel("Mean Accuracy (%)")
plt.grid(True)

# Show the plot
plt.show()
