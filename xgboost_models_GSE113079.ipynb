# %% [markdown]
# <a href="https://colab.research.google.com/github/Sachira-Heshan/omic-data-and-machine-learning-in-the-identification-of-coronary-artery-disease/blob/main/xgboost_models_GSE113079.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# building XGBoost models for different number of features choose by Mutual Information in GSE113079

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Research/Datasets/Cleaned/cleaned-dataset-GSE113079.xlsx')

# %%
df.head()
# Out:
#         Unnamed: 0         0         1         2         3         4  \
# 0  GE_BrightCorner  2.157974  1.779174  1.476457  1.635460  1.459245
# 1       DarkCorner -4.972070 -5.079564 -5.055798 -5.048396 -4.759264
# 2        p42318_v4 -5.136246 -5.309609 -4.683745 -5.058544 -5.044792
# 3             p117 -0.908056 -0.279806 -0.814316 -0.403859 -0.239435
# 4           p28737 -5.142836 -5.326123 -4.436602 -5.173800 -5.042362
#
#           5         6         7         8  ...       131       132       133  \
# 0  1.014671  1.548667  1.299535  1.340023  ...  2.105669  3.494671  2.225658
# 1 -5.384547 -4.916507 -4.586820 -4.649654  ... -2.250812 -4.181840 -5.607463
# 2 -5.042380 -5.147751 -4.501071 -4.903667  ... -2.410703 -4.110729 -5.811153
# 3 -0.586996 -0.996306 -0.345914 -0.344358  ... -1.481907 -0.438192 -0.463400
# 4 -5.497274 -5.146853 -4.856003 -4.855644  ... -2.457831 -4.348550 -5.849335
#
#         134       135       136       137       138       139       140
# 0  2.244781  2.954112  4.258145  3.446817  3.219271  3.048190  3.601977
# 1 -5.420901 -6.074095 -5.355829 -5.419512 -5.156093 -5.566904 -5.874120
# 2 -5.480375 -6.194078 -4.979015 -5.532501 -5.517557 -5.754226 -6.050066
# 3 -0.838711 -0.213053 -0.019725 -0.439010 -0.169885 -0.269132 -0.156173
# 4 -5.599132 -6.290147 -4.613355 -5.186365 -5.343323 -5.344678 -5.375709
#
# [5 rows x 142 columns]

# %%
df = df.T

# %%
column_names = df.iloc[0, :]

# %%
df.columns = column_names.tolist()

# %%
df.head()
# Out:
#             GE_BrightCorner  DarkCorner  p42318_v4      p117    p28737  \
# Unnamed: 0  GE_BrightCorner  DarkCorner  p42318_v4      p117    p28737
# 0                  2.157974    -4.97207  -5.136246 -0.908056 -5.142836
# 1                  1.779174   -5.079564  -5.309609 -0.279806 -5.326123
# 2                  1.476457   -5.055798  -4.683745 -0.814316 -4.436602
# 3                   1.63546   -5.048396  -5.058544 -0.403859   -5.1738
#
#               p17314  A_33_P3310047    p22477     p8225     p7095  ...  \
# Unnamed: 0    p17314  A_33_P3310047    p22477     p8225     p7095  ...
# 0           -5.24106       0.996369 -3.309695 -1.096744 -2.356272  ...
# 1          -5.431599       1.049151  -2.68212  -0.88413 -3.141455  ...
# 2          -5.483527       1.107679 -3.565926 -1.364489 -3.778602  ...
# 3          -5.315852       0.922813 -3.687033 -0.971812 -2.599749  ...
#
#               p25976    p23884  A_33_P3800496  A_21_P0006729  A_24_P284523  \
# Unnamed: 0    p25976    p23884  A_33_P3800496  A_21_P0006729  A_24_P284523
# 0           1.746663 -2.448382      -1.259322      -3.232127      3.164295
# 1           0.961229 -2.325115      -0.878489      -2.476317      3.059818
# 2            1.24937 -2.352775      -1.309131      -2.841979      2.908225
# 3           1.431779 -3.219944      -1.369312      -2.633309      2.667611
#
#               p11121    p26746  A_33_P3677559      p361  target_value
# Unnamed: 0    p11121    p26746  A_33_P3677559      p361  target_value
# 0           -0.41048 -3.946267       -3.01915 -1.535002           1.0
# 1          -0.499581 -4.027231       -3.49044 -1.432819           1.0
# 2            0.42274 -4.745641      -3.532535 -1.561514           1.0
# 3            0.74162 -4.544183      -4.334243 -1.536728           1.0
#
# [5 rows x 65524 columns]

# %%
df.drop(index=["Unnamed: 0"], inplace=True)

# %%
df.head()
# Out:
#   GE_BrightCorner DarkCorner p42318_v4      p117    p28737    p17314  \
# 0        2.157974   -4.97207 -5.136246 -0.908056 -5.142836  -5.24106
# 1        1.779174  -5.079564 -5.309609 -0.279806 -5.326123 -5.431599
# 2        1.476457  -5.055798 -4.683745 -0.814316 -4.436602 -5.483527
# 3         1.63546  -5.048396 -5.058544 -0.403859   -5.1738 -5.315852
# 4        1.459245  -4.759264 -5.044792 -0.239435 -5.042362 -4.622399
#
#   A_33_P3310047    p22477     p8225     p7095  ...    p25976    p23884  \
# 0      0.996369 -3.309695 -1.096744 -2.356272  ...  1.746663 -2.448382
# 1      1.049151  -2.68212  -0.88413 -3.141455  ...  0.961229 -2.325115
# 2      1.107679 -3.565926 -1.364489 -3.778602  ...   1.24937 -2.352775
# 3      0.922813 -3.687033 -0.971812 -2.599749  ...  1.431779 -3.219944
# 4      0.786796 -3.605453 -0.992999 -3.243779  ...  1.117545 -3.630248
#
#   A_33_P3800496 A_21_P0006729 A_24_P284523    p11121    p26746 A_33_P3677559  \
# 0     -1.259322     -3.232127     3.164295  -0.41048 -3.946267      -3.01915
# 1     -0.878489     -2.476317     3.059818 -0.499581 -4.027231      -3.49044
# 2     -1.309131     -2.841979     2.908225   0.42274 -4.745641     -3.532535
# 3     -1.369312     -2.633309     2.667611   0.74162 -4.544183     -4.334243
# 4     -1.304075     -3.936828      2.64173  -0.62573 -4.912573     -4.216743
#
#        p361 target_value
# 0 -1.535002          1.0
# 1 -1.432819          1.0
# 2 -1.561514          1.0
# 3 -1.536728          1.0
# 4 -1.963562          1.0
#
# [5 rows x 65524 columns]

# %%
# convert target value as integer
df["target_value"] = df["target_value"].astype(int)

# %%
df.value_counts("target_value")
# Out:
# target_value
# 1    93
# 0    48
# dtype: int64

# %%
df.shape
# Out:
# (141, 65524)

# %%
# divide the features and target values
X = df.drop(columns=["target_value"])
y = df["target_value"]

# %%
X.shape
# Out:
# (141, 65523)

# %%
y.shape
# Out:
# (141,)

# %%
non_numeric_columns = X.select_dtypes(exclude=['int', 'float']).columns
print(non_numeric_columns)
# Out:
# Index(['GE_BrightCorner', 'DarkCorner', 'p42318_v4', 'p117', 'p28737',
#        'p17314', 'A_33_P3310047', 'p22477', 'p8225', 'p7095',
#        ...
#        'p34784_v4', 'p25976', 'p23884', 'A_33_P3800496', 'A_21_P0006729',
#        'A_24_P284523', 'p11121', 'p26746', 'A_33_P3677559', 'p361'],
#       dtype='object', length=65523)

# %%
X = X.astype(float)

# %%
# build the XGBoost models
# first try the 100 features selected using mutual information

# %%
# feature selection using mutual information
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest

# mutual information selector
mi_classi_100 = SelectKBest(score_func=mutual_info_classif, k=100)

# apply the mutual information selector on the dataset
X_MI_100 = mi_classi_100.fit_transform(X, y)

# get the selected 100 features
selected_features_100 = mi_classi_100.get_support()

# feature names of selected features
selected_feature_names_100 = X.columns[selected_features_100]

X_new_100 = X[selected_feature_names_100]

print("Shape of X_new_100: ", X_new_100.shape)

# divide the dataset to train 0.8 and test 0.2
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new_100, y, test_size=0.2, random_state=42)

# create XGBoost classifier and train the data
from xgboost import XGBClassifier
xgb_classifier_100 = XGBClassifier(random_state=42)
xgb_classifier_100.fit(X_train, y_train)

# test the model on test set
y_pred_100 = xgb_classifier_100.predict(X_test)
y_pred_100

# evaluate the model using accuracy, classification_report and sensitivity
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# let's check the accuracy of the model
accuracy_xgb_100_MI = accuracy_score(y_test, y_pred_100)
print(f"Accuracy of the MI 100 XGBoost model is: {round(accuracy_xgb_100_MI*100, 3)}%")

# confusion matrix of the model
confusion_matrix_xgb_100_MI = confusion_matrix(y_test, y_pred_100)

TP_xgb_100 = confusion_matrix_xgb_100_MI[1, 1]  # True Positives
FN_xgb_100 = confusion_matrix_xgb_100_MI[1, 0]  # False Negatives

# Calculate Sensitivity (True Positive Rate or Recall)
sensitivity_xgb_100 = TP_xgb_100 / (TP_xgb_100 + FN_xgb_100)
print(f"Sensitivity for 100 features and XGBoost model (True Positive Rate): {round(sensitivity_xgb_100*100, 3)}%")

# print the confusion matrix
print("Confusion matrix of the MI 100 XGBoost model is: ")
print(confusion_matrix_xgb_100_MI)

# classification report for the
report_xgb_100 = classification_report(y_test, y_pred_100)
print("Classification report of MI 100 XGBoost model is: ")
print(report_xgb_100)
# Out:
# Shape of X_new_100:  (141, 100)
# Accuracy of the MI 100 XGBoost model is: 89.655%
# Sensitivity for 100 features and XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the MI 100 XGBoost model is:
# [[11  3]
#  [ 0 15]]
# Classification report of MI 100 XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29

# %%
X_train
# Out:
#      p37739_v4  RNA95768|RNS_850_114    p28224  p34937_v4  \
# 113  -1.783210             -1.801297  0.417392   2.957644
# 16   -0.194148             -0.976679  2.570997   3.908568
# 18    0.211387             -1.007583  2.518117   3.959290
# 10   -0.569960             -1.197541  1.804022   3.663325
# 36    0.123791             -0.591041  2.556288   3.987037
# ..         ...                   ...       ...        ...
# 71   -0.810265             -1.737683  1.720264   3.339538
# 106  -1.553305             -2.062715  0.457239   2.689619
# 14   -0.368275             -0.755708  2.285925   3.981242
# 92   -1.446095             -1.498689  1.351590   3.318151
# 102  -1.889344             -2.087023  0.311438   2.390441
#
#      RNA95977|RNS_1059_88  A_33_P3346635    p28111  A_32_P75902    p25083  \
# 113             -0.796597      -1.932526  1.944590    -0.772154  0.843513
# 16              -0.027395      -1.213037  2.661787     0.343740  1.890696
# 18              -0.169265      -1.178587  2.508373     0.447383  2.069182
# 10               0.004388      -1.486425  2.599764     0.104217  2.033562
# 36              -0.071563      -1.024691  2.862139     0.637067  1.982342
# ..                    ...            ...       ...          ...       ...
# 71              -0.248172      -1.984143  2.269958    -0.633482  1.146297
# 106             -0.560628      -2.144104  1.606442    -0.621262  0.239654
# 14               0.176835      -1.267181  2.959353     0.293233  2.359591
# 92              -0.415787      -1.419298  2.209138    -0.598279  1.430457
# 102             -1.026671      -2.420407  1.565936    -0.957399  0.658577
#
#      A_23_P400515  ...    p16197  A_33_P3352852    p15307     p6342    p28189  \
# 113     -3.140560  ... -1.776749      -0.145299  1.210713  1.025998 -3.288654
# 16      -1.024952  ... -0.221953       0.840580  1.911510  1.507567 -1.429380
# 18      -0.974265  ...  0.080070       0.937825  2.225405  1.571350 -1.569917
# 10      -1.484166  ... -0.062702       0.441141  1.889775  1.522553 -1.942533
# 36      -0.679849  ...  0.267378       0.903669  2.105485  1.542580 -1.142479
# ..            ...  ...       ...            ...       ...       ...       ...
# 71      -2.216319  ... -1.338829       0.110623  1.267159  0.327492 -2.712923
# 106     -2.867345  ... -1.641914      -0.298954  1.365937  0.156379 -2.997497
# 14      -1.105637  ...  0.191542       0.694450  1.842299  1.520016 -1.360011
# 92      -2.389238  ... -1.331849       0.132610  1.299542  0.307436 -3.212671
# 102     -3.675355  ... -2.060489      -0.280449  1.389503  0.476260 -3.105446
#
#      A_33_P3287997  A_33_P3325195    p21770  A_21_P0001861  A_23_P164958
# 113      -1.665199       1.348956  3.707849      -3.349016     -1.940878
# 16       -0.969855       1.856277  4.412049      -1.903154     -0.930776
# 18       -0.597286       2.094541  4.517180      -2.559749     -0.424975
# 10       -0.774588       1.695331  4.190980      -1.530097     -1.301593
# 36       -0.451361       2.084112  4.625600      -1.754942     -0.091854
# ..             ...            ...       ...            ...           ...
# 71       -1.474258       1.512198  3.984747      -2.633998     -1.725932
# 106      -1.965882       1.033797  3.452985      -2.674947     -1.864838
# 14       -0.623631       2.028584  4.354465      -1.380310     -1.054654
# 92       -1.432419       1.248034  3.823241      -2.869813     -1.158139
# 102      -1.785516       0.965638  3.084462      -3.511956     -2.282499
#
# [112 rows x 100 columns]

# %%
# now let's try cross validation for k = 5

# %%
from sklearn.model_selection import cross_val_score, KFold

print("5-fold Cross Validation")

# assign the model built earlier to variable model
model = xgb_classifier_100

# Define the number of folds (k) for cross-validation
k = 5

# Create a cross-validation object (K-Fold cross-validator)
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Perform k-fold cross-validation and get the cross-validation scores
# we use accuracy as the scoring metric here
scores = cross_val_score(model, X_new_100, y, cv=kf, scoring='accuracy')

# Print the cross-validation scores
print("Cross-Validation Scores:", scores)

# Calculate and print the mean and standard deviation of the scores
print(f"Mean Accuracy: {round(scores.mean()*100, 3)}%")
print(f"Standard Deviation: {round(scores.std()*100, 3)}%")
# Out:
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         1.         0.89285714 0.92857143]
# Mean Accuracy: 94.36%
# Standard Deviation: 4.77%

# %%
# cross validation for k = 8

# %%
from sklearn.model_selection import cross_val_score, KFold

print("8-fold Cross Validation")

# assign the model built earlier to variable model
model = xgb_classifier_100

# Define the number of folds (k) for cross-validation
k = 8

# Create a cross-validation object (K-Fold cross-validator)
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Perform k-fold cross-validation and get the cross-validation scores
# we use accuracy as the scoring metric here
scores = cross_val_score(model, X_new_100, y, cv=kf, scoring='accuracy')

# Print the cross-validation scores
print("Cross-Validation Scores:", scores)

# Calculate and print the mean and standard deviation of the scores
print(f"Mean Accuracy: {round(scores.mean()*100, 3)}%")
print(f"Standard Deviation: {round(scores.std()*100, 3)}%")
# Out:
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         0.94444444 1.         0.94117647
#  1.         0.94117647]
# Mean Accuracy: 95.752%
# Standard Deviation: 3.708%

# %%
# cross validation for k = 10

# %%
from sklearn.model_selection import cross_val_score, KFold

print("10-fold Cross Validation")

# assign the model built earlier to variable model
model = xgb_classifier_100

# Define the number of folds (k) for cross-validation
k = 10

# Create a cross-validation object (K-Fold cross-validator)
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Perform k-fold cross-validation and get the cross-validation scores
# we use accuracy as the scoring metric here
scores = cross_val_score(model, X_new_100, y, cv=kf, scoring='accuracy')

# Print the cross-validation scores
print("Cross-Validation Scores:", scores)

# Calculate and print the mean and standard deviation of the scores
print(f"Mean Accuracy: {round(scores.mean()*100, 3)}%")
print(f"Standard Deviation: {round(scores.std()*100, 3)}%")
# Out:
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         1.         0.92857143
#  1.         0.85714286 1.         0.92857143]
# Mean Accuracy: 95.048%
# Standard Deviation: 5.562%

# %%
# let's try for 75 features

# %%
# feature selection using mutual information
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest

# mutual information selector
mi_classi_75 = SelectKBest(score_func=mutual_info_classif, k=75)

# apply the mutual information selector on the dataset
X_MI_75 = mi_classi_75.fit_transform(X, y)

# get the selected 75 features
selected_features_75 = mi_classi_75.get_support()

# feature names of selected features
selected_feature_names_75 = X.columns[selected_features_75]

X_new_75 = X[selected_feature_names_75]

print("Shape of X_new_75: ", X_new_75.shape)

# divide the dataset to train 0.8 and test 0.2
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new_75, y, test_size=0.2, random_state=42)

# create XGBoost classifier and train the data
from xgboost import XGBClassifier
xgb_classifier_75 = XGBClassifier(random_state=42)
xgb_classifier_75.fit(X_train, y_train)

# test the model on test set
y_pred_75 = xgb_classifier_75.predict(X_test)
y_pred_75

# evaluate the model using accuracy, classification_report and sensitivity
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# let's check the accuracy of the model
accuracy_xgb_75_MI = accuracy_score(y_test, y_pred_75)
print(f"Accuracy of the MI 75 XGBoost model is: {round(accuracy_xgb_75_MI*100, 3)}%")

# confusion matrix of the model
confusion_matrix_xgb_75_MI = confusion_matrix(y_test, y_pred_75)

TP_xgb_75 = confusion_matrix_xgb_75_MI[1, 1]  # True Positives
FN_xgb_75 = confusion_matrix_xgb_75_MI[1, 0]  # False Negatives

# Calculate Sensitivity (True Positive Rate or Recall)
sensitivity_xgb_75 = TP_xgb_75 / (TP_xgb_75 + FN_xgb_75)
print(f"Sensitivity for 75 features and XGBoost model (True Positive Rate): {round(sensitivity_xgb_75*100, 3)}%")

# print the confusion matrix
print("Confusion matrix of the MI 75 XGBoost model is: ")
print(confusion_matrix_xgb_75_MI)

# classification report for the
report_xgb_75 = classification_report(y_test, y_pred_75)
print("Classification report of MI 75 XGBoost model is: ")
print(report_xgb_75)
# Out:
# Shape of X_new_75:  (141, 75)
# Accuracy of the MI 75 XGBoost model is: 89.655%
# Sensitivity for 75 features and XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the MI 75 XGBoost model is:
# [[11  3]
#  [ 0 15]]
# Classification report of MI 75 XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.83      1.00      0.91        15
#
#     accuracy                           0.90        29
#    macro avg       0.92      0.89      0.89        29
# weighted avg       0.91      0.90      0.90        29

# %%
# cross validation for k = 5

# %%
from sklearn.model_selection import cross_val_score, KFold

print("5-fold Cross Validation")

# assign the model built earlier to variable model
model = xgb_classifier_75

# Define the number of folds (k) for cross-validation
k = 5

# Create a cross-validation object (K-Fold cross-validator)
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Perform k-fold cross-validation and get the cross-validation scores
# we use accuracy as the scoring metric here
scores = cross_val_score(model, X_new_100, y, cv=kf, scoring='accuracy')

# Print the cross-validation scores
print("Cross-Validation Scores:", scores)

# Calculate and print the mean and standard deviation of the scores
print(f"Mean Accuracy: {round(scores.mean()*100, 3)}%")
print(f"Standard Deviation: {round(scores.std()*100, 3)}%")
# Out:
# 5-fold Cross Validation
# Cross-Validation Scores: [0.89655172 1.         1.         0.89285714 0.92857143]
# Mean Accuracy: 94.36%
# Standard Deviation: 4.77%

# %%
# cross validation for k = 8

# %%
from sklearn.model_selection import cross_val_score, KFold

print("8-fold Cross Validation")

# assign the model built earlier to variable model
model = xgb_classifier_75

# Define the number of folds (k) for cross-validation
k = 8

# Create a cross-validation object (K-Fold cross-validator)
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Perform k-fold cross-validation and get the cross-validation scores
# we use accuracy as the scoring metric here
scores = cross_val_score(model, X_new_100, y, cv=kf, scoring='accuracy')

# Print the cross-validation scores
print("Cross-Validation Scores:", scores)

# Calculate and print the mean and standard deviation of the scores
print(f"Mean Accuracy: {round(scores.mean()*100, 3)}%")
print(f"Standard Deviation: {round(scores.std()*100, 3)}%")
# Out:
# 8-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 1.         0.94444444 1.         0.94117647
#  1.         0.94117647]
# Mean Accuracy: 95.752%
# Standard Deviation: 3.708%

# %%
# cross validation for k = 10

# %%
from sklearn.model_selection import cross_val_score, KFold

print("10-fold Cross Validation")

# assign the model built earlier to variable model
model = xgb_classifier_75

# Define the number of folds (k) for cross-validation
k = 10

# Create a cross-validation object (K-Fold cross-validator)
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Perform k-fold cross-validation and get the cross-validation scores
# we use accuracy as the scoring metric here
scores = cross_val_score(model, X_new_100, y, cv=kf, scoring='accuracy')

# Print the cross-validation scores
print("Cross-Validation Scores:", scores)

# Calculate and print the mean and standard deviation of the scores
print(f"Mean Accuracy: {round(scores.mean()*100, 3)}%")
print(f"Standard Deviation: {round(scores.std()*100, 3)}%")
# Out:
# 10-fold Cross Validation
# Cross-Validation Scores: [0.93333333 0.85714286 1.         1.         1.         0.92857143
#  1.         0.85714286 1.         0.92857143]
# Mean Accuracy: 95.048%
# Standard Deviation: 5.562%

# %%
# now let's try for 25 features
