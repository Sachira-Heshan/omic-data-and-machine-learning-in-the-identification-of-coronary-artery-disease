# %% [markdown]
# <a href="https://colab.research.google.com/github/Sachira-Heshan/omic-data-and-machine-learning-in-the-identification-of-coronary-artery-disease/blob/main/dataset_GSE113079.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dataset - GSE113079**

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Research/Datasets/GSE113079.xlsx')

# %%
df.head()
# Out:
#                                          Unnamed: 0 CAD patient 1  \
# 0                                         #ID_REF =           NaN
# 1  #VALUE = The noromalized value of 75 percentile.           NaN
# 2                                            ID_REF         VALUE
# 3                                   GE_BrightCorner      2.157974
# 4                                        DarkCorner      -4.97207
#
#   CAD patient 2 CAD patient 3 CAD patient 4 CAD patient 5 CAD patient 6  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2         VALUE         VALUE         VALUE         VALUE         VALUE
# 3      1.779174      1.476457       1.63546      1.459245      1.014671
# 4     -5.079564     -5.055798     -5.048396     -4.759264     -5.384547
#
#   CAD patient 7 CAD patient 8 CAD patient 9  ... Healthy control 39  \
# ...

# %%
df.sample(5)
# Out:
#           Unnamed: 0 CAD patient 1 CAD patient 2 CAD patient 3 CAD patient 4  \
# 50928  A_33_P3272508      0.141177      0.518198      1.428724     -0.483368
# 60328         p11673     -2.779519     -1.859177     -2.295082     -2.626621
# 57931         p18790     -3.908235     -2.999334     -3.855045     -4.437337
# 31681         p27865     -4.289656     -5.269331     -5.126349     -4.845822
# 10600         p16527     -0.847685     -0.541274     -0.379214     -1.299413
#
#       CAD patient 5 CAD patient 6 CAD patient 7 CAD patient 8 CAD patient 9  \
# 50928     -0.027228      1.103273      0.411406      0.525714      0.831051
# 60328     -2.893071     -3.112568     -2.730855     -2.852427     -3.833563
# 57931     -3.979524     -3.426712      -2.72576     -5.143615     -2.787963
# 31681     -5.106004     -5.354612     -5.393305     -5.107918     -4.742762
# 10600     -1.107327     -0.968842     -1.116525      -1.02943     -0.727717
#
# ...

# %%
print('Size: ', df.size)
print('Shape: ', df.shape)
# Out:
# Size:  9435744
# Shape:  (65526, 144)

# %%
df_trans = df.T

# %%
df_trans.head()
# Out:
#                    0                                                 1      \
# Unnamed: 0     #ID_REF =  #VALUE = The noromalized value of 75 percentile.
# CAD patient 1        NaN                                               NaN
# CAD patient 2        NaN                                               NaN
# CAD patient 3        NaN                                               NaN
# CAD patient 4        NaN                                               NaN
#
#                 2                3           4          5         6      \
# Unnamed: 0     ID_REF  GE_BrightCorner  DarkCorner  p42318_v4      p117
# CAD patient 1   VALUE         2.157974    -4.97207  -5.136246 -0.908056
# CAD patient 2   VALUE         1.779174   -5.079564  -5.309609 -0.279806
# CAD patient 3   VALUE         1.476457   -5.055798  -4.683745 -0.814316
# CAD patient 4   VALUE          1.63546   -5.048396  -5.058544 -0.403859
#
#                   7         8              9      ...      65516     65517  \
# ...

# %%
df_trans.shape
# Out:
# (144, 65526)

# %%
df_trans.columns
# Out:
# RangeIndex(start=0, stop=65526, step=1)

# %%
df_trans_drop = df_trans.drop(columns=[0, 1, 2])

# %%
df_trans_drop.head()
# Out:
#                          3           4          5         6         7      \
# Unnamed: 0     GE_BrightCorner  DarkCorner  p42318_v4      p117    p28737
# CAD patient 1         2.157974    -4.97207  -5.136246 -0.908056 -5.142836
# CAD patient 2         1.779174   -5.079564  -5.309609 -0.279806 -5.326123
# CAD patient 3         1.476457   -5.055798  -4.683745 -0.814316 -4.436602
# CAD patient 4          1.63546   -5.048396  -5.058544 -0.403859   -5.1738
#
#                   8              9         10        11        12     ...  \
# Unnamed: 0       p17314  A_33_P3310047    p22477     p8225     p7095  ...
# CAD patient 1  -5.24106       0.996369 -3.309695 -1.096744 -2.356272  ...
# CAD patient 2 -5.431599       1.049151  -2.68212  -0.88413 -3.141455  ...
# CAD patient 3 -5.483527       1.107679 -3.565926 -1.364489 -3.778602  ...
# CAD patient 4 -5.315852       0.922813 -3.687033 -0.971812 -2.599749  ...
#
# ...

# %%
column_names = df_trans_drop.iloc[0, :]
column_names
type(column_names.tolist())
# Out:
# list

# %%
df_trans_drop.columns = column_names.tolist()

# %%
df_trans_drop.head()
# Out:
#                GE_BrightCorner  DarkCorner  p42318_v4      p117    p28737  \
# Unnamed: 0     GE_BrightCorner  DarkCorner  p42318_v4      p117    p28737
# CAD patient 1         2.157974    -4.97207  -5.136246 -0.908056 -5.142836
# CAD patient 2         1.779174   -5.079564  -5.309609 -0.279806 -5.326123
# CAD patient 3         1.476457   -5.055798  -4.683745 -0.814316 -4.436602
# CAD patient 4          1.63546   -5.048396  -5.058544 -0.403859   -5.1738
#
#                  p17314  A_33_P3310047    p22477     p8225     p7095  ...  \
# Unnamed: 0       p17314  A_33_P3310047    p22477     p8225     p7095  ...
# CAD patient 1  -5.24106       0.996369 -3.309695 -1.096744 -2.356272  ...
# CAD patient 2 -5.431599       1.049151  -2.68212  -0.88413 -3.141455  ...
# CAD patient 3 -5.483527       1.107679 -3.565926 -1.364489 -3.778602  ...
# CAD patient 4 -5.315852       0.922813 -3.687033 -0.971812 -2.599749  ...
#
# ...

# %%
df_trans_drop.drop(index="Unnamed: 0", inplace=True)

# %%
df_trans_drop.head()
# Out:
#               GE_BrightCorner DarkCorner p42318_v4      p117    p28737  \
# CAD patient 1        2.157974   -4.97207 -5.136246 -0.908056 -5.142836
# CAD patient 2        1.779174  -5.079564 -5.309609 -0.279806 -5.326123
# CAD patient 3        1.476457  -5.055798 -4.683745 -0.814316 -4.436602
# CAD patient 4         1.63546  -5.048396 -5.058544 -0.403859   -5.1738
# CAD patient 5        1.459245  -4.759264 -5.044792 -0.239435 -5.042362
#
#                  p17314 A_33_P3310047    p22477     p8225     p7095  ...  \
# CAD patient 1  -5.24106      0.996369 -3.309695 -1.096744 -2.356272  ...
# CAD patient 2 -5.431599      1.049151  -2.68212  -0.88413 -3.141455  ...
# CAD patient 3 -5.483527      1.107679 -3.565926 -1.364489 -3.778602  ...
# CAD patient 4 -5.315852      0.922813 -3.687033 -0.971812 -2.599749  ...
# CAD patient 5 -4.622399      0.786796 -3.605453 -0.992999 -3.243779  ...
#
#               p34784_v4    p25976    p23884 A_33_P3800496 A_21_P0006729  \
# ...

# %%
target_values_temp = df_trans_drop.index.tolist()

# %%
df_trans_drop['target_values'] = target_values_temp

# %%
df_trans_drop.head()
# Out:
#               GE_BrightCorner DarkCorner p42318_v4      p117    p28737  \
# CAD patient 1        2.157974   -4.97207 -5.136246 -0.908056 -5.142836
# CAD patient 2        1.779174  -5.079564 -5.309609 -0.279806 -5.326123
# CAD patient 3        1.476457  -5.055798 -4.683745 -0.814316 -4.436602
# CAD patient 4         1.63546  -5.048396 -5.058544 -0.403859   -5.1738
# CAD patient 5        1.459245  -4.759264 -5.044792 -0.239435 -5.042362
#
#                  p17314 A_33_P3310047    p22477     p8225     p7095  ...  \
# CAD patient 1  -5.24106      0.996369 -3.309695 -1.096744 -2.356272  ...
# CAD patient 2 -5.431599      1.049151  -2.68212  -0.88413 -3.141455  ...
# CAD patient 3 -5.483527      1.107679 -3.565926 -1.364489 -3.778602  ...
# CAD patient 4 -5.315852      0.922813 -3.687033 -0.971812 -2.599749  ...
# CAD patient 5 -4.622399      0.786796 -3.605453 -0.992999 -3.243779  ...
#
#                  p25976    p23884 A_33_P3800496 A_21_P0006729 A_24_P284523  \
# ...

# %%
row_indexes = list(range(0, 143))

# %%
df_trans_drop.index = row_indexes

# %%
df_trans_drop.head()
# Out:
#   GE_BrightCorner DarkCorner p42318_v4      p117    p28737    p17314  \
# 0        2.157974   -4.97207 -5.136246 -0.908056 -5.142836  -5.24106
# 1        1.779174  -5.079564 -5.309609 -0.279806 -5.326123 -5.431599
# 2        1.476457  -5.055798 -4.683745 -0.814316 -4.436602 -5.483527
# 3         1.63546  -5.048396 -5.058544 -0.403859   -5.1738 -5.315852
# 4        1.459245  -4.759264 -5.044792 -0.239435 -5.042362 -4.622399
#
#   A_33_P3310047    p22477     p8225     p7095  ...    p25976    p23884  \
# 0      0.996369 -3.309695 -1.096744 -2.356272  ...  1.746663 -2.448382
# 1      1.049151  -2.68212  -0.88413 -3.141455  ...  0.961229 -2.325115
# 2      1.107679 -3.565926 -1.364489 -3.778602  ...   1.24937 -2.352775
# 3      0.922813 -3.687033 -0.971812 -2.599749  ...  1.431779 -3.219944
# 4      0.786796 -3.605453 -0.992999 -3.243779  ...  1.117545 -3.630248
#
#   A_33_P3800496 A_21_P0006729 A_24_P284523    p11121    p26746 A_33_P3677559  \
# ...

# %%
df_trans_drop.tail()
# Out:
#     GE_BrightCorner DarkCorner p42318_v4      p117    p28737    p17314  \
# 138        4.258145  -5.355829 -4.979015 -0.019725 -4.613355 -4.134005
# 139        3.446817  -5.419512 -5.532501  -0.43901 -5.186365 -4.357549
# 140        3.219271  -5.156093 -5.517557 -0.169885 -5.343323 -3.391208
# 141         3.04819  -5.566904 -5.754226 -0.269132 -5.344678 -2.432148
# 142        3.601977   -5.87412 -6.050066 -0.156173 -5.375709 -3.145069
#
#     A_33_P3310047    p22477     p8225     p7095  ...    p25976    p23884  \
# 138      -1.02978 -4.104466  -1.71746 -1.981112  ...  1.562222 -5.508901
# 139     -0.695331 -5.582504 -2.215403 -1.984762  ...   1.16232 -5.405059
# 140      -0.55013 -5.504555 -2.193739 -2.051957  ...  1.138208 -5.613715
# 141     -0.529649 -5.844207 -2.272894 -2.500574  ...  1.303925 -5.470889
# 142     -0.341402   -5.2971 -1.877006 -2.699321  ...  1.101084 -4.271622
#
#     A_33_P3800496 A_21_P0006729 A_24_P284523    p11121    p26746  \
# ...

# %%
df_trans_drop.iloc[90:98, :]
# Out:
#    GE_BrightCorner DarkCorner p42318_v4      p117    p28737    p17314  \
# 90        2.814722  -5.255558 -5.573498 -1.132462  -5.11559  -5.65993
# 91        2.761877  -5.407251 -5.564505 -0.544162  -5.22894 -4.554888
# 92        2.644005   -5.31924 -5.466169 -0.449879  -5.44609 -5.256375
# 93                        NaN       NaN       NaN       NaN       NaN
# 94             NaN        NaN       NaN       NaN       NaN       NaN
# 95        2.353013  -4.422752 -4.657876  -0.88495 -4.573104 -4.764457
# 96        2.535326  -3.689637 -4.057941  -0.50704 -4.004152  -4.13847
# 97        2.293729  -4.453204 -4.528148 -0.909807 -4.524135 -4.359104
#
#    A_33_P3310047    p22477     p8225     p7095  ...    p25976    p23884  \
# 90      0.093473 -5.641557 -2.360164 -2.417891  ...  1.852371  -5.59074
# 91      0.051944 -5.631467 -2.876818 -2.578905  ...  2.398116 -5.597133
# 92     -0.137597 -5.218155 -2.521018 -1.793298  ...  1.908107 -4.930794
# ...

# %%
dataset = df_trans_drop.drop(index=[93, 94])

# %%
dataset.iloc[90:98, :]
# Out:
#    GE_BrightCorner DarkCorner p42318_v4      p117    p28737    p17314  \
# 90        2.814722  -5.255558 -5.573498 -1.132462  -5.11559  -5.65993
# 91        2.761877  -5.407251 -5.564505 -0.544162  -5.22894 -4.554888
# 92        2.644005   -5.31924 -5.466169 -0.449879  -5.44609 -5.256375
# 95        2.353013  -4.422752 -4.657876  -0.88495 -4.573104 -4.764457
# 96        2.535326  -3.689637 -4.057941  -0.50704 -4.004152  -4.13847
# 97        2.293729  -4.453204 -4.528148 -0.909807 -4.524135 -4.359104
# 98        3.585311  -5.335283 -5.546134  0.080051 -5.076416 -5.396224
# 99        2.245409  -4.658991 -4.925503 -0.500226 -4.963634 -4.708636
#
#    A_33_P3310047    p22477     p8225     p7095  ...    p25976    p23884  \
# 90      0.093473 -5.641557 -2.360164 -2.417891  ...  1.852371  -5.59074
# 91      0.051944 -5.631467 -2.876818 -2.578905  ...  2.398116 -5.597133
# 92     -0.137597 -5.218155 -2.521018 -1.793298  ...  1.908107 -4.930794
# ...

# %%
dataset.index = list(range(0, 141))

# %%
dataset.head()
# Out:
#   GE_BrightCorner DarkCorner p42318_v4      p117    p28737    p17314  \
# 0        2.157974   -4.97207 -5.136246 -0.908056 -5.142836  -5.24106
# 1        1.779174  -5.079564 -5.309609 -0.279806 -5.326123 -5.431599
# 2        1.476457  -5.055798 -4.683745 -0.814316 -4.436602 -5.483527
# 3         1.63546  -5.048396 -5.058544 -0.403859   -5.1738 -5.315852
# 4        1.459245  -4.759264 -5.044792 -0.239435 -5.042362 -4.622399
#
#   A_33_P3310047    p22477     p8225     p7095  ...    p25976    p23884  \
# 0      0.996369 -3.309695 -1.096744 -2.356272  ...  1.746663 -2.448382
# 1      1.049151  -2.68212  -0.88413 -3.141455  ...  0.961229 -2.325115
# 2      1.107679 -3.565926 -1.364489 -3.778602  ...   1.24937 -2.352775
# 3      0.922813 -3.687033 -0.971812 -2.599749  ...  1.431779 -3.219944
# 4      0.786796 -3.605453 -0.992999 -3.243779  ...  1.117545 -3.630248
#
#   A_33_P3800496 A_21_P0006729 A_24_P284523    p11121    p26746 A_33_P3677559  \
# ...

# %%
dataset.tail()
# Out:
#     GE_BrightCorner DarkCorner p42318_v4      p117    p28737    p17314  \
# 136        4.258145  -5.355829 -4.979015 -0.019725 -4.613355 -4.134005
# 137        3.446817  -5.419512 -5.532501  -0.43901 -5.186365 -4.357549
# 138        3.219271  -5.156093 -5.517557 -0.169885 -5.343323 -3.391208
# 139         3.04819  -5.566904 -5.754226 -0.269132 -5.344678 -2.432148
# 140        3.601977   -5.87412 -6.050066 -0.156173 -5.375709 -3.145069
#
#     A_33_P3310047    p22477     p8225     p7095  ...    p25976    p23884  \
# 136      -1.02978 -4.104466  -1.71746 -1.981112  ...  1.562222 -5.508901
# 137     -0.695331 -5.582504 -2.215403 -1.984762  ...   1.16232 -5.405059
# 138      -0.55013 -5.504555 -2.193739 -2.051957  ...  1.138208 -5.613715
# 139     -0.529649 -5.844207 -2.272894 -2.500574  ...  1.303925 -5.470889
# 140     -0.341402   -5.2971 -1.877006 -2.699321  ...  1.101084 -4.271622
#
#     A_33_P3800496 A_21_P0006729 A_24_P284523    p11121    p26746  \
# ...

# %%
dataset.shape
# Out:
# (141, 65524)

# %%
dataset.rename(columns={"target_values": "target_value"}, inplace=True)

# %%
dataset
# Out:
#     GE_BrightCorner DarkCorner p42318_v4      p117    p28737    p17314  \
# 0          2.157974   -4.97207 -5.136246 -0.908056 -5.142836  -5.24106
# 1          1.779174  -5.079564 -5.309609 -0.279806 -5.326123 -5.431599
# 2          1.476457  -5.055798 -4.683745 -0.814316 -4.436602 -5.483527
# 3           1.63546  -5.048396 -5.058544 -0.403859   -5.1738 -5.315852
# 4          1.459245  -4.759264 -5.044792 -0.239435 -5.042362 -4.622399
# ..              ...        ...       ...       ...       ...       ...
# 136        4.258145  -5.355829 -4.979015 -0.019725 -4.613355 -4.134005
# 137        3.446817  -5.419512 -5.532501  -0.43901 -5.186365 -4.357549
# 138        3.219271  -5.156093 -5.517557 -0.169885 -5.343323 -3.391208
# 139         3.04819  -5.566904 -5.754226 -0.269132 -5.344678 -2.432148
# 140        3.601977   -5.87412 -6.050066 -0.156173 -5.375709 -3.145069
#
#     A_33_P3310047    p22477     p8225     p7095  ...    p25976    p23884  \
# ...

# %%
data = dataset.copy()

# %%
data["target_value"] = data["target_value"].replace({"CAD patient": 1, "Healthy control": 0}, regex=True)

# %%
data
# Out:
#     GE_BrightCorner DarkCorner p42318_v4      p117    p28737    p17314  \
# 0          2.157974   -4.97207 -5.136246 -0.908056 -5.142836  -5.24106
# 1          1.779174  -5.079564 -5.309609 -0.279806 -5.326123 -5.431599
# 2          1.476457  -5.055798 -4.683745 -0.814316 -4.436602 -5.483527
# 3           1.63546  -5.048396 -5.058544 -0.403859   -5.1738 -5.315852
# 4          1.459245  -4.759264 -5.044792 -0.239435 -5.042362 -4.622399
# ..              ...        ...       ...       ...       ...       ...
# 136        4.258145  -5.355829 -4.979015 -0.019725 -4.613355 -4.134005
# 137        3.446817  -5.419512 -5.532501  -0.43901 -5.186365 -4.357549
# 138        3.219271  -5.156093 -5.517557 -0.169885 -5.343323 -3.391208
# 139         3.04819  -5.566904 -5.754226 -0.269132 -5.344678 -2.432148
# 140        3.601977   -5.87412 -6.050066 -0.156173 -5.375709 -3.145069
#
#     A_33_P3310047    p22477     p8225     p7095  ...    p25976    p23884  \
# ...

# %%
data_export = data.T

# %%
data_export.to_excel("partially-processed-dataset-GSE113079.xlsx", sheet_name="GSE113079")

# %%
data.value_counts("target_value")
# Out:
# target_value
# 1    93
# 0    48
# dtype: int64

# %%
# check for missing values
data.isnull().sum()
# Out:
# GE_BrightCorner    0
# DarkCorner         0
# p42318_v4          0
# p117               0
# p28737             0
#                   ..
# p11121             0
# p26746             0
# A_33_P3677559      0
# p361               0
# target_value       0
# Length: 65524, dtype: int64

# %%
data.isnull().any().any()
# Out:
# False

# %% [markdown]
# There are no null values in the dataset and the data already normalized.

# %%
# feature selection using mutual information
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest

# %%
mi_classi = SelectKBest(score_func=mutual_info_classif, k=125)

# %%
# divide the features and target values
X = data.drop(columns=["target_value"])
y = data["target_value"]

# %%
X.sample(10)
# Out:
#     GE_BrightCorner DarkCorner p42318_v4      p117    p28737    p17314  \
# 45         2.696086  -3.611663 -3.772542 -1.162201 -3.735833 -3.401447
# 36         1.970145  -5.066301 -5.365994 -0.583425 -5.260548 -5.325084
# 5          1.014671  -5.384547  -5.04238 -0.586996 -5.497274 -4.224223
# 57         2.361447  -5.032291 -4.997048 -0.605859  -4.43888 -3.909869
# 128        3.237202  -5.938892 -5.406498 -0.550451 -3.335189 -5.017414
# 97         2.245409  -4.658991 -4.925503 -0.500226 -4.963634 -4.708636
# 30         2.458807  -5.075814 -5.294832  -1.37481 -5.260432 -4.136175
# 119        3.040978  -5.335873 -5.437662 -0.068882 -5.338905 -4.780051
# 126        3.402001  -5.120371 -5.290874 -1.175645 -5.331117 -4.103317
# 87         2.732625  -5.000215 -5.165781 -1.111327  -4.73003 -3.787208
#
#     A_33_P3310047    p22477     p8225     p7095  ... p34784_v4    p25976  \
# 45       0.359551 -3.809316  -2.15441 -2.596316  ... -1.703893  1.055124
# ...

# %%
# mi_classi.fit(X, y)
# Out:
# SelectKBest(k=125, score_func=<function mutual_info_classif at 0x7a09918577f0>)

# %%
# feature_MI_score = pd.Series(mi_classi.scores_, index=X.columns)
# feature_MI_score.sort_values(ascending=False)
X.shape
# Out:
# (141, 65523)

# %%
X_MI = mi_classi.fit_transform(X, y)

# %%
selected_features = mi_classi.get_support()

# %%
selected_features
# Out:
# array([False, False, False, ..., False, False, False])

# %%
selected_feature_names = X.columns[selected_features]

# %%
X_MI.shape
# Out:
# (141, 125)

# %%
X_MI_select = pd.DataFrame(X_MI)

# %%
X_MI_select
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.455316 -0.639408  2.200286   4.12654 -0.017721 -1.132632  2.879333
# 1    0.071045 -0.660443  1.963782   4.22235  0.508597 -0.926003  2.915763
# 2    0.119662 -0.808997  2.406831  3.960643  0.035527 -0.933632  2.679596
# 3    0.074621 -0.661528  1.649061  3.813206  0.447136 -0.841461  3.122613
# 4    0.087882 -0.672335  1.851757  3.690326  0.222664 -1.416524   2.97479
# ..        ...       ...       ...       ...       ...       ...       ...
# 136 -1.986456 -2.324168  0.655798  2.140839 -0.659416 -2.500532  1.964543
# 137 -1.589083 -2.246733  0.873089  2.904433 -0.892869 -2.085856  1.425873
# 138 -1.537664 -2.070291  0.957093  2.983734 -1.100118 -2.169212  1.546984
# 139  -1.76162 -2.155889  1.341546   2.93829 -0.897742 -1.907044  1.702482
# 140 -1.151362   -1.9122  1.477609  3.075532 -0.680863 -1.881704  1.934531
#
#           7         8         9    ...       115       116       117  \
# ...

# %%
X_new = X[selected_feature_names]

# %%
X_new
# Out:
#     p37739_v4 RNA95768|RNS_850_114    p28224 p34937_v4 RNA95977|RNS_1059_88  \
# 0    0.455316            -0.639408  2.200286   4.12654            -0.017721
# 1    0.071045            -0.660443  1.963782   4.22235             0.508597
# 2    0.119662            -0.808997  2.406831  3.960643             0.035527
# 3    0.074621            -0.661528  1.649061  3.813206             0.447136
# 4    0.087882            -0.672335  1.851757  3.690326             0.222664
# ..        ...                  ...       ...       ...                  ...
# 136 -1.986456            -2.324168  0.655798  2.140839            -0.659416
# 137 -1.589083            -2.246733  0.873089  2.904433            -0.892869
# 138 -1.537664            -2.070291  0.957093  2.983734            -1.100118
# 139  -1.76162            -2.155889  1.341546   2.93829            -0.897742
# 140 -1.151362              -1.9122  1.477609  3.075532            -0.680863
#
# ...

# %%
# divide the dataset to train 0.8 and test 0.2
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_tarin, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (112, 125)

# %%
X_train.sample(10)
# Out:
#     p37739_v4 RNA95768|RNS_850_114    p28224 p34937_v4 RNA95977|RNS_1059_88  \
# 88  -0.772938            -1.336738  1.526351  3.800143            -0.036883
# 102 -1.889344            -2.087023  0.311438  2.390441            -1.026671
# 122 -2.372958            -2.446098 -0.026397  2.661022            -0.687389
# 123 -3.155782            -2.461426   0.11192  2.579909            -0.656548
# 86  -0.506495            -1.181203  2.007057  3.927276             0.322003
# 2    0.119662            -0.808997  2.406831  3.960643             0.035527
# 39  -0.180023            -0.827351  2.443966  4.278829             0.099206
# 98   -1.47648            -2.183588  0.660048  2.931853            -0.572348
# 69  -0.462215            -1.430276  1.687652  3.684996             0.232917
# 56  -0.062458            -0.904839  2.500714  3.845937             0.047109
#
#     A_33_P3346635    p28111 A_32_P75902    p25083 RNA96095|RNS_1177_73  ...  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
MI_selected_df = X_new.copy()
MI_selected_df["target_value"] = y
MI_selected_df
# Out:
#     p37739_v4 RNA95768|RNS_850_114    p28224 p34937_v4 RNA95977|RNS_1059_88  \
# 0    0.455316            -0.639408  2.200286   4.12654            -0.017721
# 1    0.071045            -0.660443  1.963782   4.22235             0.508597
# 2    0.119662            -0.808997  2.406831  3.960643             0.035527
# 3    0.074621            -0.661528  1.649061  3.813206             0.447136
# 4    0.087882            -0.672335  1.851757  3.690326             0.222664
# ..        ...                  ...       ...       ...                  ...
# 136 -1.986456            -2.324168  0.655798  2.140839            -0.659416
# 137 -1.589083            -2.246733  0.873089  2.904433            -0.892869
# 138 -1.537664            -2.070291  0.957093  2.983734            -1.100118
# 139  -1.76162            -2.155889  1.341546   2.93829            -0.897742
# 140 -1.151362              -1.9122  1.477609  3.075532            -0.680863
#
# ...

# %%
plot_data = MI_selected_df.iloc[:, 0:4]
plot_data
# Out:
#     p37739_v4 RNA95768|RNS_850_114    p28224 p34937_v4
# 0    0.455316            -0.639408  2.200286   4.12654
# 1    0.071045            -0.660443  1.963782   4.22235
# 2    0.119662            -0.808997  2.406831  3.960643
# 3    0.074621            -0.661528  1.649061  3.813206
# 4    0.087882            -0.672335  1.851757  3.690326
# ..        ...                  ...       ...       ...
# 136 -1.986456            -2.324168  0.655798  2.140839
# 137 -1.589083            -2.246733  0.873089  2.904433
# 138 -1.537664            -2.070291  0.957093  2.983734
# 139  -1.76162            -2.155889  1.341546   2.93829
# 140 -1.151362              -1.9122  1.477609  3.075532
#
# [141 rows x 4 columns]

# %%
# export the dataset with selected features using mutual information
MI_selected_df.to_excel("MI_125-GSE113079.xlsx", sheet_name="MI_125")

# %%
plot_data["target_value"] = MI_selected_df["target_value"]
# plot the selected 4 features
sns.pairplot(plot_data, hue="target_value")

# %%
# plot the selected 4 features
plot_data_2 = MI_selected_df.iloc[:, 4:8]
plot_data_2["target_value"] = MI_selected_df["target_value"]
sns.pairplot(plot_data_2, hue="target_value")
