# %% [markdown]
# <a href="https://colab.research.google.com/github/Sachira-Heshan/omic-data-and-machine-learning-in-the-identification-of-coronary-artery-disease/blob/main/rna_data/models_with_rna_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Research/Datasets/Cleaned/cleaned-non-normalized-dataset-GSE208194.xlsx')
df
# Out:
#     Unnamed: 0  ENSG00000000419.12  ENSG00000000938.13  ENSG00000001629.10  \
# 0            0            2.398878            3.324077           12.037059
# 1            1           12.157726           13.971038            1.453811
# 2            2            1.402110            1.917631           12.596614
# 3            3            7.667875           10.225812           15.799738
# 4            4            4.198525            2.847621           17.246205
# ..         ...                 ...                 ...                 ...
# 84          84           25.222543           17.525907           89.995748
# 85          85           17.734630           10.903512           32.951226
# 86          86            5.057123            1.257853           12.263058
# 87          87            0.968332            1.025641            5.968981
# 88          88            3.757043            8.876226           14.964376
#
#     ENSG00000001631.15  ENSG00000002549.12  ENSG00000002586.20  \
# 0             1.287932            2.914606          106.458644
# 1             5.842868           32.566404           40.094091
# 2             1.412257            2.231871          124.158648
# 3             1.526812           35.444900           51.141639
# 4             7.261625            9.212083           71.778619
# ..                 ...                 ...                 ...
# 84            7.899247           28.691720           55.245745
# 85           11.006974           33.123814           56.911321
# 86            6.447497            6.709470          271.525037
# 87            2.786651            1.214385          154.849235
# 88            5.343678            3.023686          155.210654
#
#     ENSG00000002834.18  ENSG00000003056.8  ENSG00000003147.19  ...  \
# 0             7.243743           3.443131            6.531775  ...
# 1            22.433910           1.512845            3.252381  ...
# 2             5.942053           8.835538            5.433218  ...
# 3            17.521034           6.539876           13.176043  ...
# 4             5.453753           4.370199            7.352974  ...
# ..                 ...                ...                 ...  ...
# 84           42.377442          64.245814           30.129237  ...
# 85           19.254234           5.987356           12.130276  ...
# 86            6.904848          13.699922            7.758268  ...
# 87           10.530023           3.465649            4.376058  ...
# 88           14.869883           8.946997            6.206429  ...
#
#     ENSG00000286021.2  ENSG00000286147.1  ENSG00000286171.1  \
# 0            2.951689           2.780988          22.090146
# 1           69.319858          66.183243          79.348496
# 2            6.950649          12.663118          18.383923
# 3           67.810987          88.524134          34.275493
# 4           12.891301          24.227999          39.581215
# ..                ...                ...                ...
# 84          15.547450           9.409992          10.441533
# 85          22.100110          19.978202          31.744585
# 86           1.974481           3.483134          27.933352
# 87           1.428419           4.340778          15.813597
# 88           2.483810           8.868814          94.583754
#
#     ENSG00000286522.1  ENSG00000286834.1  ENSG00000287080.1  \
# 0           38.558169           1.446729           8.543461
# 1          285.735258         101.312666          48.482781
# 2           36.159325          17.106360          11.492971
# 3          125.344512         109.490990          40.763492
# 4          111.782471          33.096990          23.798352
# ..                ...                ...                ...
# 84         559.390098          23.370109           2.688918
# 85         387.044359          34.169966           9.531408
# 86          89.231794           5.444215           2.823952
# 87          27.761897           4.262073           0.107894
# 88          49.830760          13.917467          12.110910
#
#     ENSG00000287160.1  ENSG00000287825.1  ENSG00000288560.1  target_value
# 0            3.392143           8.543410           8.361870             1
# 1           57.089139          26.198111           3.218659             1
# 2            7.379778           9.731645           2.560132             1
# 3           67.437197           5.939315           4.123530             1
# 4           17.519094          13.911370           5.092169             1
# ..                ...                ...                ...           ...
# 84          23.094887           7.114563           4.563028             0
# 85          19.040575           4.664343          10.941191             0
# 86           1.324381          20.376778           7.220862             0
# 87           4.329463           1.601362           1.568828             1
# 88           9.970802           9.273306           7.706704             0
#
# [89 rows x 4152 columns]

# %%
dataset = df.drop(columns=["Unnamed: 0"])
dataset
# Out:
#     ENSG00000000419.12  ENSG00000000938.13  ENSG00000001629.10  \
# 0             2.398878            3.324077           12.037059
# 1            12.157726           13.971038            1.453811
# 2             1.402110            1.917631           12.596614
# 3             7.667875           10.225812           15.799738
# 4             4.198525            2.847621           17.246205
# ..                 ...                 ...                 ...
# 84           25.222543           17.525907           89.995748
# 85           17.734630           10.903512           32.951226
# 86            5.057123            1.257853           12.263058
# 87            0.968332            1.025641            5.968981
# 88            3.757043            8.876226           14.964376
#
#     ENSG00000001631.15  ENSG00000002549.12  ENSG00000002586.20  \
# 0             1.287932            2.914606          106.458644
# 1             5.842868           32.566404           40.094091
# 2             1.412257            2.231871          124.158648
# 3             1.526812           35.444900           51.141639
# 4             7.261625            9.212083           71.778619
# ..                 ...                 ...                 ...
# 84            7.899247           28.691720           55.245745
# 85           11.006974           33.123814           56.911321
# 86            6.447497            6.709470          271.525037
# 87            2.786651            1.214385          154.849235
# 88            5.343678            3.023686          155.210654
#
#     ENSG00000002834.18  ENSG00000003056.8  ENSG00000003147.19  \
# 0             7.243743           3.443131            6.531775
# 1            22.433910           1.512845            3.252381
# 2             5.942053           8.835538            5.433218
# 3            17.521034           6.539876           13.176043
# 4             5.453753           4.370199            7.352974
# ..                 ...                ...                 ...
# 84           42.377442          64.245814           30.129237
# 85           19.254234           5.987356           12.130276
# 86            6.904848          13.699922            7.758268
# 87           10.530023           3.465649            4.376058
# 88           14.869883           8.946997            6.206429
#
#     ENSG00000003402.20  ...  ENSG00000286021.2  ENSG00000286147.1  \
# 0            79.598523  ...           2.951689           2.780988
# 1           122.045223  ...          69.319858          66.183243
# 2            48.646713  ...           6.950649          12.663118
# 3           109.224603  ...          67.810987          88.524134
# 4           108.900379  ...          12.891301          24.227999
# ..                 ...  ...                ...                ...
# 84          237.696308  ...          15.547450           9.409992
# 85          127.585057  ...          22.100110          19.978202
# 86          110.033203  ...           1.974481           3.483134
# 87           49.638060  ...           1.428419           4.340778
# 88           71.701582  ...           2.483810           8.868814
#
#     ENSG00000286171.1  ENSG00000286522.1  ENSG00000286834.1  \
# 0           22.090146          38.558169           1.446729
# 1           79.348496         285.735258         101.312666
# 2           18.383923          36.159325          17.106360
# 3           34.275493         125.344512         109.490990
# 4           39.581215         111.782471          33.096990
# ..                ...                ...                ...
# 84          10.441533         559.390098          23.370109
# 85          31.744585         387.044359          34.169966
# 86          27.933352          89.231794           5.444215
# 87          15.813597          27.761897           4.262073
# 88          94.583754          49.830760          13.917467
#
#     ENSG00000287080.1  ENSG00000287160.1  ENSG00000287825.1  \
# 0            8.543461           3.392143           8.543410
# 1           48.482781          57.089139          26.198111
# 2           11.492971           7.379778           9.731645
# 3           40.763492          67.437197           5.939315
# 4           23.798352          17.519094          13.911370
# ..                ...                ...                ...
# 84           2.688918          23.094887           7.114563
# 85           9.531408          19.040575           4.664343
# 86           2.823952           1.324381          20.376778
# 87           0.107894           4.329463           1.601362
# 88          12.110910           9.970802           9.273306
#
#     ENSG00000288560.1  target_value
# 0            8.361870             1
# 1            3.218659             1
# 2            2.560132             1
# 3            4.123530             1
# 4            5.092169             1
# ..                ...           ...
# 84           4.563028             0
# 85          10.941191             0
# 86           7.220862             0
# 87           1.568828             1
# 88           7.706704             0
#
# [89 rows x 4151 columns]

# %%
dataset.value_counts('target_value')
# Out:
# target_value
# 1    59
# 0    30
# dtype: int64

# %%
dataset.shape
# Out:
# (89, 4151)

# %%
X = dataset.drop(columns=["target_value"])
y = dataset["target_value"]

# %%
# mutual information values
from sklearn.feature_selection import mutual_info_classif
import numpy as np

# Calculate Mutual Information between each feature and the target variable
mi_scores = mutual_info_classif(X, y, discrete_features=[False]*X.shape[1])

# Create a dictionary that maps feature names to their MI scores
feature_mi_scores = {feature_name: mi_score for feature_name, mi_score in zip(X.columns, mi_scores)}

# Sort the features in ascending order of their MI scores
sorted_features_ascending = sorted(feature_mi_scores.items(), key=lambda x: x[1])

# %%
# now let's plot this data
import matplotlib.pyplot as plt

# Extract the feature names and their MI scores from sorted_features_ascending
feature_names, mi_scores = zip(*sorted_features_ascending)

# Create a bar plot to visualize MI scores
plt.figure(figsize=(12, 8))
plt.barh(range(len(feature_names)), mi_scores, align='center', alpha=0.7)
plt.yticks(range(len(feature_names)), feature_names)
plt.xlabel('Mutual Information Score')
plt.ylabel('Feature Name')
plt.title('Mutual Information Scores of All Features')
plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
# Filter features with non-zero mutual information scores
selected_features = [feature_name for feature_name, mi_score in sorted_features_ascending if mi_score > 0]
# let's create new X with only these features
X_selected = X[selected_features]
X_selected.shape
# Out:
# (89, 3492)

# %%
# SVM
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

no_of_features = [1]
cross_val_k = [5, 8, 10]
results = {}

for feature_count in no_of_features:
    print(f"RESULTS FOR {feature_count} FEATURES")
    print("--------------------------------------------------")

    results[feature_count] = {}

    # Feature selection using mutual information
    mi_classif = SelectKBest(score_func=mutual_info_classif, k=feature_count)

    # Apply the mutual information selector on the dataset
    X_MI_selected = mi_classif.fit_transform(X, y)

    # Get the selected features
    selected_features = mi_classif.get_support()

    # Feature names of selected features
    selected_feature_names = X.columns[selected_features]

    X_new = X[selected_feature_names]

    print("Shape of X_new: ", X_new.shape)

    # Divide the dataset to train 0.8 and test 0.2
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Create SVM classifier and fit the data
    svm_classif = SVC()
    svm_classif.fit(X_train, y_train)

    # Test the model on the test set
    y_pred = svm_classif.predict(X_test)

    # Check the accuracy of the model
    accuracy_svm_model = accuracy_score(y_test, y_pred)
    print(f"Accuracy of the {feature_count} features SVM model is: {round(accuracy_svm_model * 100, 3)}%")

    results[feature_count]["accuracy"] = round(accuracy_svm_model * 100, 3)

    # Confusion matrix of the model
    confusion_matrix_svm_model = confusion_matrix(y_test, y_pred)

    TP_svm_model = confusion_matrix_svm_model[1, 1]  # True Positives
    FN_svm_model = confusion_matrix_svm_model[1, 0]  # False Negatives

    # Calculate Sensitivity (True Positive Rate or Recall)
    sensitivity_svm_model = TP_svm_model / (TP_svm_model + FN_svm_model)
    print(f"Sensitivity for {feature_count} features SVM model (True Positive Rate): {round(sensitivity_svm_model * 100, 3)}%")

    results[feature_count]["sensitivity"] = round(sensitivity_svm_model * 100, 3)

    # Print the confusion matrix
    print(f"Confusion matrix of the {feature_count} features SVM model is: ")
    print(confusion_matrix_svm_model)

    # Classification report for the model
    report_svm_model = classification_report(y_test, y_pred)
    print(f"Classification report of {feature_count} features SVM model is: ")
    print(report_svm_model)

    # Now let's do the cross-validation
    for k in cross_val_k:
        print(f"{k}-fold Cross Validation")

        results[feature_count][f"{k}-fold-CV"] = {}

        # Create a cross-validation object (K-Fold cross-validator)
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Perform k-fold cross-validation and get the cross-validation scores using SVM
        scores = cross_val_score(svm_classif, X_new, y, cv=kf, scoring='accuracy')

        # Print the cross-validation scores
        print("Cross-Validation Scores:", scores)

        # Calculate and print the mean and standard deviation of the scores
        print(f"Mean Accuracy: {round(scores.mean() * 100, 3)}%")
        print(f"Standard Deviation: {round(scores.std() * 100, 3)}%")

        results[feature_count][f"{k}-fold-CV"]["mean-accuracy"] = round(scores.mean() * 100, 3)
        results[feature_count][f"{k}-fold-CV"]["standard-deviation"] = round(scores.std() * 100, 3)
        results[feature_count]["acc-std"] = f"{results[feature_count][f'{k}-fold-CV']['mean-accuracy']}% ± {results[feature_count][f'{k}-fold-CV']['standard-deviation']}%"

        print("")
    print("")
# Out:
# RESULTS FOR 1 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 1)
# Accuracy of the 1 features SVM model is: 88.889%
# Sensitivity for 1 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 1 features SVM model is:
# [[ 3  2]
#  [ 0 13]]
# Classification report of 1 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75         5
#            1       0.87      1.00      0.93        13
#
#     accuracy                           0.89        18
#    macro avg       0.93      0.80      0.84        18
# weighted avg       0.90      0.89      0.88        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.88888889 0.94444444 0.94444444 0.88888889 0.94117647]
# Mean Accuracy: 92.157%
# Standard Deviation: 2.671%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.81818182 0.90909091 0.90909091 1.         0.90909091
#  0.90909091 0.90909091]
# Mean Accuracy: 92.045%
# Standard Deviation: 5.45%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.77777778 0.88888889 1.         0.88888889 1.
#  1.         0.77777778 1.         0.875     ]
# Mean Accuracy: 92.083%
# Standard Deviation: 8.741%

# %%
selected_feature_names
# Out:
# Index(['ENSG00000165119.21'], dtype='object')

# %%
# Extract the data for plotting
x_values = results.keys()
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results.values()]
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results.values()]

# Create a single plot for mean accuracy and standard deviation
plt.figure(figsize=(12, 8))

plt.errorbar(x_values, mean_5_fold, yerr=std_5_fold, marker='o', label='5-fold', linestyle='-', capsize=5)

plt.xlabel('Number of features')
plt.ylabel('Mean Accuracy')
plt.title('Variation of Mean Accuracy with different number of features for 5-fold Cross Validation')
plt.legend()
plt.grid(True)

plt.show()

# %%
# SVM
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

no_of_features = [5, 15, 25, 35, 45, 55, 65]
cross_val_k = [5, 8, 10]
results_svm = {}

for feature_count in no_of_features:
    print(f"RESULTS FOR {feature_count} FEATURES")
    print("--------------------------------------------------")

    results_svm[feature_count] = {}

    # Feature selection using mutual information
    mi_classif = SelectKBest(score_func=mutual_info_classif, k=feature_count)

    # Apply the mutual information selector on the dataset
    X_MI_selected = mi_classif.fit_transform(X, y)

    # Get the selected features
    selected_features = mi_classif.get_support()

    # Feature names of selected features
    selected_feature_names = X.columns[selected_features]

    X_new = X[selected_feature_names]

    print("Shape of X_new: ", X_new.shape)

    # Divide the dataset to train 0.8 and test 0.2
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Create SVM classifier and fit the data
    svm_classif = SVC()
    svm_classif.fit(X_train, y_train)

    # Test the model on the test set
    y_pred = svm_classif.predict(X_test)

    # Check the accuracy of the model
    accuracy_svm_model = accuracy_score(y_test, y_pred)
    print(f"Accuracy of the {feature_count} features SVM model is: {round(accuracy_svm_model * 100, 3)}%")

    results_svm[feature_count]["accuracy"] = round(accuracy_svm_model * 100, 3)

    # Confusion matrix of the model
    confusion_matrix_svm_model = confusion_matrix(y_test, y_pred)

    TP_svm_model = confusion_matrix_svm_model[1, 1]  # True Positives
    FN_svm_model = confusion_matrix_svm_model[1, 0]  # False Negatives

    # Calculate Sensitivity (True Positive Rate or Recall)
    sensitivity_svm_model = TP_svm_model / (TP_svm_model + FN_svm_model)
    print(f"Sensitivity for {feature_count} features SVM model (True Positive Rate): {round(sensitivity_svm_model * 100, 3)}%")

    results_svm[feature_count]["sensitivity"] = round(sensitivity_svm_model * 100, 3)

    # Print the confusion matrix
    print(f"Confusion matrix of the {feature_count} features SVM model is: ")
    print(confusion_matrix_svm_model)

    # Classification report for the model
    report_svm_model = classification_report(y_test, y_pred)
    print(f"Classification report of {feature_count} features SVM model is: ")
    print(report_svm_model)

    # Now let's do the cross-validation
    for k in cross_val_k:
        print(f"{k}-fold Cross Validation")

        results_svm[feature_count][f"{k}-fold-CV"] = {}

        # Create a cross-validation object (K-Fold cross-validator)
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Perform k-fold cross-validation and get the cross-validation scores using SVM
        scores = cross_val_score(svm_classif, X_new, y, cv=kf, scoring='accuracy')

        # Print the cross-validation scores
        print("Cross-Validation Scores:", scores)

        # Calculate and print the mean and standard deviation of the scores
        print(f"Mean Accuracy: {round(scores.mean() * 100, 3)}%")
        print(f"Standard Deviation: {round(scores.std() * 100, 3)}%")

        results_svm[feature_count][f"{k}-fold-CV"]["mean-accuracy"] = round(scores.mean() * 100, 3)
        results_svm[feature_count][f"{k}-fold-CV"]["standard-deviation"] = round(scores.std() * 100, 3)
        results_svm[feature_count]["acc-std"] = f"{results_svm[feature_count][f'{k}-fold-CV']['mean-accuracy']}% ± {results_svm[feature_count][f'{k}-fold-CV']['standard-deviation']}%"

        print("")
    print("")
# Out:
# RESULTS FOR 5 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 5)
# Accuracy of the 5 features SVM model is: 88.889%
# Sensitivity for 5 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 5 features SVM model is:
# [[ 3  2]
#  [ 0 13]]
# Classification report of 5 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75         5
#            1       0.87      1.00      0.93        13
#
#     accuracy                           0.89        18
#    macro avg       0.93      0.80      0.84        18
# weighted avg       0.90      0.89      0.88        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.88888889 1.         1.         0.77777778 0.88235294]
# Mean Accuracy: 90.98%
# Standard Deviation: 8.354%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.81818182 1.         1.         0.90909091 0.81818182
#  0.81818182 0.90909091]
# Mean Accuracy: 90.909%
# Standard Deviation: 7.873%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.77777778 1.         1.         1.         1.
#  0.66666667 0.88888889 0.88888889 0.75      ]
# Mean Accuracy: 89.722%
# Standard Deviation: 11.919%
#
#
# RESULTS FOR 15 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 15)
# Accuracy of the 15 features SVM model is: 83.333%
# Sensitivity for 15 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 15 features SVM model is:
# [[ 2  3]
#  [ 0 13]]
# Classification report of 15 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.40      0.57         5
#            1       0.81      1.00      0.90        13
#
#     accuracy                           0.83        18
#    macro avg       0.91      0.70      0.73        18
# weighted avg       0.86      0.83      0.81        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.83333333 1.         0.94444444 0.77777778 0.88235294]
# Mean Accuracy: 88.758%
# Standard Deviation: 7.861%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.72727273 1.         1.         0.90909091 0.81818182
#  0.81818182 0.90909091]
# Mean Accuracy: 89.773%
# Standard Deviation: 9.575%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.77777778 1.         1.         1.         1.
#  0.66666667 0.88888889 0.88888889 0.875     ]
# Mean Accuracy: 90.972%
# Standard Deviation: 10.923%
#
#
# RESULTS FOR 25 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 25)
# Accuracy of the 25 features SVM model is: 83.333%
# Sensitivity for 25 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 25 features SVM model is:
# [[ 2  3]
#  [ 0 13]]
# Classification report of 25 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.40      0.57         5
#            1       0.81      1.00      0.90        13
#
#     accuracy                           0.83        18
#    macro avg       0.91      0.70      0.73        18
# weighted avg       0.86      0.83      0.81        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.83333333 1.         0.88888889 0.77777778 0.88235294]
# Mean Accuracy: 87.647%
# Standard Deviation: 7.355%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.72727273 1.         0.90909091 0.81818182 0.81818182
#  0.81818182 0.90909091]
# Mean Accuracy: 87.5%
# Standard Deviation: 9.02%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.66666667 1.         1.         0.88888889 1.
#  0.66666667 0.88888889 0.88888889 0.875     ]
# Mean Accuracy: 88.75%
# Standard Deviation: 12.179%
#
#
# RESULTS FOR 35 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 35)
# Accuracy of the 35 features SVM model is: 83.333%
# Sensitivity for 35 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 35 features SVM model is:
# [[ 2  3]
#  [ 0 13]]
# Classification report of 35 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.40      0.57         5
#            1       0.81      1.00      0.90        13
#
#     accuracy                           0.83        18
#    macro avg       0.91      0.70      0.73        18
# weighted avg       0.86      0.83      0.81        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.83333333 1.         0.88888889 0.77777778 0.88235294]
# Mean Accuracy: 87.647%
# Standard Deviation: 7.355%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.81818182 1.         0.90909091 0.81818182 0.81818182
#  0.81818182 0.90909091]
# Mean Accuracy: 88.636%
# Standard Deviation: 7.538%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.77777778 1.         1.         0.88888889 1.
#  0.66666667 0.88888889 0.88888889 0.875     ]
# Mean Accuracy: 89.861%
# Standard Deviation: 10.505%
#
#
# RESULTS FOR 45 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 45)
# Accuracy of the 45 features SVM model is: 83.333%
# Sensitivity for 45 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 45 features SVM model is:
# [[ 2  3]
#  [ 0 13]]
# Classification report of 45 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.40      0.57         5
#            1       0.81      1.00      0.90        13
#
#     accuracy                           0.83        18
#    macro avg       0.91      0.70      0.73        18
# weighted avg       0.86      0.83      0.81        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.83333333 1.         0.88888889 0.77777778 0.88235294]
# Mean Accuracy: 87.647%
# Standard Deviation: 7.355%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.81818182 1.         0.90909091 0.81818182 0.81818182
#  0.81818182 0.90909091]
# Mean Accuracy: 88.636%
# Standard Deviation: 7.538%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.77777778 1.         1.         0.88888889 0.88888889
#  0.66666667 0.88888889 0.88888889 0.875     ]
# Mean Accuracy: 88.75%
# Standard Deviation: 9.947%
#
#
# RESULTS FOR 55 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 55)
# Accuracy of the 55 features SVM model is: 83.333%
# Sensitivity for 55 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 55 features SVM model is:
# [[ 2  3]
#  [ 0 13]]
# Classification report of 55 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.40      0.57         5
#            1       0.81      1.00      0.90        13
#
#     accuracy                           0.83        18
#    macro avg       0.91      0.70      0.73        18
# weighted avg       0.86      0.83      0.81        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.83333333 1.         0.88888889 0.77777778 0.88235294]
# Mean Accuracy: 87.647%
# Standard Deviation: 7.355%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.81818182 1.         0.90909091 0.81818182 0.81818182
#  0.81818182 0.90909091]
# Mean Accuracy: 88.636%
# Standard Deviation: 7.538%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.77777778 1.         1.         0.88888889 0.88888889
#  0.66666667 0.88888889 0.88888889 0.875     ]
# Mean Accuracy: 88.75%
# Standard Deviation: 9.947%
#
#
# RESULTS FOR 65 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 65)
# Accuracy of the 65 features SVM model is: 83.333%
# Sensitivity for 65 features SVM model (True Positive Rate): 100.0%
# Confusion matrix of the 65 features SVM model is:
# [[ 2  3]
#  [ 0 13]]
# Classification report of 65 features SVM model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.40      0.57         5
#            1       0.81      1.00      0.90        13
#
#     accuracy                           0.83        18
#    macro avg       0.91      0.70      0.73        18
# weighted avg       0.86      0.83      0.81        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.83333333 1.         0.88888889 0.77777778 0.88235294]
# Mean Accuracy: 87.647%
# Standard Deviation: 7.355%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.81818182 1.         0.90909091 0.81818182 0.81818182
#  0.81818182 0.90909091]
# Mean Accuracy: 88.636%
# Standard Deviation: 7.538%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.77777778 1.         1.         0.88888889 0.88888889
#  0.66666667 0.88888889 0.88888889 0.875     ]
# Mean Accuracy: 88.75%
# Standard Deviation: 9.947%

# %%
# Extract the data for plotting
x_values = results_svm.keys()
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results_svm.values()]
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results_svm.values()]

# Create a single plot for mean accuracy and standard deviation
plt.figure(figsize=(12, 8))

plt.errorbar(x_values, mean_5_fold, yerr=std_5_fold, marker='o', label='5-fold', linestyle='-', capsize=5)

plt.xlabel('Number of features')
plt.ylabel('Mean Accuracy')
plt.title('Variation of Mean Accuracy with different number of features for 5-fold Cross Validation')
plt.legend()
plt.grid(True)

plt.show()

# %%
results_svm
# Out:
# {5: {'accuracy': 88.889,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 90.98, 'standard-deviation': 8.354},
#   'acc-std': '89.722% ± 11.919%',
#   '8-fold-CV': {'mean-accuracy': 90.909, 'standard-deviation': 7.873},
#   '10-fold-CV': {'mean-accuracy': 89.722, 'standard-deviation': 11.919}},
#  15: {'accuracy': 83.333,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 88.758, 'standard-deviation': 7.861},
#   'acc-std': '90.972% ± 10.923%',
#   '8-fold-CV': {'mean-accuracy': 89.773, 'standard-deviation': 9.575},
#   '10-fold-CV': {'mean-accuracy': 90.972, 'standard-deviation': 10.923}},
#  25: {'accuracy': 83.333,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 87.647, 'standard-deviation': 7.355},
#   'acc-std': '88.75% ± 12.179%',
#   '8-fold-CV': {'mean-accuracy': 87.5, 'standard-deviation': 9.02},
#   '10-fold-CV': {'mean-accuracy': 88.75, 'standard-deviation': 12.179}},
#  35: {'accuracy': 83.333,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 87.647, 'standard-deviation': 7.355},
#   'acc-std': '89.861% ± 10.505%',
#   '8-fold-CV': {'mean-accuracy': 88.636, 'standard-deviation': 7.538},
#   '10-fold-CV': {'mean-accuracy': 89.861, 'standard-deviation': 10.505}},
#  45: {'accuracy': 83.333,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 87.647, 'standard-deviation': 7.355},
#   'acc-std': '88.75% ± 9.947%',
#   '8-fold-CV': {'mean-accuracy': 88.636, 'standard-deviation': 7.538},
#   '10-fold-CV': {'mean-accuracy': 88.75, 'standard-deviation': 9.947}},
#  55: {'accuracy': 83.333,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 87.647, 'standard-deviation': 7.355},
#   'acc-std': '88.75% ± 9.947%',
#   '8-fold-CV': {'mean-accuracy': 88.636, 'standard-deviation': 7.538},
#   '10-fold-CV': {'mean-accuracy': 88.75, 'standard-deviation': 9.947}},
#  65: {'accuracy': 83.333,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 87.647, 'standard-deviation': 7.355},
#   'acc-std': '88.75% ± 9.947%',
#   '8-fold-CV': {'mean-accuracy': 88.636, 'standard-deviation': 7.538},
#   '10-fold-CV': {'mean-accuracy': 88.75, 'standard-deviation': 9.947}}}

# %%
import matplotlib.pyplot as plt

x_values = results_svm.keys()
# Mean accuracy values for different number of features
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results_svm.values()]

# Standard deviation values for different number of features
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results_svm.values()]

# Create a bar chart for mean accuracy
plt.figure(figsize=(10, 6))
plt.bar(x_values, mean_5_fold, yerr=std_5_fold, capsize=5)
plt.xlabel("Number of Features")
plt.ylabel("Mean Accuracy")
plt.title("Mean Accuracy for Different Number of Features for SVM")
plt.show()

# %%
# Random Forest
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

no_of_features = [5, 15, 25, 35, 45, 55, 65]
cross_val_k = [5, 8, 10]
results_rf = {}

for feature_count in no_of_features:
    print(f"RESULTS FOR {feature_count} FEATURES")
    print("--------------------------------------------------")

    results_rf[feature_count] = {}

    # Feature selection using mutual information
    mi_classif = SelectKBest(score_func=mutual_info_classif, k=feature_count)

    # Apply the mutual information selector on the dataset
    X_MI_selected = mi_classif.fit_transform(X, y)

    # Get the selected features
    selected_features = mi_classif.get_support()

    # Feature names of selected features
    selected_feature_names = X.columns[selected_features]

    X_new = X[selected_feature_names]

    print("Shape of X_new: ", X_new.shape)

    # Divide the dataset to train 0.8 and test 0.2
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Create Random Forest classifier and fit the data
    rf_classif = RandomForestClassifier(n_estimators=100, random_state=42)
    rf_classif.fit(X_train, y_train)

    # Test the model on the test set
    y_pred = rf_classif.predict(X_test)

    # Check the accuracy of the model
    accuracy_rf_model = accuracy_score(y_test, y_pred)
    print(f"Accuracy of the {feature_count} features Random Forest model is: {round(accuracy_rf_model * 100, 3)}%")

    results_rf[feature_count]["accuracy"] = round(accuracy_rf_model * 100, 3)

    # Confusion matrix of the model
    confusion_matrix_rf_model = confusion_matrix(y_test, y_pred)

    TP_rf_model = confusion_matrix_rf_model[1, 1]  # True Positives
    FN_rf_model = confusion_matrix_rf_model[1, 0]  # False Negatives

    # Calculate Sensitivity (True Positive Rate or Recall)
    sensitivity_rf_model = TP_rf_model / (TP_rf_model + FN_rf_model)
    print(f"Sensitivity for {feature_count} features Random Forest model (True Positive Rate): {round(sensitivity_rf_model * 100, 3)}%")

    results_rf[feature_count]["sensitivity"] = round(sensitivity_rf_model * 100, 3)

    # Print the confusion matrix
    print(f"Confusion matrix of the {feature_count} features Random Forest model is: ")
    print(confusion_matrix_rf_model)

    # Classification report for the model
    report_rf_model = classification_report(y_test, y_pred)
    print(f"Classification report of {feature_count} features Random Forest model is: ")
    print(report_rf_model)

    # Now let's do the cross-validation
    for k in cross_val_k:
        print(f"{k}-fold Cross Validation")

        results_rf[feature_count][f"{k}-fold-CV"] = {}

        # Create a cross-validation object (K-Fold cross-validator)
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Perform k-fold cross-validation and get the cross-validation scores using Random Forest
        scores = cross_val_score(rf_classif, X_new, y, cv=kf, scoring='accuracy')

        # Print the cross-validation scores
        print("Cross-Validation Scores:", scores)

        # Calculate and print the mean and standard deviation of the scores
        print(f"Mean Accuracy: {round(scores.mean() * 100, 3)}%")
        print(f"Standard Deviation: {round(scores.std() * 100, 3)}%")

        results_rf[feature_count][f"{k}-fold-CV"]["mean-accuracy"] = round(scores.mean() * 100, 3)
        results_rf[feature_count][f"{k}-fold-CV"]["standard-deviation"] = round(scores.std() * 100, 3)
        results_rf[feature_count]["acc-std"] = f"{results_rf[feature_count][f'{k}-fold-CV']['mean-accuracy']}% ± {results_rf[feature_count][f'{k}-fold-CV']['standard-deviation']}%"

        print("")
    print("")
# Out:
# RESULTS FOR 5 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 5)
# Accuracy of the 5 features Random Forest model is: 100.0%
# Sensitivity for 5 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 5 features Random Forest model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 5 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 1.         0.88888889 0.94117647]
# Mean Accuracy: 94.379%
# Standard Deviation: 3.516%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.90909091 0.90909091 1.         0.90909091 0.90909091
#  0.90909091 0.90909091]
# Mean Accuracy: 93.182%
# Standard Deviation: 3.936%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 0.88888889 1.         1.         1.
#  0.77777778 1.         0.88888889 0.875     ]
# Mean Accuracy: 93.194%
# Standard Deviation: 7.465%
#
#
# RESULTS FOR 15 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 15)
# Accuracy of the 15 features Random Forest model is: 94.444%
# Sensitivity for 15 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 15 features Random Forest model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 15 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 1.         1.         0.88888889 0.94117647]
# Mean Accuracy: 95.49%
# Standard Deviation: 4.177%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.90909091 1.         1.         0.90909091 0.90909091
#  0.90909091 0.90909091]
# Mean Accuracy: 94.318%
# Standard Deviation: 4.401%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 1.         1.         1.         1.
#  0.66666667 1.         0.88888889 0.875     ]
# Mean Accuracy: 93.194%
# Standard Deviation: 10.252%
#
#
# RESULTS FOR 25 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 25)
# Accuracy of the 25 features Random Forest model is: 94.444%
# Sensitivity for 25 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 25 features Random Forest model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 25 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 1.         0.94444444 0.94117647]
# Mean Accuracy: 95.49%
# Standard Deviation: 2.258%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.90909091 0.90909091 1.         0.90909091 1.
#  0.90909091 0.90909091]
# Mean Accuracy: 94.318%
# Standard Deviation: 4.401%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 0.88888889 1.         1.         1.
#  0.77777778 1.         0.88888889 0.875     ]
# Mean Accuracy: 93.194%
# Standard Deviation: 7.465%
#
#
# RESULTS FOR 35 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 35)
# Accuracy of the 35 features Random Forest model is: 94.444%
# Sensitivity for 35 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 35 features Random Forest model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 35 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 1.         1.         0.94444444 0.94117647]
# Mean Accuracy: 96.601%
# Standard Deviation: 2.778%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.90909091 1.         1.         0.90909091 1.
#  0.90909091 0.90909091]
# Mean Accuracy: 95.455%
# Standard Deviation: 4.545%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 0.88888889 1.         1.         1.
#  0.88888889 1.         0.88888889 1.        ]
# Mean Accuracy: 95.556%
# Standard Deviation: 5.443%
#
#
# RESULTS FOR 45 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 45)
# Accuracy of the 45 features Random Forest model is: 94.444%
# Sensitivity for 45 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 45 features Random Forest model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 45 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 1.         0.94444444 1.        ]
# Mean Accuracy: 96.667%
# Standard Deviation: 2.722%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.90909091 1.         1.         0.90909091 1.
#  0.90909091 0.90909091]
# Mean Accuracy: 95.455%
# Standard Deviation: 4.545%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 0.88888889 1.         1.         1.
#  0.88888889 1.         0.88888889 0.875     ]
# Mean Accuracy: 94.306%
# Standard Deviation: 5.708%
#
#
# RESULTS FOR 55 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 55)
# Accuracy of the 55 features Random Forest model is: 94.444%
# Sensitivity for 55 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 55 features Random Forest model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 55 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 1.         0.94444444 0.94117647]
# Mean Accuracy: 95.49%
# Standard Deviation: 2.258%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.90909091 1.         1.         0.90909091 1.
#  1.         1.        ]
# Mean Accuracy: 97.727%
# Standard Deviation: 3.936%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 0.88888889 1.         1.         1.
#  0.88888889 1.         0.88888889 0.875     ]
# Mean Accuracy: 94.306%
# Standard Deviation: 5.708%
#
#
# RESULTS FOR 65 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 65)
# Accuracy of the 65 features Random Forest model is: 94.444%
# Sensitivity for 65 features Random Forest model (True Positive Rate): 100.0%
# Confusion matrix of the 65 features Random Forest model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 65 features Random Forest model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 1.         0.94444444 1.        ]
# Mean Accuracy: 96.667%
# Standard Deviation: 2.722%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.90909091 1.         1.         0.90909091 1.
#  1.         1.        ]
# Mean Accuracy: 97.727%
# Standard Deviation: 3.936%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 1.         1.         1.         1.
#  0.88888889 1.         0.88888889 0.875     ]
# Mean Accuracy: 95.417%
# Standard Deviation: 5.626%

# %%
# Extract the data for plotting
x_values = results_rf.keys()
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results_rf.values()]
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results_rf.values()]

# Create a single plot for mean accuracy and standard deviation
plt.figure(figsize=(12, 8))

plt.errorbar(x_values, mean_5_fold, yerr=std_5_fold, marker='o', label='5-fold', linestyle='-', capsize=5)

plt.xlabel('Number of features')
plt.ylabel('Mean Accuracy')
plt.title('Variation of Mean Accuracy with different number of features for 5-fold Cross Validation')
plt.legend()
plt.grid(True)

plt.show()

# %%
results_rf
# Out:
# {5: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.379, 'standard-deviation': 3.516},
#   'acc-std': '93.194% ± 7.465%',
#   '8-fold-CV': {'mean-accuracy': 93.182, 'standard-deviation': 3.936},
#   '10-fold-CV': {'mean-accuracy': 93.194, 'standard-deviation': 7.465}},
#  15: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.49, 'standard-deviation': 4.177},
#   'acc-std': '93.194% ± 10.252%',
#   '8-fold-CV': {'mean-accuracy': 94.318, 'standard-deviation': 4.401},
#   '10-fold-CV': {'mean-accuracy': 93.194, 'standard-deviation': 10.252}},
#  25: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.49, 'standard-deviation': 2.258},
#   'acc-std': '93.194% ± 7.465%',
#   '8-fold-CV': {'mean-accuracy': 94.318, 'standard-deviation': 4.401},
#   '10-fold-CV': {'mean-accuracy': 93.194, 'standard-deviation': 7.465}},
#  35: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 96.601, 'standard-deviation': 2.778},
#   'acc-std': '95.556% ± 5.443%',
#   '8-fold-CV': {'mean-accuracy': 95.455, 'standard-deviation': 4.545},
#   '10-fold-CV': {'mean-accuracy': 95.556, 'standard-deviation': 5.443}},
#  45: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 96.667, 'standard-deviation': 2.722},
#   'acc-std': '94.306% ± 5.708%',
#   '8-fold-CV': {'mean-accuracy': 95.455, 'standard-deviation': 4.545},
#   '10-fold-CV': {'mean-accuracy': 94.306, 'standard-deviation': 5.708}},
#  55: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.49, 'standard-deviation': 2.258},
#   'acc-std': '94.306% ± 5.708%',
#   '8-fold-CV': {'mean-accuracy': 97.727, 'standard-deviation': 3.936},
#   '10-fold-CV': {'mean-accuracy': 94.306, 'standard-deviation': 5.708}},
#  65: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 96.667, 'standard-deviation': 2.722},
#   'acc-std': '95.417% ± 5.626%',
#   '8-fold-CV': {'mean-accuracy': 97.727, 'standard-deviation': 3.936},
#   '10-fold-CV': {'mean-accuracy': 95.417, 'standard-deviation': 5.626}}}

# %%
# XGBoost
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

no_of_features = [5, 15, 25, 35, 45, 55, 65]
cross_val_k = [5, 8, 10]
results_xgb = {}

for feature_count in no_of_features:
    print(f"RESULTS FOR {feature_count} FEATURES")
    print("--------------------------------------------------")

    results_xgb[feature_count] = {}

    # Feature selection using mutual information
    mi_classif = SelectKBest(score_func=mutual_info_classif, k=feature_count)

    # Apply the mutual information selector on the dataset
    X_MI_selected = mi_classif.fit_transform(X, y)

    # Get the selected features
    selected_features = mi_classif.get_support()

    # Feature names of selected features
    selected_feature_names = X.columns[selected_features]

    X_new = X[selected_feature_names]

    print("Shape of X_new: ", X_new.shape)

    # Divide the dataset to train 0.8 and test 0.2
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Create XGBoost classifier and fit the data
    xgb_classif = XGBClassifier()
    xgb_classif.fit(X_train, y_train)

    # Test the model on the test set
    y_pred = xgb_classif.predict(X_test)

    # Check the accuracy of the model
    accuracy_xgb_model = accuracy_score(y_test, y_pred)
    print(f"Accuracy of the {feature_count} features XGBoost model is: {round(accuracy_xgb_model * 100, 3)}%")

    results_xgb[feature_count]["accuracy"] = round(accuracy_xgb_model * 100, 3)

    # Confusion matrix of the model
    confusion_matrix_xgb_model = confusion_matrix(y_test, y_pred)

    TP_xgb_model = confusion_matrix_xgb_model[1, 1]  # True Positives
    FN_xgb_model = confusion_matrix_xgb_model[1, 0]  # False Negatives

    # Calculate Sensitivity (True Positive Rate or Recall)
    sensitivity_xgb_model = TP_xgb_model / (TP_xgb_model + FN_xgb_model)
    print(f"Sensitivity for {feature_count} features XGBoost model (True Positive Rate): {round(sensitivity_xgb_model * 100, 3)}%")

    results_xgb[feature_count]["sensitivity"] = round(sensitivity_xgb_model * 100, 3)

    # Print the confusion matrix
    print(f"Confusion matrix of the {feature_count} features XGBoost model is: ")
    print(confusion_matrix_xgb_model)

    # Classification report for the model
    report_xgb_model = classification_report(y_test, y_pred)
    print(f"Classification report of {feature_count} features XGBoost model is: ")
    print(report_xgb_model)

    # Now let's do the cross-validation
    for k in cross_val_k:
        print(f"{k}-fold Cross Validation")

        results_xgb[feature_count][f"{k}-fold-CV"] = {}

        # Create a cross-validation object (K-Fold cross-validator)
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Perform k-fold cross-validation and get the cross-validation scores using XGBoost
        scores = cross_val_score(xgb_classif, X_new, y, cv=kf, scoring='accuracy')

        # Print the cross-validation scores
        print("Cross-Validation Scores:", scores)

        # Calculate and print the mean and standard deviation of the scores
        print(f"Mean Accuracy: {round(scores.mean() * 100, 3)}%")
        print(f"Standard Deviation: {round(scores.std() * 100, 3)}%")

        results_xgb[feature_count][f"{k}-fold-CV"]["mean-accuracy"] = round(scores.mean() * 100, 3)
        results_xgb[feature_count][f"{k}-fold-CV"]["standard-deviation"] = round(scores.std() * 100, 3)
        results_xgb[feature_count]["acc-std"] = f"{results_xgb[feature_count][f'{k}-fold-CV']['mean-accuracy']}% ± {results_xgb[feature_count][f'{k}-fold-CV']['standard-deviation']}%"

        print("")
    print("")
# Out:
# RESULTS FOR 5 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 5)
# Accuracy of the 5 features XGBoost model is: 100.0%
# Sensitivity for 5 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 5 features XGBoost model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 5 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [1.         0.94444444 1.         0.88888889 0.94117647]
# Mean Accuracy: 95.49%
# Standard Deviation: 4.177%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.90909091 1.         0.90909091 0.81818182
#  1.         0.90909091]
# Mean Accuracy: 94.318%
# Standard Deviation: 6.327%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.88888889 1.         1.         1.
#  0.88888889 0.88888889 1.         0.875     ]
# Mean Accuracy: 95.417%
# Standard Deviation: 5.626%
#
#
# RESULTS FOR 15 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 15)
# Accuracy of the 15 features XGBoost model is: 100.0%
# Sensitivity for 15 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 15 features XGBoost model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 15 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [1.         0.94444444 1.         0.88888889 0.88235294]
# Mean Accuracy: 94.314%
# Standard Deviation: 5.12%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.90909091 1.         0.90909091 0.90909091
#  0.90909091 1.        ]
# Mean Accuracy: 95.455%
# Standard Deviation: 4.545%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 0.88888889 1.         1.         1.
#  0.77777778 0.88888889 0.88888889 1.        ]
# Mean Accuracy: 93.333%
# Standard Deviation: 7.37%
#
#
# RESULTS FOR 25 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 25)
# Accuracy of the 25 features XGBoost model is: 100.0%
# Sensitivity for 25 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 25 features XGBoost model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 25 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [1.         0.94444444 1.         0.88888889 1.        ]
# Mean Accuracy: 96.667%
# Standard Deviation: 4.444%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.90909091 1.         0.90909091 0.90909091
#  1.         1.        ]
# Mean Accuracy: 96.591%
# Standard Deviation: 4.401%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.88888889 1.         1.         1.
#  0.77777778 1.         1.         1.        ]
# Mean Accuracy: 96.667%
# Standard Deviation: 7.115%
#
#
# RESULTS FOR 35 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 35)
# Accuracy of the 35 features XGBoost model is: 100.0%
# Sensitivity for 35 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 35 features XGBoost model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 35 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [1.         0.94444444 1.         0.94444444 0.94117647]
# Mean Accuracy: 96.601%
# Standard Deviation: 2.778%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.90909091 1.         0.90909091 0.90909091
#  0.90909091 1.        ]
# Mean Accuracy: 95.455%
# Standard Deviation: 4.545%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.88888889 1.         1.         1.
#  0.88888889 1.         1.         1.        ]
# Mean Accuracy: 97.778%
# Standard Deviation: 4.444%
#
#
# RESULTS FOR 45 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 45)
# Accuracy of the 45 features XGBoost model is: 100.0%
# Sensitivity for 45 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 45 features XGBoost model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 45 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [1.         0.94444444 1.         1.         1.        ]
# Mean Accuracy: 98.889%
# Standard Deviation: 2.222%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.90909091 1.         1.         1.
#  0.90909091 1.        ]
# Mean Accuracy: 97.727%
# Standard Deviation: 3.936%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.88888889 1.         1.         1.
#  1.         1.         1.         1.        ]
# Mean Accuracy: 98.889%
# Standard Deviation: 3.333%
#
#
# RESULTS FOR 55 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 55)
# Accuracy of the 55 features XGBoost model is: 100.0%
# Sensitivity for 55 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 55 features XGBoost model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 55 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [1.         0.94444444 1.         1.         1.        ]
# Mean Accuracy: 98.889%
# Standard Deviation: 2.222%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.90909091 1.         1.         1.
#  1.         1.        ]
# Mean Accuracy: 98.864%
# Standard Deviation: 3.007%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.88888889 1.         1.         1.
#  1.         1.         1.         1.        ]
# Mean Accuracy: 98.889%
# Standard Deviation: 3.333%
#
#
# RESULTS FOR 65 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 65)
# Accuracy of the 65 features XGBoost model is: 100.0%
# Sensitivity for 65 features XGBoost model (True Positive Rate): 100.0%
# Confusion matrix of the 65 features XGBoost model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 65 features XGBoost model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [1.         0.94444444 1.         0.94444444 1.        ]
# Mean Accuracy: 97.778%
# Standard Deviation: 2.722%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.90909091 1.         1.         1.
#  1.         1.        ]
# Mean Accuracy: 98.864%
# Standard Deviation: 3.007%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.88888889 1.         1.         1.
#  0.88888889 1.         1.         1.        ]
# Mean Accuracy: 97.778%
# Standard Deviation: 4.444%

# %%
# Extract the data for plotting
x_values = results_xgb.keys()
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results_xgb.values()]
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results_xgb.values()]

# Create a single plot for mean accuracy and standard deviation
plt.figure(figsize=(12, 8))

plt.errorbar(x_values, mean_5_fold, yerr=std_5_fold, marker='o', label='5-fold', linestyle='-', capsize=5)

plt.xlabel('Number of features')
plt.ylabel('Mean Accuracy')
plt.title('Variation of Mean Accuracy with different number of features for 5-fold Cross Validation')
plt.legend()
plt.grid(True)

plt.show()

# %%
results_xgb
# Out:
# {5: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.49, 'standard-deviation': 4.177},
#   'acc-std': '95.417% ± 5.626%',
#   '8-fold-CV': {'mean-accuracy': 94.318, 'standard-deviation': 6.327},
#   '10-fold-CV': {'mean-accuracy': 95.417, 'standard-deviation': 5.626}},
#  15: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.314, 'standard-deviation': 5.12},
#   'acc-std': '93.333% ± 7.37%',
#   '8-fold-CV': {'mean-accuracy': 95.455, 'standard-deviation': 4.545},
#   '10-fold-CV': {'mean-accuracy': 93.333, 'standard-deviation': 7.37}},
#  25: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 96.667, 'standard-deviation': 4.444},
#   'acc-std': '96.667% ± 7.115%',
#   '8-fold-CV': {'mean-accuracy': 96.591, 'standard-deviation': 4.401},
#   '10-fold-CV': {'mean-accuracy': 96.667, 'standard-deviation': 7.115}},
#  35: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 96.601, 'standard-deviation': 2.778},
#   'acc-std': '97.778% ± 4.444%',
#   '8-fold-CV': {'mean-accuracy': 95.455, 'standard-deviation': 4.545},
#   '10-fold-CV': {'mean-accuracy': 97.778, 'standard-deviation': 4.444}},
#  45: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 98.889, 'standard-deviation': 2.222},
#   'acc-std': '98.889% ± 3.333%',
#   '8-fold-CV': {'mean-accuracy': 97.727, 'standard-deviation': 3.936},
#   '10-fold-CV': {'mean-accuracy': 98.889, 'standard-deviation': 3.333}},
#  55: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 98.889, 'standard-deviation': 2.222},
#   'acc-std': '98.889% ± 3.333%',
#   '8-fold-CV': {'mean-accuracy': 98.864, 'standard-deviation': 3.007},
#   '10-fold-CV': {'mean-accuracy': 98.889, 'standard-deviation': 3.333}},
#  65: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 97.778, 'standard-deviation': 2.722},
#   'acc-std': '97.778% ± 4.444%',
#   '8-fold-CV': {'mean-accuracy': 98.864, 'standard-deviation': 3.007},
#   '10-fold-CV': {'mean-accuracy': 97.778, 'standard-deviation': 4.444}}}

# %%
# Logistic Regression
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

no_of_features = [5, 15, 25, 35, 45, 55, 65]
cross_val_k = [5, 8, 10]
results_lr = {}

for feature_count in no_of_features:
    print(f"RESULTS FOR {feature_count} FEATURES")
    print("--------------------------------------------------")

    results_lr[feature_count] = {}

    # Feature selection using mutual information
    mi_classif = SelectKBest(score_func=mutual_info_classif, k=feature_count)

    # Apply the mutual information selector on the dataset
    X_MI_selected = mi_classif.fit_transform(X, y)

    # Get the selected features
    selected_features = mi_classif.get_support()

    # Feature names of selected features
    selected_feature_names = X.columns[selected_features]

    X_new = X[selected_feature_names]

    print("Shape of X_new: ", X_new.shape)

    # Divide the dataset to train 0.8 and test 0.2
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Create Logistic Regression classifier and fit the data
    lr_classif = LogisticRegression()
    lr_classif.fit(X_train, y_train)

    # Test the model on the test set
    y_pred = lr_classif.predict(X_test)

    # Check the accuracy of the model
    accuracy_lr_model = accuracy_score(y_test, y_pred)
    print(f"Accuracy of the {feature_count} features Logistic Regression model is: {round(accuracy_lr_model * 100, 3)}%")

    results_lr[feature_count]["accuracy"] = round(accuracy_lr_model * 100, 3)

    # Confusion matrix of the model
    confusion_matrix_lr_model = confusion_matrix(y_test, y_pred)

    TP_lr_model = confusion_matrix_lr_model[1, 1]  # True Positives
    FN_lr_model = confusion_matrix_lr_model[1, 0]  # False Negatives

    # Calculate Sensitivity (True Positive Rate or Recall)
    sensitivity_lr_model = TP_lr_model / (TP_lr_model + FN_lr_model)
    print(f"Sensitivity for {feature_count} features Logistic Regression model (True Positive Rate): {round(sensitivity_lr_model * 100, 3)}%")

    results_lr[feature_count]["sensitivity"] = round(sensitivity_lr_model * 100, 3)

    # Print the confusion matrix
    print(f"Confusion matrix of the {feature_count} features Logistic Regression model is: ")
    print(confusion_matrix_lr_model)

    # Classification report for the model
    report_lr_model = classification_report(y_test, y_pred)
    print(f"Classification report of {feature_count} features Logistic Regression model is: ")
    print(report_lr_model)

    # Now let's do the cross-validation
    for k in cross_val_k:
        print(f"{k}-fold Cross Validation")

        results_lr[feature_count][f"{k}-fold-CV"] = {}

        # Create a cross-validation object (K-Fold cross-validator)
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Perform k-fold cross-validation and get the cross-validation scores using Logistic Regression
        scores = cross_val_score(lr_classif, X_new, y, cv=kf, scoring='accuracy')

        # Print the cross-validation scores
        print("Cross-Validation Scores:", scores)

        # Calculate and print the mean and standard deviation of the scores
        print(f"Mean Accuracy: {round(scores.mean() * 100, 3)}%")
        print(f"Standard Deviation: {round(scores.std() * 100, 3)}%")

        results_lr[feature_count][f"{k}-fold-CV"]["mean-accuracy"] = round(scores.mean() * 100, 3)
        results_lr[feature_count][f"{k}-fold-CV"]["standard-deviation"] = round(scores.std() * 100, 3)
        results_lr[feature_count]["acc-std"] = f"{results_lr[feature_count][f'{k}-fold-CV']['mean-accuracy']}% ± {results_lr[feature_count][f'{k}-fold-CV']['standard-deviation']}%"

        print("")
    print("")
# Out:
# RESULTS FOR 5 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 5)
# Accuracy of the 5 features Logistic Regression model is: 94.444%
# Sensitivity for 5 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 5 features Logistic Regression model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 5 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 1.         0.94444444 1.         1.        ]
# Mean Accuracy: 97.778%
# Standard Deviation: 2.722%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.90909091 1.         1.         1.         1.
#  1.         1.        ]
# Mean Accuracy: 98.864%
# Standard Deviation: 3.007%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 1.         1.         1.         1.
#  1.         1.         1.         1.        ]
# Mean Accuracy: 98.889%
# Standard Deviation: 3.333%
#
#
# RESULTS FOR 15 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 15)
# Accuracy of the 15 features Logistic Regression model is: 88.889%
# Sensitivity for 15 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 15 features Logistic Regression model is:
# [[ 3  2]
#  [ 0 13]]
# Classification report of 15 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75         5
#            1       0.87      1.00      0.93        13
#
#     accuracy                           0.89        18
#    macro avg       0.93      0.80      0.84        18
# weighted avg       0.90      0.89      0.88        18
#
# 5-fold Cross Validation
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores: [0.88888889 0.83333333 0.88888889 0.88888889 1.        ]
# Mean Accuracy: 90.0%
# Standard Deviation: 5.443%
#
# 8-fold Cross Validation
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores: [1.         0.81818182 0.90909091 1.         0.72727273 0.90909091
#  1.         0.90909091]
# Mean Accuracy: 90.909%
# Standard Deviation: 9.091%
#
# 10-fold Cross Validation
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores: [1.         0.77777778 0.88888889 0.88888889 1.         0.88888889
#  0.77777778 1.         1.         1.        ]
# Mean Accuracy: 92.222%
# Standard Deviation: 8.678%
#
#
# RESULTS FOR 25 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 25)
# Accuracy of the 25 features Logistic Regression model is: 94.444%
# Sensitivity for 25 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 25 features Logistic Regression model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 25 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.88888889 0.94444444 0.94444444 0.94117647]
# Mean Accuracy: 93.268%
# Standard Deviation: 2.193%
#
# 8-fold Cross Validation
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores: [0.91666667 0.90909091 0.90909091 1.         0.81818182 0.90909091
#  1.         0.90909091]
# Mean Accuracy: 92.14%
# Standard Deviation: 5.436%
#
# 10-fold Cross Validation
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores: [1.         0.88888889 0.77777778 1.         1.         0.88888889
#  0.88888889 1.         1.         0.875     ]
# Mean Accuracy: 93.194%
# Standard Deviation: 7.465%
#
#
# RESULTS FOR 35 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 35)
# Accuracy of the 35 features Logistic Regression model is: 94.444%
# Sensitivity for 35 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 35 features Logistic Regression model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 35 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 1.         0.94444444 0.88888889 0.94117647]
# Mean Accuracy: 94.379%
# Standard Deviation: 3.516%
#
# 8-fold Cross Validation
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores: [1.         0.90909091 1.         1.         0.81818182 0.90909091
#  1.         0.90909091]
# Mean Accuracy: 94.318%
# Standard Deviation: 6.327%
#
# 10-fold Cross Validation
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores: [1.         0.88888889 0.88888889 1.         1.         0.88888889
#  0.77777778 1.         0.88888889 1.        ]
# Mean Accuracy: 93.333%
# Standard Deviation: 7.37%
#
#
# RESULTS FOR 45 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 45)
# Accuracy of the 45 features Logistic Regression model is: 94.444%
# Sensitivity for 45 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 45 features Logistic Regression model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 45 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores: [0.94444444 0.94444444 0.94444444 0.88888889 1.        ]
# Mean Accuracy: 94.444%
# Standard Deviation: 3.514%
#
# 8-fold Cross Validation
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores: [1.         0.88888889 0.88888889 1.         1.         0.88888889
#  0.77777778 1.         1.         1.        ]
# Mean Accuracy: 94.444%
# Standard Deviation: 7.454%
#
#
# RESULTS FOR 65 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 65)
# Accuracy of the 65 features Logistic Regression model is: 100.0%
# Sensitivity for 65 features Logistic Regression model (True Positive Rate): 100.0%
# Confusion matrix of the 65 features Logistic Regression model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 65 features Logistic Regression model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [1.         0.94444444 0.94444444 0.94444444 1.        ]
# Mean Accuracy: 96.667%
# Standard Deviation: 2.722%
#
# 8-fold Cross Validation
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores: [1.         1.         0.90909091 1.         0.90909091 0.90909091
#  1.         1.        ]
# Mean Accuracy: 96.591%
# Standard Deviation: 4.401%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 0.88888889 1.         1.         1.
#  0.88888889 1.         1.         1.        ]
# Mean Accuracy: 96.667%
# Standard Deviation: 5.092%
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Extract the data for plotting
x_values = results_lr.keys()
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results_lr.values()]
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results_lr.values()]

# Create a single plot for mean accuracy and standard deviation
plt.figure(figsize=(12, 8))

plt.errorbar(x_values, mean_5_fold, yerr=std_5_fold, marker='o', label='5-fold', linestyle='-', capsize=5)

plt.xlabel('Number of features')
plt.ylabel('Mean Accuracy')
plt.title('Variation of Mean Accuracy with different number of features for 5-fold Cross Validation')
plt.legend()
plt.grid(True)

plt.show()

# %%
results_lr
# Out:
# {5: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 97.778, 'standard-deviation': 2.722},
#   'acc-std': '98.889% ± 3.333%',
#   '8-fold-CV': {'mean-accuracy': 98.864, 'standard-deviation': 3.007},
#   '10-fold-CV': {'mean-accuracy': 98.889, 'standard-deviation': 3.333}},
#  15: {'accuracy': 88.889,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 90.0, 'standard-deviation': 5.443},
#   'acc-std': '92.222% ± 8.678%',
#   '8-fold-CV': {'mean-accuracy': 90.909, 'standard-deviation': 9.091},
#   '10-fold-CV': {'mean-accuracy': 92.222, 'standard-deviation': 8.678}},
#  25: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 93.268, 'standard-deviation': 2.193},
#   'acc-std': '93.194% ± 7.465%',
#   '8-fold-CV': {'mean-accuracy': 92.14, 'standard-deviation': 5.436},
#   '10-fold-CV': {'mean-accuracy': 93.194, 'standard-deviation': 7.465}},
#  35: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.379, 'standard-deviation': 3.516},
#   'acc-std': '93.333% ± 7.37%',
#   '8-fold-CV': {'mean-accuracy': 94.318, 'standard-deviation': 6.327},
#   '10-fold-CV': {'mean-accuracy': 93.333, 'standard-deviation': 7.37}},
#  45: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.444, 'standard-deviation': 3.514},
#   'acc-std': '93.333% ± 7.37%',
#   '8-fold-CV': {'mean-accuracy': 94.318, 'standard-deviation': 4.401},
#   '10-fold-CV': {'mean-accuracy': 93.333, 'standard-deviation': 7.37}},
#  55: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.444, 'standard-deviation': 3.514},
#   'acc-std': '94.444% ± 7.454%',
#   '8-fold-CV': {'mean-accuracy': 95.455, 'standard-deviation': 4.545},
#   '10-fold-CV': {'mean-accuracy': 94.444, 'standard-deviation': 7.454}},
#  65: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 96.667, 'standard-deviation': 2.722},
#   'acc-std': '96.667% ± 5.092%',
#   '8-fold-CV': {'mean-accuracy': 96.591, 'standard-deviation': 4.401},
#   '10-fold-CV': {'mean-accuracy': 96.667, 'standard-deviation': 5.092}}}

# %%
# Decision Tree
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

no_of_features = [5, 15, 25, 35, 45, 55, 65]
cross_val_k = [5, 8, 10]
results_dt = {}

for feature_count in no_of_features:
    print(f"RESULTS FOR {feature_count} FEATURES")
    print("--------------------------------------------------")

    results_dt[feature_count] = {}

    # Feature selection using mutual information
    mi_classif = SelectKBest(score_func=mutual_info_classif, k=feature_count)

    # Apply the mutual information selector on the dataset
    X_MI_selected = mi_classif.fit_transform(X, y)

    # Get the selected features
    selected_features = mi_classif.get_support()

    # Feature names of selected features
    selected_feature_names = X.columns[selected_features]

    X_new = X[selected_feature_names]

    print("Shape of X_new: ", X_new.shape)

    # Divide the dataset to train 0.8 and test 0.2
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Create Decision Tree classifier and fit the data
    dt_classif = DecisionTreeClassifier()
    dt_classif.fit(X_train, y_train)

    # Test the model on the test set
    y_pred = dt_classif.predict(X_test)

    # Check the accuracy of the model
    accuracy_dt_model = accuracy_score(y_test, y_pred)
    print(f"Accuracy of the {feature_count} features Decision Tree model is: {round(accuracy_dt_model * 100, 3)}%")

    results_dt[feature_count]["accuracy"] = round(accuracy_dt_model * 100, 3)

    # Confusion matrix of the model
    confusion_matrix_dt_model = confusion_matrix(y_test, y_pred)

    TP_dt_model = confusion_matrix_dt_model[1, 1]  # True Positives
    FN_dt_model = confusion_matrix_dt_model[1, 0]  # False Negatives

    # Calculate Sensitivity (True Positive Rate or Recall)
    sensitivity_dt_model = TP_dt_model / (TP_dt_model + FN_dt_model)
    print(f"Sensitivity for {feature_count} features Decision Tree model (True Positive Rate): {round(sensitivity_dt_model * 100, 3)}%")

    results_dt[feature_count]["sensitivity"] = round(sensitivity_dt_model * 100, 3)

    # Print the confusion matrix
    print(f"Confusion matrix of the {feature_count} features Decision Tree model is: ")
    print(confusion_matrix_dt_model)

    # Classification report for the model
    report_dt_model = classification_report(y_test, y_pred)
    print(f"Classification report of {feature_count} features Decision Tree model is: ")
    print(report_dt_model)

    # Now let's do the cross-validation
    for k in cross_val_k:
        print(f"{k}-fold Cross Validation")

        results_dt[feature_count][f"{k}-fold-CV"] = {}

        # Create a cross-validation object (K-Fold cross-validator)
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Perform k-fold cross-validation and get the cross-validation scores using Decision Tree
        scores = cross_val_score(dt_classif, X_new, y, cv=kf, scoring='accuracy')

        # Print the cross-validation scores
        print("Cross-Validation Scores:", scores)

        # Calculate and print the mean and standard deviation of the scores
        print(f"Mean Accuracy: {round(scores.mean() * 100, 3)}%")
        print(f"Standard Deviation: {round(scores.std() * 100, 3)}%")

        results_dt[feature_count][f"{k}-fold-CV"]["mean-accuracy"] = round(scores.mean() * 100, 3)
        results_dt[feature_count][f"{k}-fold-CV"]["standard-deviation"] = round(scores.std() * 100, 3)
        results_dt[feature_count]["acc-std"] = f"{results_dt[feature_count]['5-fold-CV']['mean-accuracy']}% ± {results_dt[feature_count]['5-fold-CV']['standard-deviation']}%"

        print("")
    print("")
# Out:
# RESULTS FOR 5 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 5)
# Accuracy of the 5 features Decision Tree model is: 100.0%
# Sensitivity for 5 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 5 features Decision Tree model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 5 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [1.         0.94444444 1.         0.94444444 0.88235294]
# Mean Accuracy: 95.425%
# Standard Deviation: 4.37%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.90909091 1.         1.         0.90909091
#  0.81818182 0.90909091]
# Mean Accuracy: 94.318%
# Standard Deviation: 6.327%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.88888889 1.         1.         1.
#  0.88888889 0.88888889 0.88888889 0.75      ]
# Mean Accuracy: 93.056%
# Standard Deviation: 7.979%
#
#
# RESULTS FOR 15 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 15)
# Accuracy of the 15 features Decision Tree model is: 94.444%
# Sensitivity for 15 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 15 features Decision Tree model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 15 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [1.         0.94444444 1.         1.         0.94117647]
# Mean Accuracy: 97.712%
# Standard Deviation: 2.804%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.90909091 0.90909091 1.         1.         1.
#  0.90909091 0.81818182]
# Mean Accuracy: 94.318%
# Standard Deviation: 6.327%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 0.88888889 1.         0.88888889 1.
#  0.77777778 1.         0.88888889 0.875     ]
# Mean Accuracy: 92.083%
# Standard Deviation: 7.191%
#
#
# RESULTS FOR 25 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 25)
# Accuracy of the 25 features Decision Tree model is: 94.444%
# Sensitivity for 25 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 25 features Decision Tree model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 25 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 1.         0.94444444 0.94117647]
# Mean Accuracy: 95.49%
# Standard Deviation: 2.258%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.90909091 0.90909091 1.         1.         0.90909091
#  1.         0.90909091]
# Mean Accuracy: 95.455%
# Standard Deviation: 4.545%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 0.88888889 1.         1.         1.
#  1.         1.         0.88888889 0.875     ]
# Mean Accuracy: 95.417%
# Standard Deviation: 5.626%
#
#
# RESULTS FOR 35 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 35)
# Accuracy of the 35 features Decision Tree model is: 100.0%
# Sensitivity for 35 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 35 features Decision Tree model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 35 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 0.88888889 0.88888889 0.94117647]
# Mean Accuracy: 92.157%
# Standard Deviation: 2.671%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.90909091 1.         1.         0.90909091
#  0.90909091 0.90909091]
# Mean Accuracy: 95.455%
# Standard Deviation: 4.545%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.88888889 1.         1.         1.
#  1.         1.         0.88888889 0.875     ]
# Mean Accuracy: 96.528%
# Standard Deviation: 5.316%
#
#
# RESULTS FOR 45 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 45)
# Accuracy of the 45 features Decision Tree model is: 94.444%
# Sensitivity for 45 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 45 features Decision Tree model is:
# [[ 4  1]
#  [ 0 13]]
# Classification report of 45 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.93      1.00      0.96        13
#
#     accuracy                           0.94        18
#    macro avg       0.96      0.90      0.93        18
# weighted avg       0.95      0.94      0.94        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 1.         0.88888889 0.88235294]
# Mean Accuracy: 93.203%
# Standard Deviation: 5.555%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.81818182 1.         1.         0.90909091
#  0.90909091 0.81818182]
# Mean Accuracy: 93.182%
# Standard Deviation: 7.538%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.88888889 0.88888889 1.         1.
#  0.88888889 1.         0.88888889 0.75      ]
# Mean Accuracy: 93.056%
# Standard Deviation: 7.979%
#
#
# RESULTS FOR 55 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 55)
# Accuracy of the 55 features Decision Tree model is: 100.0%
# Sensitivity for 55 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 55 features Decision Tree model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 55 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [1.         0.88888889 0.94444444 0.94444444 0.94117647]
# Mean Accuracy: 94.379%
# Standard Deviation: 3.516%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.81818182 1.         1.         0.90909091
#  1.         0.90909091]
# Mean Accuracy: 95.455%
# Standard Deviation: 6.428%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.88888889 1.         1.         1.
#  1.         1.         0.88888889 0.875     ]
# Mean Accuracy: 96.528%
# Standard Deviation: 5.316%
#
#
# RESULTS FOR 65 FEATURES
# --------------------------------------------------
# Shape of X_new:  (89, 65)
# Accuracy of the 65 features Decision Tree model is: 100.0%
# Sensitivity for 65 features Decision Tree model (True Positive Rate): 100.0%
# Confusion matrix of the 65 features Decision Tree model is:
# [[ 5  0]
#  [ 0 13]]
# Classification report of 65 features Decision Tree model is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        13
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 5-fold Cross Validation
# Cross-Validation Scores: [0.94444444 0.94444444 0.83333333 0.94444444 0.94117647]
# Mean Accuracy: 92.157%
# Standard Deviation: 4.414%
#
# 8-fold Cross Validation
# Cross-Validation Scores: [1.         0.90909091 0.90909091 1.         1.         0.81818182
#  0.90909091 0.90909091]
# Mean Accuracy: 93.182%
# Standard Deviation: 6.013%
#
# 10-fold Cross Validation
# Cross-Validation Scores: [1.         1.         0.88888889 0.88888889 1.         1.
#  0.88888889 1.         0.88888889 0.875     ]
# Mean Accuracy: 94.306%
# Standard Deviation: 5.708%

# %%
# Extract the data for plotting
x_values = results_dt.keys()
mean_5_fold = [item['5-fold-CV']['mean-accuracy'] for item in results_dt.values()]
std_5_fold = [item['5-fold-CV']['standard-deviation'] for item in results_dt.values()]

# Create a single plot for mean accuracy and standard deviation
plt.figure(figsize=(12, 8))

plt.errorbar(x_values, mean_5_fold, yerr=std_5_fold, marker='o', label='5-fold', linestyle='-', capsize=5)

plt.xlabel('Number of features')
plt.ylabel('Mean Accuracy')
plt.title('Variation of Mean Accuracy with different number of features for 5-fold Cross Validation')
plt.legend()
plt.grid(True)

plt.show()

# %%
results_dt
# Out:
# {5: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.425, 'standard-deviation': 4.37},
#   'acc-std': '95.425% ± 4.37%',
#   '8-fold-CV': {'mean-accuracy': 94.318, 'standard-deviation': 6.327},
#   '10-fold-CV': {'mean-accuracy': 93.056, 'standard-deviation': 7.979}},
#  15: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 97.712, 'standard-deviation': 2.804},
#   'acc-std': '97.712% ± 2.804%',
#   '8-fold-CV': {'mean-accuracy': 94.318, 'standard-deviation': 6.327},
#   '10-fold-CV': {'mean-accuracy': 92.083, 'standard-deviation': 7.191}},
#  25: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 95.49, 'standard-deviation': 2.258},
#   'acc-std': '95.49% ± 2.258%',
#   '8-fold-CV': {'mean-accuracy': 95.455, 'standard-deviation': 4.545},
#   '10-fold-CV': {'mean-accuracy': 95.417, 'standard-deviation': 5.626}},
#  35: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 92.157, 'standard-deviation': 2.671},
#   'acc-std': '92.157% ± 2.671%',
#   '8-fold-CV': {'mean-accuracy': 95.455, 'standard-deviation': 4.545},
#   '10-fold-CV': {'mean-accuracy': 96.528, 'standard-deviation': 5.316}},
#  45: {'accuracy': 94.444,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 93.203, 'standard-deviation': 5.555},
#   'acc-std': '93.203% ± 5.555%',
#   '8-fold-CV': {'mean-accuracy': 93.182, 'standard-deviation': 7.538},
#   '10-fold-CV': {'mean-accuracy': 93.056, 'standard-deviation': 7.979}},
#  55: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 94.379, 'standard-deviation': 3.516},
#   'acc-std': '94.379% ± 3.516%',
#   '8-fold-CV': {'mean-accuracy': 95.455, 'standard-deviation': 6.428},
#   '10-fold-CV': {'mean-accuracy': 96.528, 'standard-deviation': 5.316}},
#  65: {'accuracy': 100.0,
#   'sensitivity': 100.0,
#   '5-fold-CV': {'mean-accuracy': 92.157, 'standard-deviation': 4.414},
#   'acc-std': '92.157% ± 4.414%',
#   '8-fold-CV': {'mean-accuracy': 93.182, 'standard-deviation': 6.013},
#   '10-fold-CV': {'mean-accuracy': 94.306, 'standard-deviation': 5.708}}}

# %%
# plotting all the results for RNA data

# %%
import matplotlib.pyplot as plt

# Create a figure and axis
fig, ax = plt.subplots()

# Define colors for each algorithm
colors = ['b', 'g', 'r', 'c', 'm']  # You can add more colors if needed

# Data for different algorithms
algorithms = ['SVM', 'Random Forest', 'XGBoost', 'Logistic Regression', 'Decision Tree']
data = [results_svm, results_rf, results_xgb, results_lr, results_dt]

# Plot data for each algorithm
for i, algorithm_data in enumerate(data):
    mean_accuracies = [item['5-fold-CV']['mean-accuracy'] for item in algorithm_data.values()]
    std_devs = [item['5-fold-CV']['standard-deviation'] for item in algorithm_data.values()]

    feature_counts = list(algorithm_data.keys())

    ax.errorbar(
        feature_counts,
        mean_accuracies,
        yerr=std_devs,
        label=algorithms[i],
        marker='o',
        color=colors[i],
    )

# Customize the plot
plt.title("Mean Accuracy vs. Number of Features for Different Algorithms (5-fold CV)")
plt.xlabel("Number of Features")
plt.ylabel("Mean Accuracy (%)")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and axis with a larger size
fig, ax = plt.subplots(figsize=(12, 8))

# Define colors for each algorithm
colors = ['b', 'g', 'r', 'c', 'm']  # You can add more colors if needed

# Data for different algorithms
algorithms = ['SVM', 'Random Forest', 'XGBoost', 'Logistic Regression', 'Decision Tree']
data = [results_svm, results_rf, results_xgb, results_lr, results_dt]

# Plot data for each algorithm
for i, algorithm_data in enumerate(data):
    mean_accuracies = [item['5-fold-CV']['mean-accuracy'] for item in algorithm_data.values()]

    feature_counts = list(algorithm_data.keys())

    ax.plot(
        feature_counts,
        mean_accuracies,
        label=algorithms[i],
        marker='o',
        color=colors[i],
    )

# Customize the plot
plt.title("Mean Accuracy vs. Number of Features for Different Algorithms (5-fold CV)")
plt.xlabel("Number of Features")
plt.ylabel("Mean Accuracy (%)")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and axis with a larger size
fig, ax = plt.subplots(figsize=(12, 8))

# Define colors for each algorithm
colors = ['b', 'g', 'r', 'c']

# Data for different algorithms
algorithms = ['SVM', 'Random Forest', 'XGBoost', 'Decision Tree']
data = [results_svm, results_rf, results_xgb, results_dt]

# Plot data for each algorithm
for i, algorithm_data in enumerate(data):
    mean_accuracies = [item['5-fold-CV']['mean-accuracy'] for item in algorithm_data.values()]

    feature_counts = list(algorithm_data.keys())

    ax.plot(
        feature_counts,
        mean_accuracies,
        label=algorithms[i],
        marker='o',
        color=colors[i],
    )

# Customize the plot
plt.title("Mean Accuracy vs. Number of Features for Different Algorithms (5-fold CV)")
plt.xlabel("Number of Features")
plt.ylabel("Mean Accuracy (%)")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and axis with a larger size
fig, ax = plt.subplots(figsize=(12, 8))

# Define colors for each algorithm
colors = ['b', 'g', 'r', 'c']

# Data for different algorithms
algorithms = ['SVM', 'Random Forest', 'XGBoost', 'Decision Tree']
data = [results_svm, results_rf, results_xgb, results_dt]

# Plot data for each algorithm
for i, algorithm_data in enumerate(data):
    mean_accuracies = [item['5-fold-CV']['mean-accuracy'] for item in algorithm_data.values()]

    feature_counts = list(algorithm_data.keys())

    ax.plot(
        feature_counts,
        mean_accuracies,
        label=algorithms[i],
        marker='o',
        color=colors[i],
    )

# Customize the plot
plt.title("Mean Accuracy vs. Number of Features for Different Algorithms (5-fold CV)")
plt.xlabel("Number of Features")
plt.ylabel("Mean Accuracy (%)")
plt.grid(True)

# Show the plot
plt.show()
